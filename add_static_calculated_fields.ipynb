# %%
import pandas as pd
from datetime import datetime
import numpy as np
import math

twitter_human_bots_dataset_path = "twitter_human_bots_dataset/twitter_human_bots_dataset.csv"
tweets_dataset_path = "twitter_human_bots_dataset/tweets140522.csv"

twitter_human_bots_dataset = pd.read_csv(twitter_human_bots_dataset_path, index_col=0)
tweets_dataset = pd.read_csv(tweets_dataset_path, index_col=0)

# %% [markdown]
# # Posts Likes Count

# %%
posts_likes_count = {}

for user_id in twitter_human_bots_dataset.id:
    current_user_tweets = tweets_dataset.loc[tweets_dataset["account_id"]==user_id]
    posts_likes_count[user_id] = (current_user_tweets.shape[0], 
                                  int(current_user_tweets.like_count.sum()))

# %% [markdown]
# # Posts Created At Calcs

# %%
CREATED_AT_TIME_FORMAT = '%Y-%m-%dT%H:%M:%S.%fZ'
TEN_MINUTES_IN_SEC = 10*60
MINUTE_IN_SEC = 60


ACCOUNT_ID_COL = 'account_id'
POSTS_TIMES_COL = 'posts_times'
POSTS_DELTAS_COL = 'posts_deltas'
POSTS_HAVE_CONSTANT_DELTAS_COL = 'posts_constant_deltas'
LESS_THAN_1MIN_DELTAS_COL = 'less_than_one_min_deltas_count'


posts_created_at_calcs_df = pd.DataFrame(columns=[ACCOUNT_ID_COL, POSTS_TIMES_COL, POSTS_DELTAS_COL, 
                                                  POSTS_HAVE_CONSTANT_DELTAS_COL, LESS_THAN_1MIN_DELTAS_COL])

for user_id in twitter_human_bots_dataset.id:
    current_user_tweets = tweets_dataset.loc[tweets_dataset["account_id"]==user_id]
    current_user_tweets_ca_str = current_user_tweets.created_at.dropna().astype(str).tolist()
    current_user_tweets_ca = [datetime.strptime(tweet_created_at, CREATED_AT_TIME_FORMAT) 
                              for tweet_created_at in current_user_tweets_ca_str]
    
    current_user_deltas = []
    for i in range(len(current_user_tweets_ca)-1):
        current_user_deltas.append(current_user_tweets_ca[i]-current_user_tweets_ca[i+1])
        
    # We want to check if a user posts tweets every constant time (means using some automated script probably)
    # We decided to measure this constant time by the creation time deltas variation. 
    # If all posts are with deltas with a difference of max 10 minutes
    total_seconds_deltas = [d.total_seconds() for d in current_user_deltas]
    if len(total_seconds_deltas) > 2:
        user_deltas_avg = sum(total_seconds_deltas) / len(total_seconds_deltas)
        posts_have_constant_deltas = all([abs(tsd-user_deltas_avg)<=TEN_MINUTES_IN_SEC 
                                          for tsd in total_seconds_deltas])
    else:
        posts_have_constant_deltas = None
    
    # We want to check if a user posts tweets in a difference of less than a minute.
    # This data will be represented simply by the count of deltas <= 1min
    
    less_than_1min_deltas = len([t for t in total_seconds_deltas if t<=MINUTE_IN_SEC])
    
    
    posts_created_at_calcs_df = posts_created_at_calcs_df.append(
        {ACCOUNT_ID_COL: user_id,
         POSTS_TIMES_COL: current_user_tweets_ca,
         POSTS_DELTAS_COL: total_seconds_deltas,
         POSTS_HAVE_CONSTANT_DELTAS_COL: posts_have_constant_deltas,
         LESS_THAN_1MIN_DELTAS_COL: less_than_1min_deltas}, ignore_index=True)

# %%
posts_created_at_calcs_df.loc[posts_created_at_calcs_df.posts_constant_deltas==True].account_id
# Out:
# 23                313116175
# 48       772315537992916992
# 59               2157748434
# 64       818494659873951745
# 110              3304160639
#                 ...
# 37266              46745190
# 37317             169696352
# 37349    878072807107600384
# 37369              87343277
# 37430            4588875447
# Name: account_id, Length: 1743, dtype: object

# %%
constant_account_ids = posts_created_at_calcs_df.loc[posts_created_at_calcs_df.posts_constant_deltas==True].account_id.tolist()
twitter_human_bots_dataset.query("id in @constant_account_ids").account_type.value_counts()
# Out:
# bot      1050
# human     693
# Name: account_type, dtype: int64

# %%
# We want to check if a user posts tweets every constant time (means using some automated script probably)
# We decided to measure this constant time by the creation time deltas variation. 
# If all posts are with deltas with a difference of max 10 minutes

# TEN_MINUTES_IN_SEC = 10*60
# posts_constant_deltas = {}

# for user_id, user_deltas in posts_deltas.items():
#     total_seconds_deltas = [d.total_seconds() for d in user_deltas]
#     user_deltas_avg = sum(total_seconds_deltas) / len(total_seconds_deltas)
    
#     posts_constant_deltas[user_id] = all([abs(tsd-user_deltas_avg)<=TEN_MINUTES_IN_SEC 
#                                           for tsd in total_seconds_deltas])

# %%
# We want to check if a user posts tweets in a difference of less than a minute.
# We decided to measure it by dividing

TEN_MINUTES_IN_SEC = 10*60
posts_constant_deltas = {}

for user_id, user_deltas in posts_deltas.items():
    total_seconds_deltas = [d.total_seconds() for d in user_deltas]
    user_deltas_avg = sum(total_seconds_deltas) / len(total_seconds_deltas)
    
    posts_constant_deltas[user_id] = all([abs(tsd-user_deltas_avg)<=TEN_MINUTES_IN_SEC 
                                          for tsd in total_seconds_deltas])

# %%
posts_deltas
# Out:
# {53779179: [datetime.timedelta(seconds=6651),
#   datetime.timedelta(days=9, seconds=53243),
#   datetime.timedelta(seconds=75964),
#   datetime.timedelta(seconds=257),
#   datetime.timedelta(seconds=10),
#   datetime.timedelta(days=11, seconds=14633),
#   datetime.timedelta(seconds=65210),
#   datetime.timedelta(seconds=6309),
#   datetime.timedelta(seconds=31277)],
#  105916557: [datetime.timedelta(days=16, seconds=5867),
#   datetime.timedelta(seconds=2949),
#   datetime.timedelta(days=3, seconds=73259),
#   datetime.timedelta(days=241, seconds=10771),
#   datetime.timedelta(days=105, seconds=54312),
#   datetime.timedelta(seconds=27),
#   datetime.timedelta(seconds=99),
#   datetime.timedelta(days=5, seconds=24751),
#   datetime.timedelta(days=1, seconds=80028)],
#  509788597: [datetime.timedelta(days=1, seconds=9549),
#   datetime.timedelta(days=7, seconds=50946),
#   datetime.timedelta(seconds=103),
#   datetime.timedelta(days=3, seconds=11546),
#   datetime.timedelta(days=1, seconds=36383),
#   datetime.timedelta(days=11, seconds=50032),
#   datetime.timedelta(seconds=38451),
#   datetime.timedelta(seconds=77304),
#   datetime.timedelta(seconds=61120)],
#  70601327: [datetime.timedelta(days=32, seconds=57550),
#   datetime.timedelta(days=22, seconds=27539),
#   datetime.timedelta(days=35, seconds=70256),
#   datetime.timedelta(days=56, seconds=80044),
#   datetime.timedelta(days=2, seconds=67775),
#   datetime.timedelta(seconds=65355),
#   datetime.timedelta(days=2, seconds=78856),
#   datetime.timedelta(days=1, seconds=35266),
#   datetime.timedelta(days=1, seconds=38143)],
#  108999927: [datetime.timedelta(days=84, seconds=47653),
#   datetime.timedelta(days=16, seconds=71344),
#   datetime.timedelta(days=5, seconds=83881),
#   datetime.timedelta(days=6, seconds=10834),
#   datetime.timedelta(days=90, seconds=4380),
#   datetime.timedelta(seconds=2458),
#   datetime.timedelta(days=61, seconds=4249),
#   datetime.timedelta(days=19, seconds=31070),
#   datetime.timedelta(days=24, seconds=43441)],
#  875952456060084225: [datetime.timedelta(seconds=21),
#   datetime.timedelta(seconds=42),
#   datetime.timedelta(seconds=3584),
#   datetime.timedelta(seconds=8),
#   datetime.timedelta(seconds=133),
#   datetime.timedelta(seconds=63)],
#  772481473463083009: [datetime.timedelta(seconds=693),
#   datetime.timedelta(seconds=1483),
#   datetime.timedelta(seconds=517),
#   datetime.timedelta(seconds=759),
#   datetime.timedelta(seconds=999),
#   datetime.timedelta(seconds=179),
#   datetime.timedelta(seconds=540)],
#  2391776040: [],
#  602249341: [],
#  155100760: [datetime.timedelta(days=2, seconds=36892),
#   datetime.timedelta(days=1018, seconds=81113),
#   datetime.timedelta(seconds=36),
#   datetime.timedelta(seconds=35),
#   datetime.timedelta(seconds=15),
#   datetime.timedelta(seconds=36),
#   datetime.timedelta(seconds=26),
#   datetime.timedelta(seconds=194)],
#  178218286: [datetime.timedelta(days=29, seconds=69035),
#   datetime.timedelta(days=10, seconds=22578),
#   datetime.timedelta(days=61, seconds=64826),
#   datetime.timedelta(seconds=34),
#   datetime.timedelta(days=46, seconds=70351),
#   datetime.timedelta(days=23, seconds=36150),
#   datetime.timedelta(days=22, seconds=8696),
#   datetime.timedelta(days=16, seconds=64732),
#   datetime.timedelta(days=12, seconds=72058)],
#  4408686088: [],
#  99847971: [datetime.timedelta(seconds=1470),
#   datetime.timedelta(days=222, seconds=12060),
#   datetime.timedelta(days=689, seconds=70289),
#   datetime.timedelta(days=194, seconds=26932),
#   datetime.timedelta(days=12, seconds=74657),
#   datetime.timedelta(days=152, seconds=77623),
#   datetime.timedelta(days=14, seconds=37056)],
#  1063034450: [datetime.timedelta(days=239, seconds=78189),
#   datetime.timedelta(days=44, seconds=80886),
#   datetime.timedelta(seconds=41),
#   datetime.timedelta(days=31, seconds=58816),
#   datetime.timedelta(days=20, seconds=1230),
#   datetime.timedelta(days=2, seconds=36626),
#   datetime.timedelta(days=11, seconds=85209),
#   datetime.timedelta(days=2, seconds=6479),
#   datetime.timedelta(days=1, seconds=64838)],
#  963263894: [datetime.timedelta(seconds=1059),
#   datetime.timedelta(seconds=3107),
#   datetime.timedelta(seconds=2862),
#   datetime.timedelta(seconds=1641)],
#  537500546: [datetime.timedelta(seconds=3172),
#   datetime.timedelta(seconds=1123),
#   datetime.timedelta(seconds=12155),
#   datetime.timedelta(seconds=4689),
#   datetime.timedelta(seconds=2707),
#   datetime.timedelta(seconds=2067)],
#  569581750: [datetime.timedelta(seconds=64191),
#   datetime.timedelta(days=1, seconds=39495),
#   datetime.timedelta(days=9, seconds=76518),
#   datetime.timedelta(seconds=74756),
#   datetime.timedelta(days=2, seconds=13393),
#   datetime.timedelta(days=3, seconds=78515),
#   datetime.timedelta(days=1, seconds=15978),
#   datetime.timedelta(days=5, seconds=72919),
#   datetime.timedelta(days=4, seconds=21919)],
#  155568211: [datetime.timedelta(seconds=10994),
#   datetime.timedelta(seconds=36606),
#   datetime.timedelta(seconds=14143),
#   datetime.timedelta(seconds=19),
#   datetime.timedelta(seconds=14505),
#   datetime.timedelta(seconds=5482),
#   datetime.timedelta(seconds=16),
#   datetime.timedelta(seconds=11832),
#   datetime.timedelta(seconds=288)],
#  877352477280043008: [datetime.timedelta(seconds=8),
#   datetime.timedelta(seconds=64),
#   datetime.timedelta(seconds=17),
#   datetime.timedelta(seconds=22),
#   datetime.timedelta(seconds=77),
#   datetime.timedelta(seconds=45),
#   datetime.timedelta(seconds=7617)],
#  1449155815: [datetime.timedelta(seconds=205),
#   datetime.timedelta(days=416, seconds=11159),
#   datetime.timedelta(seconds=123),
#   datetime.timedelta(seconds=6),
#   datetime.timedelta(days=19, seconds=67949),
#   datetime.timedelta(seconds=11),
#   datetime.timedelta(seconds=3),
#   datetime.timedelta(seconds=34),
#   datetime.timedelta(seconds=3)],
#  44051445: [datetime.timedelta(seconds=87),
#   datetime.timedelta(seconds=3772),
#   datetime.timedelta(seconds=55),
#   datetime.timedelta(seconds=5),
#   datetime.timedelta(seconds=45),
#   datetime.timedelta(seconds=95)],
#  26152058: [datetime.timedelta(days=335, seconds=39687),
#   datetime.timedelta(seconds=32501),
#   datetime.timedelta(days=155, seconds=48028),
#   datetime.timedelta(days=969, seconds=43387),
#   datetime.timedelta(seconds=262),
#   datetime.timedelta(seconds=235),
#   datetime.timedelta(seconds=82),
#   datetime.timedelta(seconds=201),
#   datetime.timedelta(seconds=25)],
#  3346363073: [datetime.timedelta(seconds=75),
#   datetime.timedelta(seconds=40),
#   datetime.timedelta(seconds=360),
#   datetime.timedelta(seconds=17920),
#   datetime.timedelta(seconds=19),
#   datetime.timedelta(seconds=64),
#   datetime.timedelta(seconds=14822),
#   datetime.timedelta(seconds=14356),
#   datetime.timedelta(seconds=102)],
#  313116175: [datetime.timedelta(seconds=43),
#   datetime.timedelta(seconds=155),
#   datetime.timedelta(seconds=36),
#   datetime.timedelta(seconds=89),
#   datetime.timedelta(seconds=115),
#   datetime.timedelta(seconds=127)],
#  3237927257: [datetime.timedelta(days=17, seconds=4087),
#   datetime.timedelta(days=1, seconds=4497),
#   datetime.timedelta(days=25, seconds=73902),
#   datetime.timedelta(days=3, seconds=74108),
#   datetime.timedelta(days=4, seconds=7758),
#   datetime.timedelta(days=1, seconds=10221),
#   datetime.timedelta(seconds=74053),
#   datetime.timedelta(seconds=35),
#   datetime.timedelta(days=2, seconds=31116)],
#  716612819375038464: [datetime.timedelta(seconds=53),
#   datetime.timedelta(seconds=4456)],
#  264700057: [],
#  50885229: [datetime.timedelta(days=6, seconds=82415),
#   datetime.timedelta(days=4, seconds=39752),
#   datetime.timedelta(seconds=1200),
#   datetime.timedelta(days=3, seconds=35011),
#   datetime.timedelta(days=1, seconds=40493),
#   datetime.timedelta(seconds=42589),
#   datetime.timedelta(seconds=10105),
#   datetime.timedelta(days=2, seconds=46503),
#   datetime.timedelta(days=8, seconds=73916)],
#  3327665070: [datetime.timedelta(days=91, seconds=46352),
#   datetime.timedelta(days=72, seconds=8659),
#   datetime.timedelta(days=1, seconds=35991),
#   datetime.timedelta(days=126, seconds=59799),
#   datetime.timedelta(days=103, seconds=694),
#   datetime.timedelta(days=15, seconds=18966),
#   datetime.timedelta(days=7, seconds=85341),
#   datetime.timedelta(seconds=4),
#   datetime.timedelta(seconds=7)],
#  62204119: [datetime.timedelta(seconds=3241),
#   datetime.timedelta(seconds=1543),
#   datetime.timedelta(seconds=184),
#   datetime.timedelta(seconds=4535),
#   datetime.timedelta(seconds=30655),
#   datetime.timedelta(seconds=10971),
#   datetime.timedelta(seconds=95),
#   datetime.timedelta(seconds=922),
#   datetime.timedelta(seconds=1841)],
#  801240960: [],
#  281473975: [datetime.timedelta(seconds=2376),
#   datetime.timedelta(seconds=21015),
#   datetime.timedelta(seconds=277),
#   datetime.timedelta(seconds=5916),
#   datetime.timedelta(seconds=4955),
#   datetime.timedelta(seconds=1954),
#   datetime.timedelta(seconds=2383),
#   datetime.timedelta(seconds=18628),
#   datetime.timedelta(seconds=30066)],
#  488512845: [datetime.timedelta(seconds=4),
#   datetime.timedelta(seconds=82),
#   datetime.timedelta(days=1, seconds=6408),
#   datetime.timedelta(days=2, seconds=11756),
#   datetime.timedelta(seconds=7),
#   datetime.timedelta(days=5, seconds=64141),
#   datetime.timedelta(days=2, seconds=251),
#   datetime.timedelta(seconds=6),
#   datetime.timedelta(seconds=2)],
#  2952010610: [datetime.timedelta(seconds=51378),
#   datetime.timedelta(days=1, seconds=39671),
#   datetime.timedelta(seconds=48421),
#   datetime.timedelta(seconds=79153),
#   datetime.timedelta(days=2, seconds=437),
#   datetime.timedelta(days=1, seconds=80813),
#   datetime.timedelta(days=1, seconds=3098),
#   datetime.timedelta(seconds=8754),
#   datetime.timedelta(days=2, seconds=74267)],
#  169421357: [datetime.timedelta(seconds=1125),
#   datetime.timedelta(days=108, seconds=44609),
#   datetime.timedelta(days=38, seconds=47598),
#   datetime.timedelta(days=215, seconds=38533),
#   datetime.timedelta(days=19, seconds=67273),
#   datetime.timedelta(days=229, seconds=80887),
#   datetime.timedelta(days=6, seconds=7771),
#   datetime.timedelta(days=7, seconds=23761)],
#  33289393: [datetime.timedelta(days=51, seconds=78152),
#   datetime.timedelta(days=32, seconds=11836),
#   datetime.timedelta(days=16, seconds=37552),
#   datetime.timedelta(seconds=32088),
#   datetime.timedelta(days=1, seconds=34035),
#   datetime.timedelta(days=2, seconds=2246),
#   datetime.timedelta(days=7, seconds=71505),
#   datetime.timedelta(days=3, seconds=17826),
#   datetime.timedelta(days=15, seconds=18899)],
#  15998107: [datetime.timedelta(seconds=66),
#   datetime.timedelta(seconds=708),
#   datetime.timedelta(seconds=261),
#   datetime.timedelta(seconds=19212),
#   datetime.timedelta(seconds=29286),
#   datetime.timedelta(seconds=383),
#   datetime.timedelta(seconds=68),
#   datetime.timedelta(seconds=1443),
#   datetime.timedelta(seconds=3042)],
#  138600717: [datetime.timedelta(days=108, seconds=7201),
#   datetime.timedelta(days=6, seconds=75743),
#   datetime.timedelta(seconds=47),
#   datetime.timedelta(days=1, seconds=82843),
#   datetime.timedelta(seconds=1),
#   datetime.timedelta(days=1, seconds=10662),
#   datetime.timedelta(days=3, seconds=2348),
#   datetime.timedelta(seconds=10),
#   datetime.timedelta(days=3, seconds=69546)],
#  709540733456224257: [datetime.timedelta(seconds=26362),
#   datetime.timedelta(seconds=309),
#   datetime.timedelta(days=46, seconds=80791),
#   datetime.timedelta(days=22, seconds=33844),
#   datetime.timedelta(days=35, seconds=37003),
#   datetime.timedelta(seconds=29794),
#   datetime.timedelta(seconds=612),
#   datetime.timedelta(days=55, seconds=65111),
#   datetime.timedelta(seconds=85938),
#   datetime.timedelta(days=-163, seconds=72236),
#   datetime.timedelta(seconds=26362),
#   datetime.timedelta(seconds=309),
#   datetime.timedelta(days=46, seconds=80791),
#   datetime.timedelta(days=57, seconds=70847),
#   datetime.timedelta(seconds=29794),
#   datetime.timedelta(seconds=612),
#   datetime.timedelta(days=55, seconds=65111),
#   datetime.timedelta(seconds=85938)],
#  16378198: [datetime.timedelta(seconds=2600),
#   datetime.timedelta(seconds=51100),
#   datetime.timedelta(seconds=4204),
#   datetime.timedelta(seconds=561),
#   datetime.timedelta(seconds=57),
#   datetime.timedelta(seconds=221),
#   datetime.timedelta(seconds=21889),
#   datetime.timedelta(seconds=1103),
#   datetime.timedelta(seconds=90)],
#  250983398: [datetime.timedelta(seconds=3698),
#   datetime.timedelta(seconds=4925),
#   datetime.timedelta(seconds=555),
#   datetime.timedelta(seconds=1369),
#   datetime.timedelta(seconds=2878),
#   datetime.timedelta(seconds=6023)],
#  3245648312: [datetime.timedelta(seconds=12432),
#   datetime.timedelta(seconds=3255),
#   datetime.timedelta(days=2, seconds=19775),
#   datetime.timedelta(days=1, seconds=64157),
#   datetime.timedelta(days=14, seconds=30135),
#   datetime.timedelta(days=3, seconds=7735),
#   datetime.timedelta(days=7, seconds=33139),
#   datetime.timedelta(days=1, seconds=45799)],
#  392228721: [datetime.timedelta(seconds=41),
#   datetime.timedelta(seconds=21),
#   datetime.timedelta(seconds=68),
#   datetime.timedelta(days=12, seconds=68983),
#   datetime.timedelta(days=1, seconds=7843),
#   datetime.timedelta(seconds=22),
#   datetime.timedelta(seconds=16),
#   datetime.timedelta(seconds=23)],
#  362075658: [],
#  4499854215: [],
#  2227979517: [datetime.timedelta(seconds=1178),
#   datetime.timedelta(days=3, seconds=74997),
#   datetime.timedelta(seconds=71),
#   datetime.timedelta(days=14, seconds=76446),
#   datetime.timedelta(days=24, seconds=51643),
#   datetime.timedelta(days=1, seconds=39871),
#   datetime.timedelta(seconds=21113),
#   datetime.timedelta(seconds=90)],
#  292920781: [datetime.timedelta(seconds=54174),
#   datetime.timedelta(seconds=78030),
#   datetime.timedelta(seconds=8400),
#   datetime.timedelta(seconds=83569),
#   datetime.timedelta(seconds=2832),
#   datetime.timedelta(days=1),
#   datetime.timedelta(days=1),
#   datetime.timedelta(days=1),
#   datetime.timedelta(seconds=86399)],
#  28471026: [datetime.timedelta(seconds=29042),
#   datetime.timedelta(seconds=14),
#   datetime.timedelta(seconds=7),
#   datetime.timedelta(seconds=70189),
#   datetime.timedelta(seconds=36),
#   datetime.timedelta(days=1, seconds=6352),
#   datetime.timedelta(seconds=16854),
#   datetime.timedelta(seconds=2728),
#   datetime.timedelta(seconds=50557)],
#  772315537992916992: [datetime.timedelta(seconds=5),
#   datetime.timedelta(seconds=416),
#   datetime.timedelta(seconds=260),
#   datetime.timedelta(seconds=8),
#   datetime.timedelta(seconds=53),
#   datetime.timedelta(seconds=39),
#   datetime.timedelta(seconds=4),
#   datetime.timedelta(seconds=5)],
#  31139434: [datetime.timedelta(seconds=25842),
#   datetime.timedelta(seconds=6645),
#   datetime.timedelta(seconds=45290),
#   datetime.timedelta(seconds=21899),
#   datetime.timedelta(seconds=77290),
#   datetime.timedelta(seconds=1583),
#   datetime.timedelta(seconds=2868),
#   datetime.timedelta(seconds=24757),
#   datetime.timedelta(seconds=37559)],
#  121389491: [datetime.timedelta(days=7, seconds=62295),
#   datetime.timedelta(seconds=1225),
#   datetime.timedelta(seconds=12415),
#   datetime.timedelta(seconds=1),
#   datetime.timedelta(days=1, seconds=70064),
#   datetime.timedelta(seconds=1),
#   datetime.timedelta(seconds=32908),
#   datetime.timedelta(seconds=83786),
#   datetime.timedelta(seconds=84203)],
#  2370489267: [datetime.timedelta(days=6, seconds=67264),
#   datetime.timedelta(seconds=4061),
#   datetime.timedelta(seconds=178),
#   datetime.timedelta(seconds=10504),
#   datetime.timedelta(seconds=77872),
#   datetime.timedelta(seconds=24434),
#   datetime.timedelta(seconds=9088),
#   datetime.timedelta(seconds=139),
#   datetime.timedelta(days=5, seconds=5944)],
#  120538744: [datetime.timedelta(seconds=20),
#   datetime.timedelta(days=1, seconds=43511),
#   datetime.timedelta(days=1, seconds=48915),
#   datetime.timedelta(seconds=28975),
#   datetime.timedelta(seconds=16512),
#   datetime.timedelta(seconds=627),
#   datetime.timedelta(seconds=9),
#   datetime.timedelta(seconds=73),
#   datetime.timedelta(seconds=38)],
#  410303609: [datetime.timedelta(days=274, seconds=30436),
#   datetime.timedelta(seconds=54),
#   datetime.timedelta(seconds=57),
#   datetime.timedelta(seconds=88),
#   datetime.timedelta(seconds=105),
#   datetime.timedelta(days=35, seconds=22350),
#   datetime.timedelta(days=151, seconds=8760),
#   datetime.timedelta(seconds=124),
#   datetime.timedelta(days=7, seconds=29524)],
#  1210485564: [datetime.timedelta(days=2, seconds=81605),
#   datetime.timedelta(seconds=9142),
#   datetime.timedelta(days=2, seconds=76841),
#   datetime.timedelta(days=8, seconds=1104),
#   datetime.timedelta(seconds=55438),
#   datetime.timedelta(seconds=5960),
#   datetime.timedelta(seconds=24698),
#   datetime.timedelta(days=1, seconds=84428),
#   datetime.timedelta(days=4, seconds=12457)],
#  2334336214: [],
#  897654887974137857: [],
#  16967612: [datetime.timedelta(seconds=1244),
#   datetime.timedelta(seconds=2413),
#   datetime.timedelta(seconds=2283),
#   datetime.timedelta(seconds=41430),
#   datetime.timedelta(seconds=35442),
#   datetime.timedelta(seconds=1699),
#   datetime.timedelta(seconds=2315),
#   datetime.timedelta(seconds=117),
#   datetime.timedelta(seconds=2862)],
#  30603300: [],
#  2157748434: [datetime.timedelta(seconds=127),
#   datetime.timedelta(seconds=54),
#   datetime.timedelta(seconds=11),
#   datetime.timedelta(seconds=26),
#   datetime.timedelta(seconds=36),
#   datetime.timedelta(seconds=73),
#   datetime.timedelta(seconds=69),
#   datetime.timedelta(seconds=44),
#   datetime.timedelta(seconds=11)],
#  17685964: [datetime.timedelta(seconds=16458),
#   datetime.timedelta(seconds=36441),
#   datetime.timedelta(seconds=5521),
#   datetime.timedelta(days=1, seconds=4131),
#   datetime.timedelta(seconds=32),
#   datetime.timedelta(seconds=7313),
#   datetime.timedelta(seconds=79),
#   datetime.timedelta(seconds=49),
#   datetime.timedelta(seconds=4740)],
#  49031917: [datetime.timedelta(days=35, seconds=44028),
#   datetime.timedelta(days=106, seconds=23843),
#   datetime.timedelta(days=2, seconds=8480),
#   datetime.timedelta(seconds=91),
#   datetime.timedelta(days=50, seconds=37969),
#   datetime.timedelta(days=2, seconds=42260),
#   datetime.timedelta(days=1, seconds=38468),
#   datetime.timedelta(days=259, seconds=30318),
#   datetime.timedelta(days=5, seconds=80189)],
#  192608058: [],
#  206795782: [datetime.timedelta(seconds=9410),
#   datetime.timedelta(days=3, seconds=76851),
#   datetime.timedelta(days=1, seconds=39520),
#   datetime.timedelta(seconds=90),
#   datetime.timedelta(seconds=47349),
#   datetime.timedelta(seconds=2892),
#   datetime.timedelta(seconds=81529),
#   datetime.timedelta(seconds=34084),
#   datetime.timedelta(days=1, seconds=405)],
#  818494659873951745: [datetime.timedelta(seconds=106),
#   datetime.timedelta(seconds=111),
#   datetime.timedelta(seconds=38),
#   datetime.timedelta(seconds=798),
#   datetime.timedelta(seconds=54),
#   datetime.timedelta(seconds=57),
#   datetime.timedelta(seconds=452),
#   datetime.timedelta(seconds=122),
#   datetime.timedelta(seconds=222)],
#  892830498350931973: [datetime.timedelta(seconds=556),
#   datetime.timedelta(seconds=439),
#   datetime.timedelta(seconds=714),
#   datetime.timedelta(seconds=502),
#   datetime.timedelta(days=-1, seconds=85184)],
#  2806413827: [datetime.timedelta(seconds=28220),
#   datetime.timedelta(seconds=42271),
#   datetime.timedelta(seconds=82990),
#   datetime.timedelta(days=2, seconds=42273),
#   datetime.timedelta(seconds=888),
#   datetime.timedelta(days=1, seconds=2234),
#   datetime.timedelta(seconds=993),
#   datetime.timedelta(seconds=1542),
#   datetime.timedelta(seconds=380)],
#  54135314: [datetime.timedelta(seconds=199),
#   datetime.timedelta(seconds=1418),
#   datetime.timedelta(seconds=340),
#   datetime.timedelta(seconds=32),
#   datetime.timedelta(seconds=5120),
#   datetime.timedelta(seconds=9104),
#   datetime.timedelta(seconds=75025),
#   datetime.timedelta(days=8, seconds=75887),
#   datetime.timedelta(seconds=29208)],
#  262355899: [datetime.timedelta(days=4, seconds=52102),
#   datetime.timedelta(seconds=71209),
#   datetime.timedelta(days=1, seconds=33261),
#   datetime.timedelta(days=2, seconds=3503),
#   datetime.timedelta(days=2, seconds=80204),
#   datetime.timedelta(days=1, seconds=12818),
#   datetime.timedelta(days=2, seconds=72709),
#   datetime.timedelta(days=1, seconds=7164),
#   datetime.timedelta(days=1, seconds=82465)],
#  899119832922071040: [datetime.timedelta(seconds=37),
#   datetime.timedelta(seconds=152),
#   datetime.timedelta(seconds=72),
#   datetime.timedelta(seconds=3443),
#   datetime.timedelta(seconds=211),
#   datetime.timedelta(seconds=3450),
#   datetime.timedelta(seconds=82),
#   datetime.timedelta(seconds=3154)],
#  66209470: [datetime.timedelta(days=9, seconds=34787),
#   datetime.timedelta(days=1, seconds=8230),
#   datetime.timedelta(days=4, seconds=58705),
#   datetime.timedelta(seconds=76259),
#   datetime.timedelta(days=3, seconds=7350),
#   datetime.timedelta(seconds=12036),
#   datetime.timedelta(seconds=6723),
#   datetime.timedelta(days=2, seconds=84377),
#   datetime.timedelta(days=1, seconds=59872)],
#  237947008: [datetime.timedelta(days=4, seconds=14003),
#   datetime.timedelta(days=3, seconds=66887),
#   datetime.timedelta(seconds=64432),
#   datetime.timedelta(days=5, seconds=41489),
#   datetime.timedelta(days=8, seconds=54218),
#   datetime.timedelta(days=3, seconds=37643),
#   datetime.timedelta(days=4, seconds=61105),
#   datetime.timedelta(days=3, seconds=76772),
#   datetime.timedelta(seconds=61879)],
#  105874636: [datetime.timedelta(seconds=68),
#   datetime.timedelta(seconds=61419),
#   datetime.timedelta(days=2, seconds=81751),
#   datetime.timedelta(days=1, seconds=20660),
#   datetime.timedelta(days=3, seconds=3980),
#   datetime.timedelta(days=6, seconds=68698),
#   datetime.timedelta(days=2, seconds=1243),
#   datetime.timedelta(days=5, seconds=5964),
#   datetime.timedelta(seconds=64003)],
#  15380583: [datetime.timedelta(seconds=881),
#   datetime.timedelta(seconds=1767),
#   datetime.timedelta(seconds=5617)],
#  496493810: [datetime.timedelta(seconds=11407),
#   datetime.timedelta(seconds=2541),
#   datetime.timedelta(seconds=266),
#   datetime.timedelta(seconds=248),
#   datetime.timedelta(seconds=104),
#   datetime.timedelta(seconds=554),
#   datetime.timedelta(seconds=362),
#   datetime.timedelta(seconds=110),
#   datetime.timedelta(seconds=120)],
#  955613694: [datetime.timedelta(seconds=3993),
#   datetime.timedelta(seconds=14),
#   datetime.timedelta(seconds=1263),
#   datetime.timedelta(seconds=5968),
#   datetime.timedelta(seconds=8248)],
#  1425520304: [],
#  242916135: [datetime.timedelta(seconds=26),
#   datetime.timedelta(seconds=32),
#   datetime.timedelta(seconds=21),
#   datetime.timedelta(seconds=1662),
#   datetime.timedelta(seconds=969),
#   datetime.timedelta(seconds=32196),
#   datetime.timedelta(seconds=517),
#   datetime.timedelta(seconds=1958),
#   datetime.timedelta(seconds=35)],
#  1198902685: [],
#  3262306109: [datetime.timedelta(days=386, seconds=61627),
#   datetime.timedelta(seconds=11),
#   datetime.timedelta(seconds=3066),
#   datetime.timedelta(days=189, seconds=29208),
#   datetime.timedelta(days=26, seconds=65235),
#   datetime.timedelta(seconds=1509),
#   datetime.timedelta(days=1, seconds=25516),
#   datetime.timedelta(days=3, seconds=1159),
#   datetime.timedelta(days=18, seconds=59943)],
#  865213866: [datetime.timedelta(days=8, seconds=41988),
#   datetime.timedelta(days=5, seconds=80757),
#   datetime.timedelta(days=2, seconds=935),
#   datetime.timedelta(days=40, seconds=13553),
#   datetime.timedelta(days=21, seconds=46286)],
#  49717874: [datetime.timedelta(seconds=1937),
#   datetime.timedelta(days=6, seconds=84899),
#   datetime.timedelta(seconds=128),
#   datetime.timedelta(days=7, seconds=56251),
#   datetime.timedelta(seconds=21),
#   datetime.timedelta(seconds=28639),
#   datetime.timedelta(days=6, seconds=82604),
#   datetime.timedelta(days=6, seconds=71243),
#   datetime.timedelta(days=2, seconds=1963)],
#  507975093: [datetime.timedelta(seconds=134),
#   datetime.timedelta(seconds=7792),
#   datetime.timedelta(seconds=828),
#   datetime.timedelta(seconds=459)],
#  319916258: [datetime.timedelta(seconds=33702),
#   datetime.timedelta(days=3, seconds=51915),
#   datetime.timedelta(seconds=363),
#   datetime.timedelta(seconds=5309),
#   datetime.timedelta(seconds=26695),
#   datetime.timedelta(seconds=76481),
#   datetime.timedelta(seconds=666),
#   datetime.timedelta(seconds=11389),
#   datetime.timedelta(days=1, seconds=73087)],
#  33416325: [datetime.timedelta(seconds=89),
#   datetime.timedelta(seconds=123),
#   datetime.timedelta(seconds=91),
#   datetime.timedelta(days=4, seconds=57675),
#   datetime.timedelta(days=33, seconds=78671),
#   datetime.timedelta(days=16, seconds=27370),
#   datetime.timedelta(seconds=63),
#   datetime.timedelta(days=5, seconds=69341),
#   datetime.timedelta(seconds=272)],
#  27055023: [datetime.timedelta(seconds=29486),
#   datetime.timedelta(days=1, seconds=173),
#   datetime.timedelta(seconds=16285),
#   datetime.timedelta(days=3, seconds=60694),
#   datetime.timedelta(seconds=22158),
#   datetime.timedelta(seconds=2626),
#   datetime.timedelta(days=1, seconds=58978),
#   datetime.timedelta(days=3, seconds=31933),
#   datetime.timedelta(seconds=60279)],
#  772201057506164736: [datetime.timedelta(seconds=84),
#   datetime.timedelta(seconds=1098),
#   datetime.timedelta(seconds=1558),
#   datetime.timedelta(seconds=549),
#   datetime.timedelta(seconds=53),
#   datetime.timedelta(seconds=477)],
#  2765054066: [datetime.timedelta(seconds=2803),
#   datetime.timedelta(seconds=2960),
#   datetime.timedelta(seconds=2349),
#   datetime.timedelta(seconds=3608),
#   datetime.timedelta(seconds=3386),
#   datetime.timedelta(seconds=9064)],
#  2557037323: [datetime.timedelta(days=3, seconds=85345),
#   datetime.timedelta(days=7, seconds=1018),
#   datetime.timedelta(days=1, seconds=66184),
#   datetime.timedelta(days=8, seconds=16614),
#   datetime.timedelta(days=2, seconds=76985),
#   datetime.timedelta(days=8, seconds=85222),
#   datetime.timedelta(days=4, seconds=10694),
#   datetime.timedelta(days=2, seconds=2185),
#   datetime.timedelta(days=6, seconds=72899)],
#  3930997512: [datetime.timedelta(days=6, seconds=73093),
#   datetime.timedelta(days=2, seconds=47752),
#   datetime.timedelta(days=16, seconds=39979),
#   datetime.timedelta(seconds=309),
#   datetime.timedelta(days=2, seconds=30904),
#   datetime.timedelta(days=27, seconds=1727),
#   datetime.timedelta(days=33, seconds=54906),
#   datetime.timedelta(seconds=112),
#   datetime.timedelta(seconds=135)],
#  194490327: [datetime.timedelta(seconds=16218),
#   datetime.timedelta(seconds=7193),
#   datetime.timedelta(seconds=12619),
#   datetime.timedelta(seconds=7194),
#   datetime.timedelta(seconds=16184),
#   datetime.timedelta(seconds=185),
#   datetime.timedelta(seconds=7020),
#   datetime.timedelta(seconds=5582),
#   datetime.timedelta(seconds=1622)],
#  8161232: [datetime.timedelta(seconds=81465),
#   datetime.timedelta(days=3, seconds=26519),
#   datetime.timedelta(seconds=18666),
#   datetime.timedelta(seconds=81362),
#   datetime.timedelta(seconds=72873),
#   datetime.timedelta(0),
#   datetime.timedelta(seconds=1),
#   datetime.timedelta(seconds=7883),
#   datetime.timedelta(seconds=80118)],
#  266567089: [datetime.timedelta(days=129, seconds=72338),
#   datetime.timedelta(days=332, seconds=14250),
#   datetime.timedelta(seconds=447),
#   datetime.timedelta(seconds=187)],
#  284265377: [datetime.timedelta(seconds=231),
#   datetime.timedelta(seconds=2515),
#   datetime.timedelta(seconds=11274),
#   datetime.timedelta(seconds=446),
#   datetime.timedelta(seconds=1406),
#   datetime.timedelta(seconds=779),
#   datetime.timedelta(seconds=1442),
#   datetime.timedelta(seconds=1615),
#   datetime.timedelta(seconds=13465)],
#  172028587: [datetime.timedelta(seconds=2985),
#   datetime.timedelta(seconds=62),
#   datetime.timedelta(seconds=17737),
#   datetime.timedelta(seconds=77572),
#   datetime.timedelta(seconds=91),
#   datetime.timedelta(seconds=1978),
#   datetime.timedelta(seconds=4),
#   datetime.timedelta(seconds=4411),
#   datetime.timedelta(seconds=2344)],
#  524229856: [datetime.timedelta(days=149, seconds=84216),
#   datetime.timedelta(days=103, seconds=28971),
#   datetime.timedelta(days=23, seconds=73124),
#   datetime.timedelta(days=716, seconds=83688),
#   datetime.timedelta(seconds=753),
#   datetime.timedelta(seconds=410),
#   datetime.timedelta(seconds=397)],
#  106854148: [],
#  2753102609: [datetime.timedelta(days=19, seconds=58730),
#   datetime.timedelta(days=6, seconds=62351),
#   datetime.timedelta(days=4, seconds=81626),
#   datetime.timedelta(days=1, seconds=49971),
#   datetime.timedelta(days=1, seconds=11042),
#   datetime.timedelta(seconds=107),
#   datetime.timedelta(seconds=34105),
#   datetime.timedelta(seconds=8998),
#   datetime.timedelta(days=264, seconds=76225)],
#  2493362950: [datetime.timedelta(seconds=3531),
#   datetime.timedelta(seconds=1520),
#   datetime.timedelta(seconds=1335),
#   datetime.timedelta(seconds=27),
#   datetime.timedelta(days=2, seconds=11582),
#   datetime.timedelta(seconds=3536),
#   datetime.timedelta(seconds=277),
#   datetime.timedelta(seconds=1717),
#   datetime.timedelta(seconds=33)],
#  2444454050: [datetime.timedelta(seconds=5),
#   datetime.timedelta(days=3, seconds=10880),
#   datetime.timedelta(seconds=71062),
#   datetime.timedelta(seconds=8909),
#   datetime.timedelta(seconds=30205),
#   datetime.timedelta(seconds=4913),
#   datetime.timedelta(seconds=2545),
#   datetime.timedelta(seconds=76),
#   datetime.timedelta(seconds=41)],
#  1353020900: [datetime.timedelta(seconds=28529),
#   datetime.timedelta(seconds=55146),
#   datetime.timedelta(days=5, seconds=5260),
#   datetime.timedelta(days=3, seconds=3085),
#   datetime.timedelta(days=2, seconds=22250),
#   datetime.timedelta(seconds=56235),
#   datetime.timedelta(days=3, seconds=15698),
#   datetime.timedelta(days=4, seconds=3064),
#   datetime.timedelta(days=28, seconds=19652)],
#  997629601: [datetime.timedelta(days=2, seconds=17189),
#   datetime.timedelta(seconds=102),
#   datetime.timedelta(days=8, seconds=81117),
#   datetime.timedelta(days=13, seconds=74953),
#   datetime.timedelta(days=6, seconds=19576),
#   datetime.timedelta(days=10, seconds=58126),
#   datetime.timedelta(days=81, seconds=18280),
#   datetime.timedelta(days=6, seconds=6579),
#   datetime.timedelta(days=5, seconds=3592)],
#  36149861: [datetime.timedelta(days=62, seconds=7702),
#   datetime.timedelta(days=3, seconds=59828),
#   datetime.timedelta(seconds=6287),
#   datetime.timedelta(seconds=220),
#   datetime.timedelta(seconds=53),
#   datetime.timedelta(seconds=1319),
#   datetime.timedelta(seconds=6011)],
#  452695727: [],
#  595227048: [],
#  146962935: [datetime.timedelta(seconds=17731),
#   datetime.timedelta(days=1, seconds=60666),
#   datetime.timedelta(seconds=14557),
#   datetime.timedelta(seconds=44),
#   datetime.timedelta(days=2, seconds=83134),
#   datetime.timedelta(days=3, seconds=50917),
#   datetime.timedelta(seconds=2869),
#   datetime.timedelta(days=3, seconds=46525),
#   datetime.timedelta(days=3, seconds=71082)],
#  2149467889: [],
#  39916645: [datetime.timedelta(days=41, seconds=20136),
#   datetime.timedelta(seconds=5763),
#   datetime.timedelta(days=1, seconds=67879),
#   datetime.timedelta(days=3, seconds=81723),
#   datetime.timedelta(days=2, seconds=13800),
#   datetime.timedelta(seconds=15),
#   datetime.timedelta(days=21, seconds=50646),
#   datetime.timedelta(days=12, seconds=73),
#   datetime.timedelta(days=13, seconds=9965)],
#  185614108: [datetime.timedelta(seconds=198),
#   datetime.timedelta(seconds=440),
#   datetime.timedelta(seconds=4105),
#   datetime.timedelta(seconds=816),
#   datetime.timedelta(seconds=2054),
#   datetime.timedelta(seconds=2571)],
#  96756427: [datetime.timedelta(seconds=521),
#   datetime.timedelta(seconds=7698),
#   datetime.timedelta(seconds=75),
#   datetime.timedelta(seconds=908),
#   datetime.timedelta(seconds=1491),
#   datetime.timedelta(seconds=25701),
#   datetime.timedelta(days=1, seconds=53985),
#   datetime.timedelta(seconds=408),
#   datetime.timedelta(seconds=342)],
#  3304160639: [datetime.timedelta(seconds=4),
#   datetime.timedelta(seconds=310),
#   datetime.timedelta(seconds=705),
#   datetime.timedelta(seconds=10),
#   datetime.timedelta(seconds=23),
#   datetime.timedelta(seconds=4),
#   datetime.timedelta(seconds=215)],
#  262261686: [datetime.timedelta(days=3, seconds=20856),
#   datetime.timedelta(days=1, seconds=54861),
#   datetime.timedelta(days=1, seconds=54379),
#   datetime.timedelta(seconds=37954),
#   datetime.timedelta(seconds=45198),
#   datetime.timedelta(seconds=35366),
#   datetime.timedelta(seconds=2),
#   datetime.timedelta(days=1, seconds=16397),
#   datetime.timedelta(seconds=13)],
#  101022647: [datetime.timedelta(days=756, seconds=20506),
#   datetime.timedelta(days=3, seconds=64355),
#   datetime.timedelta(days=626, seconds=40284),
#   datetime.timedelta(seconds=5311),
#   datetime.timedelta(seconds=2372),
#   datetime.timedelta(seconds=11001),
#   datetime.timedelta(seconds=1997),
#   datetime.timedelta(seconds=3243)],
#  211951322: [],
#  65957347: [datetime.timedelta(days=4, seconds=73473),
#   datetime.timedelta(days=1, seconds=83305),
#   datetime.timedelta(seconds=22078),
#   datetime.timedelta(seconds=74780),
#   datetime.timedelta(seconds=82281),
#   datetime.timedelta(days=1, seconds=9549),
#   datetime.timedelta(days=44, seconds=50189),
#   datetime.timedelta(days=7, seconds=40432),
#   datetime.timedelta(days=14, seconds=76864)],
#  130557513: [datetime.timedelta(seconds=54),
#   datetime.timedelta(seconds=4139),
#   datetime.timedelta(seconds=52),
#   datetime.timedelta(seconds=7417),
#   datetime.timedelta(seconds=203),
#   datetime.timedelta(seconds=56),
#   datetime.timedelta(seconds=75),
#   datetime.timedelta(seconds=49),
#   datetime.timedelta(seconds=483)],
#  3048406794: [datetime.timedelta(seconds=181),
#   datetime.timedelta(days=73, seconds=23642),
#   datetime.timedelta(seconds=327),
#   datetime.timedelta(days=1, seconds=48032),
#   datetime.timedelta(seconds=62),
#   datetime.timedelta(days=16, seconds=11117)],
#  768505022: [datetime.timedelta(seconds=4069),
#   datetime.timedelta(seconds=4990),
#   datetime.timedelta(seconds=1510),
#   datetime.timedelta(seconds=929),
#   datetime.timedelta(seconds=6800),
#   datetime.timedelta(seconds=11029),
#   datetime.timedelta(seconds=2986)],
#  434968527: [],
#  27744185: [datetime.timedelta(days=100, seconds=82307),
#   datetime.timedelta(days=65, seconds=83304),
#   datetime.timedelta(days=16, seconds=14487),
#   datetime.timedelta(days=86, seconds=72609),
#   datetime.timedelta(days=1, seconds=11896),
#   datetime.timedelta(seconds=73178),
#   datetime.timedelta(days=55, seconds=13536),
#   datetime.timedelta(days=1, seconds=75524),
#   datetime.timedelta(0)],
#  444084726: [datetime.timedelta(days=945, seconds=74460),
#   datetime.timedelta(days=155, seconds=15777),
#   datetime.timedelta(days=106, seconds=65336),
#   datetime.timedelta(days=146, seconds=18038),
#   datetime.timedelta(days=33, seconds=44703),
#   datetime.timedelta(days=13, seconds=54097),
#   datetime.timedelta(days=10, seconds=57935),
#   datetime.timedelta(days=3, seconds=17587)],
#  24636191: [datetime.timedelta(days=1, seconds=66482),
#   datetime.timedelta(days=2, seconds=13590),
#   datetime.timedelta(seconds=72),
#   datetime.timedelta(days=1, seconds=81671),
#   datetime.timedelta(days=4, seconds=68287),
#   datetime.timedelta(seconds=18208),
#   datetime.timedelta(days=1, seconds=68554),
#   datetime.timedelta(seconds=469),
#   datetime.timedelta(days=3, seconds=24988)],
#  31583882: [datetime.timedelta(seconds=9663),
#   datetime.timedelta(seconds=5229),
#   datetime.timedelta(seconds=4037),
#   datetime.timedelta(seconds=5038),
#   datetime.timedelta(0),
#   datetime.timedelta(seconds=906),
#   datetime.timedelta(seconds=284),
#   datetime.timedelta(seconds=2474),
#   datetime.timedelta(seconds=4134)],
#  44511572: [datetime.timedelta(days=1, seconds=10046),
#   datetime.timedelta(seconds=46211),
#   datetime.timedelta(seconds=32079),
#   datetime.timedelta(seconds=2133),
#   datetime.timedelta(days=1, seconds=5431),
#   datetime.timedelta(seconds=1264),
#   datetime.timedelta(seconds=7303),
#   datetime.timedelta(days=3, seconds=76380),
#   datetime.timedelta(seconds=9945)],
#  14200130: [datetime.timedelta(seconds=699),
#   datetime.timedelta(seconds=56850),
#   datetime.timedelta(seconds=6353),
#   datetime.timedelta(seconds=62851),
#   datetime.timedelta(days=1, seconds=2848),
#   datetime.timedelta(days=2, seconds=19007),
#   datetime.timedelta(seconds=686),
#   datetime.timedelta(seconds=143),
#   datetime.timedelta(seconds=1289)],
#  899210773: [datetime.timedelta(seconds=125),
#   datetime.timedelta(days=554, seconds=57760),
#   datetime.timedelta(days=17, seconds=26752),
#   datetime.timedelta(days=64, seconds=43182),
#   datetime.timedelta(days=109, seconds=8432),
#   datetime.timedelta(days=7, seconds=7855),
#   datetime.timedelta(days=7, seconds=78587),
#   datetime.timedelta(seconds=12792),
#   datetime.timedelta(days=18, seconds=38968)],
#  331613467: [datetime.timedelta(days=1, seconds=2164),
#   datetime.timedelta(days=3, seconds=81372),
#   datetime.timedelta(seconds=98),
#   datetime.timedelta(days=17, seconds=19030),
#   datetime.timedelta(days=3, seconds=80545),
#   datetime.timedelta(seconds=13),
#   datetime.timedelta(seconds=22364),
#   datetime.timedelta(seconds=218),
#   datetime.timedelta(days=72, seconds=51934)],
#  33880658: [datetime.timedelta(days=565, seconds=65963),
#   datetime.timedelta(days=136, seconds=58550),
#   datetime.timedelta(seconds=23670),
#   datetime.timedelta(seconds=653),
#   datetime.timedelta(seconds=30248),
#   datetime.timedelta(seconds=5948),
#   datetime.timedelta(seconds=30446),
#   datetime.timedelta(seconds=360),
#   datetime.timedelta(seconds=54)],
#  1006904365016330245: [],
#  62318705: [datetime.timedelta(days=1, seconds=629),
#   datetime.timedelta(seconds=53634),
#   datetime.timedelta(days=3, seconds=35488),
#   datetime.timedelta(days=15, seconds=44074),
#   datetime.timedelta(days=8, seconds=33933),
#   datetime.timedelta(days=9, seconds=32494),
#   datetime.timedelta(days=1, seconds=48275),
#   datetime.timedelta(seconds=74432),
#   datetime.timedelta(days=7, seconds=75382)],
#  227771924: [datetime.timedelta(days=13, seconds=26602),
#   datetime.timedelta(days=1, seconds=20392),
#   datetime.timedelta(days=9, seconds=69896),
#   datetime.timedelta(days=23, seconds=45580),
#   datetime.timedelta(days=1, seconds=1157),
#   datetime.timedelta(seconds=78323),
#   datetime.timedelta(seconds=72287),
#   datetime.timedelta(days=2, seconds=63583),
#   datetime.timedelta(days=18, seconds=29385)],
#  365297032: [datetime.timedelta(days=6, seconds=12611),
#   datetime.timedelta(days=16, seconds=81436),
#   datetime.timedelta(days=22, seconds=25880),
#   datetime.timedelta(days=21, seconds=30860),
#   datetime.timedelta(days=34, seconds=83432),
#   datetime.timedelta(days=47, seconds=41968),
#   datetime.timedelta(seconds=2),
#   datetime.timedelta(seconds=12130),
#   datetime.timedelta(days=3, seconds=11582)],
#  1355634794: [datetime.timedelta(seconds=1916),
#   datetime.timedelta(seconds=4877),
#   datetime.timedelta(seconds=853),
#   datetime.timedelta(seconds=11462),
#   datetime.timedelta(seconds=7495),
#   datetime.timedelta(seconds=697),
#   datetime.timedelta(seconds=2372)],
#  549680454: [datetime.timedelta(days=5, seconds=68233),
#   datetime.timedelta(seconds=21613),
#   datetime.timedelta(seconds=19),
#   datetime.timedelta(seconds=1329),
#   datetime.timedelta(seconds=54416),
#   datetime.timedelta(days=83, seconds=69508),
#   datetime.timedelta(seconds=12665)],
#  206811711: [datetime.timedelta(seconds=14092),
#   datetime.timedelta(seconds=9151),
#   datetime.timedelta(seconds=5107),
#   datetime.timedelta(seconds=1415),
#   datetime.timedelta(seconds=59270),
#   datetime.timedelta(seconds=29),
#   datetime.timedelta(seconds=34),
#   datetime.timedelta(seconds=1732),
#   datetime.timedelta(seconds=670)],
#  301218888: [datetime.timedelta(seconds=36),
#   datetime.timedelta(seconds=26),
#   datetime.timedelta(days=1, seconds=85350),
#   datetime.timedelta(seconds=16),
#   datetime.timedelta(days=2, seconds=2287),
#   datetime.timedelta(seconds=17),
#   datetime.timedelta(days=2, seconds=29843),
#   datetime.timedelta(days=1, seconds=77956),
#   datetime.timedelta(seconds=25)],
#  2204874359: [datetime.timedelta(seconds=170),
#   datetime.timedelta(seconds=876),
#   datetime.timedelta(seconds=72),
#   datetime.timedelta(seconds=30),
#   datetime.timedelta(seconds=89),
#   datetime.timedelta(seconds=172),
#   datetime.timedelta(seconds=59),
#   datetime.timedelta(seconds=8),
#   datetime.timedelta(seconds=288)],
#  434986912: [datetime.timedelta(seconds=331),
#   datetime.timedelta(seconds=7137),
#   datetime.timedelta(seconds=792)],
#  1094153152389992449: [datetime.timedelta(seconds=43208),
#   datetime.timedelta(seconds=86395),
#   datetime.timedelta(seconds=43186),
#   datetime.timedelta(seconds=43215),
#   datetime.timedelta(seconds=43200),
#   datetime.timedelta(seconds=86394),
#   datetime.timedelta(seconds=43206),
#   datetime.timedelta(seconds=43191),
#   datetime.timedelta(seconds=43209)],
#  834554303176138752: [datetime.timedelta(seconds=136),
#   datetime.timedelta(seconds=1538),
#   datetime.timedelta(seconds=420),
#   datetime.timedelta(seconds=52),
#   datetime.timedelta(seconds=505)],
#  2545978907: [datetime.timedelta(days=72, seconds=8011),
#   datetime.timedelta(days=13, seconds=19953),
#   datetime.timedelta(days=7, seconds=51102),
#   datetime.timedelta(days=4, seconds=34049),
#   datetime.timedelta(days=8, seconds=2400),
#   datetime.timedelta(days=26, seconds=83378),
#   datetime.timedelta(days=6, seconds=78131),
#   datetime.timedelta(seconds=8968)],
#  155561448: [datetime.timedelta(seconds=71),
#   datetime.timedelta(days=11, seconds=27446),
#   datetime.timedelta(days=1, seconds=29452),
#   datetime.timedelta(seconds=39223),
#   datetime.timedelta(days=6, seconds=12007),
#   datetime.timedelta(days=4, seconds=40316),
#   datetime.timedelta(seconds=5143),
#   datetime.timedelta(days=3, seconds=54993),
#   datetime.timedelta(days=1, seconds=41051)],
#  22316967: [datetime.timedelta(days=48, seconds=73649),
#   datetime.timedelta(seconds=2528),
#   datetime.timedelta(seconds=759),
#   datetime.timedelta(seconds=2580),
#   datetime.timedelta(seconds=1617)],
#  1016379415205482496: [datetime.timedelta(days=3, seconds=65177),
#   datetime.timedelta(days=1, seconds=86026),
#   datetime.timedelta(seconds=8985),
#   datetime.timedelta(seconds=3751),
#   datetime.timedelta(seconds=1696),
#   datetime.timedelta(seconds=2028),
#   datetime.timedelta(seconds=3702),
#   datetime.timedelta(days=1, seconds=57553),
#   datetime.timedelta(seconds=24683)],
#  370693222: [datetime.timedelta(days=211, seconds=83850),
#   datetime.timedelta(days=28, seconds=61809),
#   datetime.timedelta(days=16, seconds=79984),
#   datetime.timedelta(days=4, seconds=8189),
#   datetime.timedelta(days=2, seconds=29234),
#   datetime.timedelta(days=10, seconds=53690),
#   datetime.timedelta(days=5, seconds=2299),
#   datetime.timedelta(days=1, seconds=81758),
#   datetime.timedelta(days=2, seconds=13210)],
#  21741551: [datetime.timedelta(seconds=238),
#   datetime.timedelta(days=1, seconds=48988),
#   datetime.timedelta(days=2, seconds=68883),
#   datetime.timedelta(seconds=12356),
#   datetime.timedelta(days=2, seconds=77996),
#   datetime.timedelta(seconds=66),
#   datetime.timedelta(seconds=76),
#   datetime.timedelta(seconds=8713),
#   datetime.timedelta(seconds=9760)],
#  956522994: [datetime.timedelta(seconds=1121),
#   datetime.timedelta(seconds=448),
#   datetime.timedelta(seconds=44),
#   datetime.timedelta(seconds=11),
#   datetime.timedelta(seconds=78613),
#   datetime.timedelta(seconds=849),
#   datetime.timedelta(seconds=3244),
#   datetime.timedelta(seconds=1717)],
#  877329307005100032: [datetime.timedelta(seconds=5),
#   datetime.timedelta(seconds=39),
#   datetime.timedelta(seconds=6),
#   datetime.timedelta(seconds=155),
#   datetime.timedelta(seconds=11),
#   datetime.timedelta(seconds=10)],
#  98487400: [],
#  321799506: [datetime.timedelta(seconds=41),
#   datetime.timedelta(days=9, seconds=16611),
#   datetime.timedelta(days=1, seconds=68056),
#   datetime.timedelta(seconds=3838),
#   datetime.timedelta(days=20, seconds=11894),
#   datetime.timedelta(seconds=94),
#   datetime.timedelta(days=46, seconds=183),
#   datetime.timedelta(seconds=39793),
#   datetime.timedelta(days=30, seconds=52689)],
#  1244372887: [datetime.timedelta(seconds=365),
#   datetime.timedelta(seconds=12),
#   datetime.timedelta(seconds=98),
#   datetime.timedelta(seconds=25),
#   datetime.timedelta(seconds=65),
#   datetime.timedelta(seconds=67),
#   datetime.timedelta(seconds=264),
#   datetime.timedelta(seconds=16328),
#   datetime.timedelta(seconds=84)],
#  4766492432: [datetime.timedelta(seconds=6707),
#   datetime.timedelta(seconds=6125),
#   datetime.timedelta(seconds=31),
#   datetime.timedelta(seconds=11860),
#   datetime.timedelta(seconds=75),
#   datetime.timedelta(seconds=7),
#   datetime.timedelta(seconds=3765),
#   datetime.timedelta(seconds=1753),
#   datetime.timedelta(seconds=151)],
#  365090932: [datetime.timedelta(seconds=18313),
#   datetime.timedelta(seconds=7540),
#   datetime.timedelta(seconds=3),
#   datetime.timedelta(seconds=2561),
#   datetime.timedelta(seconds=149),
#   datetime.timedelta(seconds=538),
#   datetime.timedelta(days=1, seconds=84968),
#   datetime.timedelta(days=3, seconds=2319),
#   datetime.timedelta(seconds=83753)],
#  1062421026: [],
#  3020078978: [datetime.timedelta(seconds=620),
#   datetime.timedelta(seconds=500),
#   datetime.timedelta(seconds=6348),
#   datetime.timedelta(seconds=376)],
#  1030207566628970496: [],
#  761296330903916545: [datetime.timedelta(seconds=171),
#   datetime.timedelta(seconds=1249),
#   datetime.timedelta(seconds=407),
#   datetime.timedelta(seconds=103),
#   datetime.timedelta(seconds=3887),
#   datetime.timedelta(seconds=642),
#   datetime.timedelta(seconds=9182),
#   datetime.timedelta(seconds=3968),
#   datetime.timedelta(seconds=41257),
#   datetime.timedelta(days=8, seconds=4109),
#   datetime.timedelta(seconds=28),
#   datetime.timedelta(seconds=5986),
#   datetime.timedelta(seconds=4171),
#   datetime.timedelta(seconds=3599),
#   datetime.timedelta(seconds=1749),
#   datetime.timedelta(seconds=2221),
#   datetime.timedelta(seconds=3982),
#   datetime.timedelta(seconds=690),
#   datetime.timedelta(seconds=289)],
#  289019369: [datetime.timedelta(seconds=17052),
#   datetime.timedelta(seconds=1773),
#   datetime.timedelta(seconds=4784),
#   datetime.timedelta(seconds=2382),
#   datetime.timedelta(seconds=4535),
#   datetime.timedelta(seconds=40185),
#   datetime.timedelta(seconds=16),
#   datetime.timedelta(seconds=164),
#   datetime.timedelta(seconds=5473)],
#  3320478908: [datetime.timedelta(seconds=82),
#   datetime.timedelta(seconds=183),
#   datetime.timedelta(seconds=100),
#   datetime.timedelta(seconds=672),
#   datetime.timedelta(seconds=98),
#   datetime.timedelta(seconds=353),
#   datetime.timedelta(days=2, seconds=81984),
#   datetime.timedelta(seconds=12),
#   datetime.timedelta(seconds=382)],
#  14348594: [datetime.timedelta(seconds=34),
#   datetime.timedelta(seconds=22873),
#   datetime.timedelta(seconds=2943),
#   datetime.timedelta(seconds=4456),
#   datetime.timedelta(seconds=14728),
#   datetime.timedelta(seconds=2260),
#   datetime.timedelta(seconds=202),
#   datetime.timedelta(seconds=6003),
#   datetime.timedelta(seconds=629)],
#  515297173: [datetime.timedelta(days=4, seconds=8819),
#   datetime.timedelta(days=13, seconds=78633),
#   datetime.timedelta(days=9, seconds=22919),
#   datetime.timedelta(days=2, seconds=42081),
#   datetime.timedelta(seconds=15),
#   datetime.timedelta(seconds=332),
#   datetime.timedelta(seconds=992),
#   datetime.timedelta(days=11, seconds=19206),
#   datetime.timedelta(days=3, seconds=61259)],
#  23201994: [],
#  734492654755577858: [datetime.timedelta(seconds=34161),
#   datetime.timedelta(seconds=25),
#   datetime.timedelta(days=14, seconds=80314),
#   datetime.timedelta(seconds=2682),
#   datetime.timedelta(days=1, seconds=13726),
#   datetime.timedelta(seconds=5),
#   datetime.timedelta(seconds=10),
#   datetime.timedelta(days=6, seconds=50104),
#   datetime.timedelta(days=1, seconds=35736),
#   datetime.timedelta(days=-10, seconds=70537),
#   datetime.timedelta(seconds=2682),
#   datetime.timedelta(days=1, seconds=13726),
#   datetime.timedelta(seconds=15),
#   datetime.timedelta(days=6, seconds=50104),
#   datetime.timedelta(days=1, seconds=35736),
#   datetime.timedelta(days=2, seconds=3188),
#   datetime.timedelta(seconds=638),
#   datetime.timedelta(days=1, seconds=55787)],
#  377542601: [datetime.timedelta(seconds=236),
#   datetime.timedelta(days=29, seconds=82809),
#   datetime.timedelta(days=19, seconds=20063),
#   datetime.timedelta(days=210, seconds=18835),
#   datetime.timedelta(days=24, seconds=59564),
#   datetime.timedelta(days=1192, seconds=81252),
#   datetime.timedelta(days=18, seconds=76052),
#   datetime.timedelta(days=57, seconds=25221),
#   datetime.timedelta(seconds=81)],
#  67336727: [datetime.timedelta(days=131, seconds=28767),
#   datetime.timedelta(seconds=67),
#   datetime.timedelta(seconds=84607),
#   datetime.timedelta(seconds=317),
# ...
#   datetime.timedelta(days=1, seconds=60246),
#   datetime.timedelta(seconds=59711),
#   datetime.timedelta(seconds=18),
#   datetime.timedelta(seconds=77598),
#   datetime.timedelta(seconds=14252)],
#  68042177: [datetime.timedelta(seconds=124),
#   datetime.timedelta(seconds=66),
#   datetime.timedelta(seconds=62),
#   datetime.timedelta(seconds=193),
#   datetime.timedelta(seconds=3593),
#   datetime.timedelta(seconds=4400),
#   datetime.timedelta(seconds=5200),
#   datetime.timedelta(seconds=188),
#   datetime.timedelta(seconds=88)],
#  877492293967773697: [datetime.timedelta(seconds=92),
#   datetime.timedelta(seconds=57),
#   datetime.timedelta(seconds=7298),
#   datetime.timedelta(seconds=199),
#   datetime.timedelta(seconds=15),
#   datetime.timedelta(seconds=61),
#   datetime.timedelta(seconds=26),
#   datetime.timedelta(seconds=99),
#   datetime.timedelta(days=-1, seconds=78553),
#   datetime.timedelta(seconds=92),
#   datetime.timedelta(seconds=57)],
#  490801600: [datetime.timedelta(days=53, seconds=12544),
#   datetime.timedelta(days=69, seconds=12314),
#   datetime.timedelta(days=710, seconds=69548),
#   datetime.timedelta(days=17, seconds=64109),
#   datetime.timedelta(days=10, seconds=23350),
#   datetime.timedelta(days=16, seconds=61560),
#   datetime.timedelta(days=39, seconds=22433),
#   datetime.timedelta(days=11, seconds=8677),
#   datetime.timedelta(days=2, seconds=73073)],
#  1342207069: [],
#  277163970: [datetime.timedelta(days=146, seconds=4369),
#   datetime.timedelta(days=180, seconds=32192),
#   datetime.timedelta(days=86, seconds=61465),
#   datetime.timedelta(days=49, seconds=70017),
#   datetime.timedelta(days=2, seconds=14700),
#   datetime.timedelta(days=36, seconds=14423),
#   datetime.timedelta(days=17, seconds=71426),
#   datetime.timedelta(days=3, seconds=16484),
#   datetime.timedelta(days=15, seconds=58999)],
#  1027986648947150848: [datetime.timedelta(days=3, seconds=64049),
#   datetime.timedelta(seconds=238),
#   datetime.timedelta(seconds=230),
#   datetime.timedelta(seconds=72),
#   datetime.timedelta(seconds=50),
#   datetime.timedelta(seconds=123),
#   datetime.timedelta(seconds=105),
#   datetime.timedelta(seconds=68),
#   datetime.timedelta(days=7, seconds=37964)],
#  2309880170: [datetime.timedelta(seconds=904),
#   datetime.timedelta(seconds=416),
#   datetime.timedelta(seconds=671),
#   datetime.timedelta(seconds=57),
#   datetime.timedelta(seconds=2687),
#   datetime.timedelta(seconds=323),
#   datetime.timedelta(seconds=60),
#   datetime.timedelta(seconds=22),
#   datetime.timedelta(seconds=59)],
#  376012638: [datetime.timedelta(days=5, seconds=8004),
#   datetime.timedelta(days=1, seconds=75939),
#   datetime.timedelta(days=2, seconds=56539),
#   datetime.timedelta(days=10, seconds=7583),
#   datetime.timedelta(days=1, seconds=43410),
#   datetime.timedelta(days=6, seconds=38557),
#   datetime.timedelta(days=7, seconds=78015),
#   datetime.timedelta(days=4, seconds=67008),
#   datetime.timedelta(days=6, seconds=67478)],
#  1714082910: [datetime.timedelta(seconds=4),
#   datetime.timedelta(days=8, seconds=14638),
#   datetime.timedelta(seconds=23),
#   datetime.timedelta(days=19, seconds=31992),
#   datetime.timedelta(seconds=12),
#   datetime.timedelta(seconds=40),
#   datetime.timedelta(days=3, seconds=28297),
#   datetime.timedelta(days=39, seconds=56687),
#   datetime.timedelta(days=7, seconds=4045)],
#  865887312407822336: [datetime.timedelta(seconds=509),
#   datetime.timedelta(days=74, seconds=45866),
#   datetime.timedelta(days=43, seconds=47531),
#   datetime.timedelta(days=8, seconds=82455),
#   datetime.timedelta(days=8, seconds=47354),
#   datetime.timedelta(days=7, seconds=48735),
#   datetime.timedelta(days=7, seconds=45175),
#   datetime.timedelta(days=1, seconds=3771)],
#  74795417: [datetime.timedelta(days=86, seconds=73169),
#   datetime.timedelta(days=14, seconds=73939),
#   datetime.timedelta(0),
#   datetime.timedelta(days=4, seconds=7767),
#   datetime.timedelta(seconds=43),
#   datetime.timedelta(seconds=41),
#   datetime.timedelta(seconds=74),
#   datetime.timedelta(seconds=70894),
#   datetime.timedelta(seconds=6)],
#  620708877: [datetime.timedelta(days=25, seconds=16565),
#   datetime.timedelta(days=5, seconds=12331),
#   datetime.timedelta(seconds=21),
#   datetime.timedelta(seconds=27),
#   datetime.timedelta(seconds=19),
#   datetime.timedelta(seconds=22),
#   datetime.timedelta(seconds=22),
#   datetime.timedelta(seconds=19),
#   datetime.timedelta(seconds=25)],
#  852562204607913984: [datetime.timedelta(seconds=9356),
#   datetime.timedelta(seconds=1360),
#   datetime.timedelta(seconds=909),
#   datetime.timedelta(seconds=290),
#   datetime.timedelta(seconds=8500),
#   datetime.timedelta(seconds=1565),
#   datetime.timedelta(seconds=2634),
#   datetime.timedelta(seconds=6021)],
#  2332583791: [datetime.timedelta(days=3, seconds=57701),
#   datetime.timedelta(seconds=21),
#   datetime.timedelta(days=10, seconds=18699),
#   datetime.timedelta(seconds=10),
#   datetime.timedelta(seconds=533),
#   datetime.timedelta(seconds=55),
#   datetime.timedelta(seconds=83),
#   datetime.timedelta(seconds=27),
#   datetime.timedelta(seconds=81)],
#  72131142: [datetime.timedelta(seconds=40179),
#   datetime.timedelta(seconds=5525),
#   datetime.timedelta(seconds=270),
#   datetime.timedelta(seconds=60),
#   datetime.timedelta(seconds=160),
#   datetime.timedelta(seconds=137),
#   datetime.timedelta(seconds=225),
#   datetime.timedelta(seconds=1933),
#   datetime.timedelta(seconds=207)],
#  1144796250: [],
#  1661404440: [datetime.timedelta(seconds=3161),
#   datetime.timedelta(seconds=22),
#   datetime.timedelta(seconds=44),
#   datetime.timedelta(seconds=43),
#   datetime.timedelta(seconds=190),
#   datetime.timedelta(seconds=2544),
#   datetime.timedelta(seconds=12384),
#   datetime.timedelta(seconds=2965),
#   datetime.timedelta(seconds=438)],
#  312751823: [datetime.timedelta(seconds=16),
#   datetime.timedelta(seconds=6246),
#   datetime.timedelta(seconds=26983),
#   datetime.timedelta(seconds=75),
#   datetime.timedelta(seconds=29044),
#   datetime.timedelta(days=1, seconds=13489),
#   datetime.timedelta(seconds=1300),
#   datetime.timedelta(seconds=398),
#   datetime.timedelta(seconds=13946)],
#  14312300: [],
#  57858524: [datetime.timedelta(seconds=422),
#   datetime.timedelta(seconds=2419),
#   datetime.timedelta(seconds=2576),
#   datetime.timedelta(seconds=659)],
#  62915097: [datetime.timedelta(seconds=690),
#   datetime.timedelta(seconds=168),
#   datetime.timedelta(seconds=394),
#   datetime.timedelta(seconds=65008),
#   datetime.timedelta(seconds=67),
#   datetime.timedelta(seconds=303),
#   datetime.timedelta(seconds=36),
#   datetime.timedelta(seconds=224),
#   datetime.timedelta(seconds=116)],
#  840642788: [datetime.timedelta(days=10, seconds=86330),
#   datetime.timedelta(days=2, seconds=86393),
#   datetime.timedelta(days=17, seconds=86314),
#   datetime.timedelta(days=17, seconds=86106),
#   datetime.timedelta(days=2, seconds=86231),
#   datetime.timedelta(days=42, seconds=7),
#   datetime.timedelta(days=12, seconds=770),
#   datetime.timedelta(days=1, seconds=86084),
#   datetime.timedelta(days=3, seconds=86370)],
#  1877152158: [datetime.timedelta(days=3, seconds=56554),
#   datetime.timedelta(days=23, seconds=44574),
#   datetime.timedelta(seconds=47583),
#   datetime.timedelta(days=9, seconds=32287),
#   datetime.timedelta(days=8, seconds=59826),
#   datetime.timedelta(seconds=459),
#   datetime.timedelta(days=5, seconds=82160)],
#  15146558: [datetime.timedelta(seconds=15),
#   datetime.timedelta(seconds=7378),
#   datetime.timedelta(seconds=5622),
#   datetime.timedelta(seconds=14826),
#   datetime.timedelta(seconds=50806),
#   datetime.timedelta(seconds=233),
#   datetime.timedelta(seconds=15856),
#   datetime.timedelta(seconds=1786),
#   datetime.timedelta(seconds=9734)],
#  1909134048: [datetime.timedelta(days=77, seconds=30066),
#   datetime.timedelta(days=4, seconds=84245),
#   datetime.timedelta(days=7, seconds=63044),
#   datetime.timedelta(days=93, seconds=19809),
#   datetime.timedelta(days=6, seconds=14146),
#   datetime.timedelta(days=3, seconds=8402),
#   datetime.timedelta(seconds=1457),
#   datetime.timedelta(days=1, seconds=75657),
#   datetime.timedelta(days=1, seconds=4223)],
#  283068083: [datetime.timedelta(seconds=81255),
#   datetime.timedelta(days=1, seconds=5789),
#   datetime.timedelta(seconds=232),
#   datetime.timedelta(seconds=50),
#   datetime.timedelta(seconds=23),
#   datetime.timedelta(seconds=21),
#   datetime.timedelta(seconds=5226),
#   datetime.timedelta(seconds=162),
#   datetime.timedelta(seconds=70)],
#  44551682: [datetime.timedelta(seconds=53),
#   datetime.timedelta(seconds=35),
#   datetime.timedelta(seconds=52),
#   datetime.timedelta(seconds=29),
#   datetime.timedelta(seconds=9218),
#   datetime.timedelta(seconds=69),
#   datetime.timedelta(seconds=10946),
#   datetime.timedelta(seconds=31),
#   datetime.timedelta(seconds=76406)],
#  436366250: [datetime.timedelta(seconds=1958),
#   datetime.timedelta(seconds=3750),
#   datetime.timedelta(seconds=6260),
#   datetime.timedelta(seconds=1961),
#   datetime.timedelta(seconds=1618),
#   datetime.timedelta(seconds=300),
#   datetime.timedelta(seconds=1042),
#   datetime.timedelta(seconds=22476),
#   datetime.timedelta(seconds=46825)],
#  238503376: [datetime.timedelta(seconds=927),
#   datetime.timedelta(seconds=3773),
#   datetime.timedelta(seconds=1166),
#   datetime.timedelta(seconds=6118),
#   datetime.timedelta(seconds=9870),
#   datetime.timedelta(seconds=4715),
#   datetime.timedelta(seconds=6476)],
#  315476130: [datetime.timedelta(days=3, seconds=54614),
#   datetime.timedelta(days=35, seconds=2088),
#   datetime.timedelta(days=965, seconds=29818),
#   datetime.timedelta(seconds=104),
#   datetime.timedelta(seconds=78190),
#   datetime.timedelta(days=13, seconds=4963),
#   datetime.timedelta(days=1, seconds=69495),
#   datetime.timedelta(seconds=4),
#   datetime.timedelta(days=41, seconds=25480)],
#  775162575420002306: [datetime.timedelta(seconds=6588),
#   datetime.timedelta(seconds=7672),
#   datetime.timedelta(seconds=399),
#   datetime.timedelta(seconds=1845),
#   datetime.timedelta(seconds=25479),
#   datetime.timedelta(seconds=3291),
#   datetime.timedelta(seconds=60499),
#   datetime.timedelta(seconds=8500),
#   datetime.timedelta(seconds=10838),
#   datetime.timedelta(days=6, seconds=40590),
#   datetime.timedelta(seconds=142),
#   datetime.timedelta(seconds=4),
#   datetime.timedelta(seconds=315),
#   datetime.timedelta(seconds=386),
#   datetime.timedelta(seconds=85598),
#   datetime.timedelta(seconds=400),
#   datetime.timedelta(seconds=1215),
#   datetime.timedelta(seconds=59),
#   datetime.timedelta(days=1, seconds=25434)],
#  25068919: [datetime.timedelta(seconds=1223),
#   datetime.timedelta(seconds=30412),
#   datetime.timedelta(seconds=7362),
#   datetime.timedelta(seconds=10374),
#   datetime.timedelta(seconds=40954),
#   datetime.timedelta(seconds=3019),
#   datetime.timedelta(seconds=14057),
#   datetime.timedelta(seconds=15575),
#   datetime.timedelta(seconds=3022)],
#  363852718: [datetime.timedelta(days=3, seconds=9293),
#   datetime.timedelta(seconds=1606),
#   datetime.timedelta(days=8, seconds=20127),
#   datetime.timedelta(days=1, seconds=25231),
#   datetime.timedelta(seconds=109),
#   datetime.timedelta(seconds=2309)],
#  743565374499749888: [],
#  28474662: [datetime.timedelta(days=2, seconds=68951),
#   datetime.timedelta(days=1, seconds=6084),
#   datetime.timedelta(days=4, seconds=8165),
#   datetime.timedelta(days=1, seconds=4907),
#   datetime.timedelta(days=1, seconds=84743),
#   datetime.timedelta(days=1, seconds=77719),
#   datetime.timedelta(days=2, seconds=71214),
#   datetime.timedelta(seconds=25320),
#   datetime.timedelta(seconds=4036)],
#  1698808080: [datetime.timedelta(days=255, seconds=28126),
#   datetime.timedelta(days=12, seconds=6373),
#   datetime.timedelta(days=8, seconds=53867),
#   datetime.timedelta(seconds=47390),
#   datetime.timedelta(days=28, seconds=83748),
#   datetime.timedelta(days=3, seconds=69999),
#   datetime.timedelta(days=9, seconds=65291),
#   datetime.timedelta(days=5, seconds=73250),
#   datetime.timedelta(days=129, seconds=1862)],
#  84114859: [datetime.timedelta(seconds=318),
#   datetime.timedelta(seconds=302),
#   datetime.timedelta(seconds=1094),
#   datetime.timedelta(seconds=154),
#   datetime.timedelta(seconds=26),
#   datetime.timedelta(seconds=85468),
#   datetime.timedelta(seconds=25)],
#  2491336532: [datetime.timedelta(days=1, seconds=76961),
#   datetime.timedelta(seconds=77),
#   datetime.timedelta(seconds=775),
#   datetime.timedelta(seconds=200),
#   datetime.timedelta(seconds=1990),
#   datetime.timedelta(seconds=12),
#   datetime.timedelta(seconds=140)],
#  368549815: [datetime.timedelta(seconds=44),
#   datetime.timedelta(days=1, seconds=14278),
#   datetime.timedelta(days=4, seconds=77775),
#   datetime.timedelta(days=1, seconds=10768),
#   datetime.timedelta(days=1, seconds=84937),
#   datetime.timedelta(days=3, seconds=80900),
#   datetime.timedelta(seconds=45424),
#   datetime.timedelta(seconds=38215),
#   datetime.timedelta(days=1, seconds=3504)],
#  890657462512123904: [datetime.timedelta(seconds=96),
#   datetime.timedelta(seconds=6283),
#   datetime.timedelta(seconds=192),
#   datetime.timedelta(seconds=27),
#   datetime.timedelta(seconds=28)],
#  3924259581: [],
#  951241980859830272: [datetime.timedelta(days=212, seconds=72403),
#   datetime.timedelta(days=7, seconds=180),
#   datetime.timedelta(seconds=63),
#   datetime.timedelta(days=27, seconds=84852),
#   datetime.timedelta(seconds=20),
#   datetime.timedelta(seconds=54),
#   datetime.timedelta(days=2, seconds=9860),
#   datetime.timedelta(days=1, seconds=1503),
#   datetime.timedelta(seconds=1)],
#  229030007: [datetime.timedelta(seconds=18),
#   datetime.timedelta(seconds=27),
#   datetime.timedelta(seconds=17),
#   datetime.timedelta(seconds=306),
#   datetime.timedelta(seconds=22),
#   datetime.timedelta(seconds=109),
#   datetime.timedelta(seconds=54),
#   datetime.timedelta(seconds=160)],
#  37355062: [datetime.timedelta(seconds=9120),
#   datetime.timedelta(seconds=1188),
#   datetime.timedelta(days=2, seconds=74726),
#   datetime.timedelta(days=1, seconds=85437),
#   datetime.timedelta(seconds=2452),
#   datetime.timedelta(days=6, seconds=82640),
#   datetime.timedelta(seconds=9040),
#   datetime.timedelta(days=7, seconds=82063),
#   datetime.timedelta(seconds=3210)],
#  2977616300: [datetime.timedelta(seconds=62190),
#   datetime.timedelta(days=8, seconds=9286),
#   datetime.timedelta(seconds=5117),
#   datetime.timedelta(days=14, seconds=76451),
#   datetime.timedelta(days=5, seconds=3532),
#   datetime.timedelta(days=7, seconds=1180),
#   datetime.timedelta(days=21, seconds=24040),
#   datetime.timedelta(seconds=36),
#   datetime.timedelta(seconds=65721)],
#  4111400352: [datetime.timedelta(days=6, seconds=23398),
#   datetime.timedelta(seconds=23040),
#   datetime.timedelta(seconds=176),
#   datetime.timedelta(seconds=2520),
#   datetime.timedelta(seconds=544),
#   datetime.timedelta(seconds=239),
#   datetime.timedelta(seconds=67074)],
#  280986369: [datetime.timedelta(seconds=3600),
#   datetime.timedelta(seconds=3600),
#   datetime.timedelta(seconds=3601),
#   datetime.timedelta(seconds=3599),
#   datetime.timedelta(seconds=3600),
#   datetime.timedelta(seconds=3599),
#   datetime.timedelta(seconds=3601),
#   datetime.timedelta(seconds=3601),
#   datetime.timedelta(seconds=3599)],
#  305763080: [datetime.timedelta(seconds=8521),
#   datetime.timedelta(days=9, seconds=9922),
#   datetime.timedelta(days=4, seconds=68291),
#   datetime.timedelta(seconds=11470),
#   datetime.timedelta(days=2, seconds=62471),
#   datetime.timedelta(seconds=201),
#   datetime.timedelta(seconds=106),
#   datetime.timedelta(days=1, seconds=41674),
#   datetime.timedelta(days=2, seconds=41590)],
#  865479344923197440: [datetime.timedelta(seconds=88),
#   datetime.timedelta(seconds=215),
#   datetime.timedelta(days=4, seconds=190),
#   datetime.timedelta(seconds=131),
#   datetime.timedelta(days=3, seconds=25589),
#   datetime.timedelta(seconds=174),
#   datetime.timedelta(seconds=52),
#   datetime.timedelta(seconds=81),
#   datetime.timedelta(seconds=63)],
#  1643500784: [datetime.timedelta(seconds=125),
#   datetime.timedelta(seconds=121),
#   datetime.timedelta(seconds=49),
#   datetime.timedelta(seconds=29),
#   datetime.timedelta(seconds=1099),
#   datetime.timedelta(seconds=199),
#   datetime.timedelta(seconds=275),
#   datetime.timedelta(seconds=45),
#   datetime.timedelta(seconds=198)],
#  ...}

# %%
posts_deltas1 = {}
for user_id in posts_deltas:
    posts_deltas1[f"{twitter_human_bots_dataset.loc[twitter_human_bots_dataset.id==user_id].account_type.iloc[0]}-{user_id}"] = posts_deltas[user_id]

# %%
(posts_deltas1['bot-53779179'][0]-posts_deltas1['bot-53779179'][1]).total_seconds()
# Out:
# -824192.0

# %%
posts_deltas1['bot-53779179'][1].total_seconds()
# Out:
# 830843.0

# %%
posts_deltas1
# Out:
# {'bot-53779179': [datetime.timedelta(seconds=6651),
#   datetime.timedelta(days=9, seconds=53243),
#   datetime.timedelta(seconds=75964),
#   datetime.timedelta(seconds=257),
#   datetime.timedelta(seconds=10),
#   datetime.timedelta(days=11, seconds=14633),
#   datetime.timedelta(seconds=65210),
#   datetime.timedelta(seconds=6309),
#   datetime.timedelta(seconds=31277)],
#  'human-105916557': [datetime.timedelta(days=16, seconds=5867),
#   datetime.timedelta(seconds=2949),
#   datetime.timedelta(days=3, seconds=73259),
#   datetime.timedelta(days=241, seconds=10771),
#   datetime.timedelta(days=105, seconds=54312),
#   datetime.timedelta(seconds=27),
#   datetime.timedelta(seconds=99),
#   datetime.timedelta(days=5, seconds=24751),
#   datetime.timedelta(days=1, seconds=80028)],
#  'human-509788597': [datetime.timedelta(days=1, seconds=9549),
#   datetime.timedelta(days=7, seconds=50946),
#   datetime.timedelta(seconds=103),
#   datetime.timedelta(days=3, seconds=11546),
#   datetime.timedelta(days=1, seconds=36383),
#   datetime.timedelta(days=11, seconds=50032),
#   datetime.timedelta(seconds=38451),
#   datetime.timedelta(seconds=77304),
#   datetime.timedelta(seconds=61120)],
#  'human-70601327': [datetime.timedelta(days=32, seconds=57550),
#   datetime.timedelta(days=22, seconds=27539),
#   datetime.timedelta(days=35, seconds=70256),
#   datetime.timedelta(days=56, seconds=80044),
#   datetime.timedelta(days=2, seconds=67775),
#   datetime.timedelta(seconds=65355),
#   datetime.timedelta(days=2, seconds=78856),
#   datetime.timedelta(days=1, seconds=35266),
#   datetime.timedelta(days=1, seconds=38143)],
#  'human-108999927': [datetime.timedelta(days=84, seconds=47653),
#   datetime.timedelta(days=16, seconds=71344),
#   datetime.timedelta(days=5, seconds=83881),
#   datetime.timedelta(days=6, seconds=10834),
#   datetime.timedelta(days=90, seconds=4380),
#   datetime.timedelta(seconds=2458),
#   datetime.timedelta(days=61, seconds=4249),
#   datetime.timedelta(days=19, seconds=31070),
#   datetime.timedelta(days=24, seconds=43441)],
#  'bot-875952456060084225': [datetime.timedelta(seconds=21),
#   datetime.timedelta(seconds=42),
#   datetime.timedelta(seconds=3584),
#   datetime.timedelta(seconds=8),
#   datetime.timedelta(seconds=133),
#   datetime.timedelta(seconds=63)],
#  'human-772481473463083009': [datetime.timedelta(seconds=693),
#   datetime.timedelta(seconds=1483),
#   datetime.timedelta(seconds=517),
#   datetime.timedelta(seconds=759),
#   datetime.timedelta(seconds=999),
#   datetime.timedelta(seconds=179),
#   datetime.timedelta(seconds=540)],
#  'human-2391776040': [],
#  'human-602249341': [],
#  'human-155100760': [datetime.timedelta(days=2, seconds=36892),
#   datetime.timedelta(days=1018, seconds=81113),
#   datetime.timedelta(seconds=36),
#   datetime.timedelta(seconds=35),
#   datetime.timedelta(seconds=15),
#   datetime.timedelta(seconds=36),
#   datetime.timedelta(seconds=26),
#   datetime.timedelta(seconds=194)],
#  'human-178218286': [datetime.timedelta(days=29, seconds=69035),
#   datetime.timedelta(days=10, seconds=22578),
#   datetime.timedelta(days=61, seconds=64826),
#   datetime.timedelta(seconds=34),
#   datetime.timedelta(days=46, seconds=70351),
#   datetime.timedelta(days=23, seconds=36150),
#   datetime.timedelta(days=22, seconds=8696),
#   datetime.timedelta(days=16, seconds=64732),
#   datetime.timedelta(days=12, seconds=72058)],
#  'bot-4408686088': [],
#  'bot-99847971': [datetime.timedelta(seconds=1470),
#   datetime.timedelta(days=222, seconds=12060),
#   datetime.timedelta(days=689, seconds=70289),
#   datetime.timedelta(days=194, seconds=26932),
#   datetime.timedelta(days=12, seconds=74657),
#   datetime.timedelta(days=152, seconds=77623),
#   datetime.timedelta(days=14, seconds=37056)],
#  'human-1063034450': [datetime.timedelta(days=239, seconds=78189),
#   datetime.timedelta(days=44, seconds=80886),
#   datetime.timedelta(seconds=41),
#   datetime.timedelta(days=31, seconds=58816),
#   datetime.timedelta(days=20, seconds=1230),
#   datetime.timedelta(days=2, seconds=36626),
#   datetime.timedelta(days=11, seconds=85209),
#   datetime.timedelta(days=2, seconds=6479),
#   datetime.timedelta(days=1, seconds=64838)],
#  'bot-963263894': [datetime.timedelta(seconds=1059),
#   datetime.timedelta(seconds=3107),
#   datetime.timedelta(seconds=2862),
#   datetime.timedelta(seconds=1641)],
#  'bot-537500546': [datetime.timedelta(seconds=3172),
#   datetime.timedelta(seconds=1123),
#   datetime.timedelta(seconds=12155),
#   datetime.timedelta(seconds=4689),
#   datetime.timedelta(seconds=2707),
#   datetime.timedelta(seconds=2067)],
#  'human-569581750': [datetime.timedelta(seconds=64191),
#   datetime.timedelta(days=1, seconds=39495),
#   datetime.timedelta(days=9, seconds=76518),
#   datetime.timedelta(seconds=74756),
#   datetime.timedelta(days=2, seconds=13393),
#   datetime.timedelta(days=3, seconds=78515),
#   datetime.timedelta(days=1, seconds=15978),
#   datetime.timedelta(days=5, seconds=72919),
#   datetime.timedelta(days=4, seconds=21919)],
#  'human-155568211': [datetime.timedelta(seconds=10994),
#   datetime.timedelta(seconds=36606),
#   datetime.timedelta(seconds=14143),
#   datetime.timedelta(seconds=19),
#   datetime.timedelta(seconds=14505),
#   datetime.timedelta(seconds=5482),
#   datetime.timedelta(seconds=16),
#   datetime.timedelta(seconds=11832),
#   datetime.timedelta(seconds=288)],
#  'bot-877352477280043008': [datetime.timedelta(seconds=8),
#   datetime.timedelta(seconds=64),
#   datetime.timedelta(seconds=17),
#   datetime.timedelta(seconds=22),
#   datetime.timedelta(seconds=77),
#   datetime.timedelta(seconds=45),
#   datetime.timedelta(seconds=7617)],
#  'bot-1449155815': [datetime.timedelta(seconds=205),
#   datetime.timedelta(days=416, seconds=11159),
#   datetime.timedelta(seconds=123),
#   datetime.timedelta(seconds=6),
#   datetime.timedelta(days=19, seconds=67949),
#   datetime.timedelta(seconds=11),
#   datetime.timedelta(seconds=3),
#   datetime.timedelta(seconds=34),
#   datetime.timedelta(seconds=3)],
#  'bot-44051445': [datetime.timedelta(seconds=87),
#   datetime.timedelta(seconds=3772),
#   datetime.timedelta(seconds=55),
#   datetime.timedelta(seconds=5),
#   datetime.timedelta(seconds=45),
#   datetime.timedelta(seconds=95)],
#  'bot-26152058': [datetime.timedelta(days=335, seconds=39687),
#   datetime.timedelta(seconds=32501),
#   datetime.timedelta(days=155, seconds=48028),
#   datetime.timedelta(days=969, seconds=43387),
#   datetime.timedelta(seconds=262),
#   datetime.timedelta(seconds=235),
#   datetime.timedelta(seconds=82),
#   datetime.timedelta(seconds=201),
#   datetime.timedelta(seconds=25)],
#  'bot-3346363073': [datetime.timedelta(seconds=75),
#   datetime.timedelta(seconds=40),
#   datetime.timedelta(seconds=360),
#   datetime.timedelta(seconds=17920),
#   datetime.timedelta(seconds=19),
#   datetime.timedelta(seconds=64),
#   datetime.timedelta(seconds=14822),
#   datetime.timedelta(seconds=14356),
#   datetime.timedelta(seconds=102)],
#  'bot-313116175': [datetime.timedelta(seconds=43),
#   datetime.timedelta(seconds=155),
#   datetime.timedelta(seconds=36),
#   datetime.timedelta(seconds=89),
#   datetime.timedelta(seconds=115),
#   datetime.timedelta(seconds=127)],
#  'bot-3237927257': [datetime.timedelta(days=17, seconds=4087),
#   datetime.timedelta(days=1, seconds=4497),
#   datetime.timedelta(days=25, seconds=73902),
#   datetime.timedelta(days=3, seconds=74108),
#   datetime.timedelta(days=4, seconds=7758),
#   datetime.timedelta(days=1, seconds=10221),
#   datetime.timedelta(seconds=74053),
#   datetime.timedelta(seconds=35),
#   datetime.timedelta(days=2, seconds=31116)],
#  'human-716612819375038464': [datetime.timedelta(seconds=53),
#   datetime.timedelta(seconds=4456)],
#  'human-264700057': [],
#  'human-50885229': [datetime.timedelta(days=6, seconds=82415),
#   datetime.timedelta(days=4, seconds=39752),
#   datetime.timedelta(seconds=1200),
#   datetime.timedelta(days=3, seconds=35011),
#   datetime.timedelta(days=1, seconds=40493),
#   datetime.timedelta(seconds=42589),
#   datetime.timedelta(seconds=10105),
#   datetime.timedelta(days=2, seconds=46503),
#   datetime.timedelta(days=8, seconds=73916)],
#  'human-3327665070': [datetime.timedelta(days=91, seconds=46352),
#   datetime.timedelta(days=72, seconds=8659),
#   datetime.timedelta(days=1, seconds=35991),
#   datetime.timedelta(days=126, seconds=59799),
#   datetime.timedelta(days=103, seconds=694),
#   datetime.timedelta(days=15, seconds=18966),
#   datetime.timedelta(days=7, seconds=85341),
#   datetime.timedelta(seconds=4),
#   datetime.timedelta(seconds=7)],
#  'human-62204119': [datetime.timedelta(seconds=3241),
#   datetime.timedelta(seconds=1543),
#   datetime.timedelta(seconds=184),
#   datetime.timedelta(seconds=4535),
#   datetime.timedelta(seconds=30655),
#   datetime.timedelta(seconds=10971),
#   datetime.timedelta(seconds=95),
#   datetime.timedelta(seconds=922),
#   datetime.timedelta(seconds=1841)],
#  'human-801240960': [],
#  'human-281473975': [datetime.timedelta(seconds=2376),
#   datetime.timedelta(seconds=21015),
#   datetime.timedelta(seconds=277),
#   datetime.timedelta(seconds=5916),
#   datetime.timedelta(seconds=4955),
#   datetime.timedelta(seconds=1954),
#   datetime.timedelta(seconds=2383),
#   datetime.timedelta(seconds=18628),
#   datetime.timedelta(seconds=30066)],
#  'human-488512845': [datetime.timedelta(seconds=4),
#   datetime.timedelta(seconds=82),
#   datetime.timedelta(days=1, seconds=6408),
#   datetime.timedelta(days=2, seconds=11756),
#   datetime.timedelta(seconds=7),
#   datetime.timedelta(days=5, seconds=64141),
#   datetime.timedelta(days=2, seconds=251),
#   datetime.timedelta(seconds=6),
#   datetime.timedelta(seconds=2)],
#  'human-2952010610': [datetime.timedelta(seconds=51378),
#   datetime.timedelta(days=1, seconds=39671),
#   datetime.timedelta(seconds=48421),
#   datetime.timedelta(seconds=79153),
#   datetime.timedelta(days=2, seconds=437),
#   datetime.timedelta(days=1, seconds=80813),
#   datetime.timedelta(days=1, seconds=3098),
#   datetime.timedelta(seconds=8754),
#   datetime.timedelta(days=2, seconds=74267)],
#  'human-169421357': [datetime.timedelta(seconds=1125),
#   datetime.timedelta(days=108, seconds=44609),
#   datetime.timedelta(days=38, seconds=47598),
#   datetime.timedelta(days=215, seconds=38533),
#   datetime.timedelta(days=19, seconds=67273),
#   datetime.timedelta(days=229, seconds=80887),
#   datetime.timedelta(days=6, seconds=7771),
#   datetime.timedelta(days=7, seconds=23761)],
#  'human-33289393': [datetime.timedelta(days=51, seconds=78152),
#   datetime.timedelta(days=32, seconds=11836),
#   datetime.timedelta(days=16, seconds=37552),
#   datetime.timedelta(seconds=32088),
#   datetime.timedelta(days=1, seconds=34035),
#   datetime.timedelta(days=2, seconds=2246),
#   datetime.timedelta(days=7, seconds=71505),
#   datetime.timedelta(days=3, seconds=17826),
#   datetime.timedelta(days=15, seconds=18899)],
#  'human-15998107': [datetime.timedelta(seconds=66),
#   datetime.timedelta(seconds=708),
#   datetime.timedelta(seconds=261),
#   datetime.timedelta(seconds=19212),
#   datetime.timedelta(seconds=29286),
#   datetime.timedelta(seconds=383),
#   datetime.timedelta(seconds=68),
#   datetime.timedelta(seconds=1443),
#   datetime.timedelta(seconds=3042)],
#  'human-138600717': [datetime.timedelta(days=108, seconds=7201),
#   datetime.timedelta(days=6, seconds=75743),
#   datetime.timedelta(seconds=47),
#   datetime.timedelta(days=1, seconds=82843),
#   datetime.timedelta(seconds=1),
#   datetime.timedelta(days=1, seconds=10662),
#   datetime.timedelta(days=3, seconds=2348),
#   datetime.timedelta(seconds=10),
#   datetime.timedelta(days=3, seconds=69546)],
#  'human-709540733456224257': [datetime.timedelta(seconds=26362),
#   datetime.timedelta(seconds=309),
#   datetime.timedelta(days=46, seconds=80791),
#   datetime.timedelta(days=22, seconds=33844),
#   datetime.timedelta(days=35, seconds=37003),
#   datetime.timedelta(seconds=29794),
#   datetime.timedelta(seconds=612),
#   datetime.timedelta(days=55, seconds=65111),
#   datetime.timedelta(seconds=85938),
#   datetime.timedelta(days=-163, seconds=72236),
#   datetime.timedelta(seconds=26362),
#   datetime.timedelta(seconds=309),
#   datetime.timedelta(days=46, seconds=80791),
#   datetime.timedelta(days=57, seconds=70847),
#   datetime.timedelta(seconds=29794),
#   datetime.timedelta(seconds=612),
#   datetime.timedelta(days=55, seconds=65111),
#   datetime.timedelta(seconds=85938)],
#  'human-16378198': [datetime.timedelta(seconds=2600),
#   datetime.timedelta(seconds=51100),
#   datetime.timedelta(seconds=4204),
#   datetime.timedelta(seconds=561),
#   datetime.timedelta(seconds=57),
#   datetime.timedelta(seconds=221),
#   datetime.timedelta(seconds=21889),
#   datetime.timedelta(seconds=1103),
#   datetime.timedelta(seconds=90)],
#  'bot-250983398': [datetime.timedelta(seconds=3698),
#   datetime.timedelta(seconds=4925),
#   datetime.timedelta(seconds=555),
#   datetime.timedelta(seconds=1369),
#   datetime.timedelta(seconds=2878),
#   datetime.timedelta(seconds=6023)],
#  'human-3245648312': [datetime.timedelta(seconds=12432),
#   datetime.timedelta(seconds=3255),
#   datetime.timedelta(days=2, seconds=19775),
#   datetime.timedelta(days=1, seconds=64157),
#   datetime.timedelta(days=14, seconds=30135),
#   datetime.timedelta(days=3, seconds=7735),
#   datetime.timedelta(days=7, seconds=33139),
#   datetime.timedelta(days=1, seconds=45799)],
#  'human-392228721': [datetime.timedelta(seconds=41),
#   datetime.timedelta(seconds=21),
#   datetime.timedelta(seconds=68),
#   datetime.timedelta(days=12, seconds=68983),
#   datetime.timedelta(days=1, seconds=7843),
#   datetime.timedelta(seconds=22),
#   datetime.timedelta(seconds=16),
#   datetime.timedelta(seconds=23)],
#  'human-362075658': [],
#  'bot-4499854215': [],
#  'human-2227979517': [datetime.timedelta(seconds=1178),
#   datetime.timedelta(days=3, seconds=74997),
#   datetime.timedelta(seconds=71),
#   datetime.timedelta(days=14, seconds=76446),
#   datetime.timedelta(days=24, seconds=51643),
#   datetime.timedelta(days=1, seconds=39871),
#   datetime.timedelta(seconds=21113),
#   datetime.timedelta(seconds=90)],
#  'human-292920781': [datetime.timedelta(seconds=54174),
#   datetime.timedelta(seconds=78030),
#   datetime.timedelta(seconds=8400),
#   datetime.timedelta(seconds=83569),
#   datetime.timedelta(seconds=2832),
#   datetime.timedelta(days=1),
#   datetime.timedelta(days=1),
#   datetime.timedelta(days=1),
#   datetime.timedelta(seconds=86399)],
#  'human-28471026': [datetime.timedelta(seconds=29042),
#   datetime.timedelta(seconds=14),
#   datetime.timedelta(seconds=7),
#   datetime.timedelta(seconds=70189),
#   datetime.timedelta(seconds=36),
#   datetime.timedelta(days=1, seconds=6352),
#   datetime.timedelta(seconds=16854),
#   datetime.timedelta(seconds=2728),
#   datetime.timedelta(seconds=50557)],
#  'human-772315537992916992': [datetime.timedelta(seconds=5),
#   datetime.timedelta(seconds=416),
#   datetime.timedelta(seconds=260),
#   datetime.timedelta(seconds=8),
#   datetime.timedelta(seconds=53),
#   datetime.timedelta(seconds=39),
#   datetime.timedelta(seconds=4),
#   datetime.timedelta(seconds=5)],
#  'human-31139434': [datetime.timedelta(seconds=25842),
#   datetime.timedelta(seconds=6645),
#   datetime.timedelta(seconds=45290),
#   datetime.timedelta(seconds=21899),
#   datetime.timedelta(seconds=77290),
#   datetime.timedelta(seconds=1583),
#   datetime.timedelta(seconds=2868),
#   datetime.timedelta(seconds=24757),
#   datetime.timedelta(seconds=37559)],
#  'human-121389491': [datetime.timedelta(days=7, seconds=62295),
#   datetime.timedelta(seconds=1225),
#   datetime.timedelta(seconds=12415),
#   datetime.timedelta(seconds=1),
#   datetime.timedelta(days=1, seconds=70064),
#   datetime.timedelta(seconds=1),
#   datetime.timedelta(seconds=32908),
#   datetime.timedelta(seconds=83786),
#   datetime.timedelta(seconds=84203)],
#  'bot-2370489267': [datetime.timedelta(days=6, seconds=67264),
#   datetime.timedelta(seconds=4061),
#   datetime.timedelta(seconds=178),
#   datetime.timedelta(seconds=10504),
#   datetime.timedelta(seconds=77872),
#   datetime.timedelta(seconds=24434),
#   datetime.timedelta(seconds=9088),
#   datetime.timedelta(seconds=139),
#   datetime.timedelta(days=5, seconds=5944)],
#  'human-120538744': [datetime.timedelta(seconds=20),
#   datetime.timedelta(days=1, seconds=43511),
#   datetime.timedelta(days=1, seconds=48915),
#   datetime.timedelta(seconds=28975),
#   datetime.timedelta(seconds=16512),
#   datetime.timedelta(seconds=627),
#   datetime.timedelta(seconds=9),
#   datetime.timedelta(seconds=73),
#   datetime.timedelta(seconds=38)],
#  'human-410303609': [datetime.timedelta(days=274, seconds=30436),
#   datetime.timedelta(seconds=54),
#   datetime.timedelta(seconds=57),
#   datetime.timedelta(seconds=88),
#   datetime.timedelta(seconds=105),
#   datetime.timedelta(days=35, seconds=22350),
#   datetime.timedelta(days=151, seconds=8760),
#   datetime.timedelta(seconds=124),
#   datetime.timedelta(days=7, seconds=29524)],
#  'human-1210485564': [datetime.timedelta(days=2, seconds=81605),
#   datetime.timedelta(seconds=9142),
#   datetime.timedelta(days=2, seconds=76841),
#   datetime.timedelta(days=8, seconds=1104),
#   datetime.timedelta(seconds=55438),
#   datetime.timedelta(seconds=5960),
#   datetime.timedelta(seconds=24698),
#   datetime.timedelta(days=1, seconds=84428),
#   datetime.timedelta(days=4, seconds=12457)],
#  'bot-2334336214': [],
#  'human-897654887974137857': [],
#  'human-16967612': [datetime.timedelta(seconds=1244),
#   datetime.timedelta(seconds=2413),
#   datetime.timedelta(seconds=2283),
#   datetime.timedelta(seconds=41430),
#   datetime.timedelta(seconds=35442),
#   datetime.timedelta(seconds=1699),
#   datetime.timedelta(seconds=2315),
#   datetime.timedelta(seconds=117),
#   datetime.timedelta(seconds=2862)],
#  'human-30603300': [],
#  'bot-2157748434': [datetime.timedelta(seconds=127),
#   datetime.timedelta(seconds=54),
#   datetime.timedelta(seconds=11),
#   datetime.timedelta(seconds=26),
#   datetime.timedelta(seconds=36),
#   datetime.timedelta(seconds=73),
#   datetime.timedelta(seconds=69),
#   datetime.timedelta(seconds=44),
#   datetime.timedelta(seconds=11)],
#  'human-17685964': [datetime.timedelta(seconds=16458),
#   datetime.timedelta(seconds=36441),
#   datetime.timedelta(seconds=5521),
#   datetime.timedelta(days=1, seconds=4131),
#   datetime.timedelta(seconds=32),
#   datetime.timedelta(seconds=7313),
#   datetime.timedelta(seconds=79),
#   datetime.timedelta(seconds=49),
#   datetime.timedelta(seconds=4740)],
#  'human-49031917': [datetime.timedelta(days=35, seconds=44028),
#   datetime.timedelta(days=106, seconds=23843),
#   datetime.timedelta(days=2, seconds=8480),
#   datetime.timedelta(seconds=91),
#   datetime.timedelta(days=50, seconds=37969),
#   datetime.timedelta(days=2, seconds=42260),
#   datetime.timedelta(days=1, seconds=38468),
#   datetime.timedelta(days=259, seconds=30318),
#   datetime.timedelta(days=5, seconds=80189)],
#  'human-192608058': [],
#  'human-206795782': [datetime.timedelta(seconds=9410),
#   datetime.timedelta(days=3, seconds=76851),
#   datetime.timedelta(days=1, seconds=39520),
#   datetime.timedelta(seconds=90),
#   datetime.timedelta(seconds=47349),
#   datetime.timedelta(seconds=2892),
#   datetime.timedelta(seconds=81529),
#   datetime.timedelta(seconds=34084),
#   datetime.timedelta(days=1, seconds=405)],
#  'human-818494659873951745': [datetime.timedelta(seconds=106),
#   datetime.timedelta(seconds=111),
#   datetime.timedelta(seconds=38),
#   datetime.timedelta(seconds=798),
#   datetime.timedelta(seconds=54),
#   datetime.timedelta(seconds=57),
#   datetime.timedelta(seconds=452),
#   datetime.timedelta(seconds=122),
#   datetime.timedelta(seconds=222)],
#  'human-892830498350931973': [datetime.timedelta(seconds=556),
#   datetime.timedelta(seconds=439),
#   datetime.timedelta(seconds=714),
#   datetime.timedelta(seconds=502),
#   datetime.timedelta(days=-1, seconds=85184)],
#  'human-2806413827': [datetime.timedelta(seconds=28220),
#   datetime.timedelta(seconds=42271),
#   datetime.timedelta(seconds=82990),
#   datetime.timedelta(days=2, seconds=42273),
#   datetime.timedelta(seconds=888),
#   datetime.timedelta(days=1, seconds=2234),
#   datetime.timedelta(seconds=993),
#   datetime.timedelta(seconds=1542),
#   datetime.timedelta(seconds=380)],
#  'human-54135314': [datetime.timedelta(seconds=199),
#   datetime.timedelta(seconds=1418),
#   datetime.timedelta(seconds=340),
#   datetime.timedelta(seconds=32),
#   datetime.timedelta(seconds=5120),
#   datetime.timedelta(seconds=9104),
#   datetime.timedelta(seconds=75025),
#   datetime.timedelta(days=8, seconds=75887),
#   datetime.timedelta(seconds=29208)],
#  'human-262355899': [datetime.timedelta(days=4, seconds=52102),
#   datetime.timedelta(seconds=71209),
#   datetime.timedelta(days=1, seconds=33261),
#   datetime.timedelta(days=2, seconds=3503),
#   datetime.timedelta(days=2, seconds=80204),
#   datetime.timedelta(days=1, seconds=12818),
#   datetime.timedelta(days=2, seconds=72709),
#   datetime.timedelta(days=1, seconds=7164),
#   datetime.timedelta(days=1, seconds=82465)],
#  'human-899119832922071040': [datetime.timedelta(seconds=37),
#   datetime.timedelta(seconds=152),
#   datetime.timedelta(seconds=72),
#   datetime.timedelta(seconds=3443),
#   datetime.timedelta(seconds=211),
#   datetime.timedelta(seconds=3450),
#   datetime.timedelta(seconds=82),
#   datetime.timedelta(seconds=3154)],
#  'human-66209470': [datetime.timedelta(days=9, seconds=34787),
#   datetime.timedelta(days=1, seconds=8230),
#   datetime.timedelta(days=4, seconds=58705),
#   datetime.timedelta(seconds=76259),
#   datetime.timedelta(days=3, seconds=7350),
#   datetime.timedelta(seconds=12036),
#   datetime.timedelta(seconds=6723),
#   datetime.timedelta(days=2, seconds=84377),
#   datetime.timedelta(days=1, seconds=59872)],
#  'human-237947008': [datetime.timedelta(days=4, seconds=14003),
#   datetime.timedelta(days=3, seconds=66887),
#   datetime.timedelta(seconds=64432),
#   datetime.timedelta(days=5, seconds=41489),
#   datetime.timedelta(days=8, seconds=54218),
#   datetime.timedelta(days=3, seconds=37643),
#   datetime.timedelta(days=4, seconds=61105),
#   datetime.timedelta(days=3, seconds=76772),
#   datetime.timedelta(seconds=61879)],
#  'human-105874636': [datetime.timedelta(seconds=68),
#   datetime.timedelta(seconds=61419),
#   datetime.timedelta(days=2, seconds=81751),
#   datetime.timedelta(days=1, seconds=20660),
#   datetime.timedelta(days=3, seconds=3980),
#   datetime.timedelta(days=6, seconds=68698),
#   datetime.timedelta(days=2, seconds=1243),
#   datetime.timedelta(days=5, seconds=5964),
#   datetime.timedelta(seconds=64003)],
#  'bot-15380583': [datetime.timedelta(seconds=881),
#   datetime.timedelta(seconds=1767),
#   datetime.timedelta(seconds=5617)],
#  'human-496493810': [datetime.timedelta(seconds=11407),
#   datetime.timedelta(seconds=2541),
#   datetime.timedelta(seconds=266),
#   datetime.timedelta(seconds=248),
#   datetime.timedelta(seconds=104),
#   datetime.timedelta(seconds=554),
#   datetime.timedelta(seconds=362),
#   datetime.timedelta(seconds=110),
#   datetime.timedelta(seconds=120)],
#  'bot-955613694': [datetime.timedelta(seconds=3993),
#   datetime.timedelta(seconds=14),
#   datetime.timedelta(seconds=1263),
#   datetime.timedelta(seconds=5968),
#   datetime.timedelta(seconds=8248)],
#  'bot-1425520304': [],
#  'human-242916135': [datetime.timedelta(seconds=26),
#   datetime.timedelta(seconds=32),
#   datetime.timedelta(seconds=21),
#   datetime.timedelta(seconds=1662),
#   datetime.timedelta(seconds=969),
#   datetime.timedelta(seconds=32196),
#   datetime.timedelta(seconds=517),
#   datetime.timedelta(seconds=1958),
#   datetime.timedelta(seconds=35)],
#  'human-1198902685': [],
#  'bot-3262306109': [datetime.timedelta(days=386, seconds=61627),
#   datetime.timedelta(seconds=11),
#   datetime.timedelta(seconds=3066),
#   datetime.timedelta(days=189, seconds=29208),
#   datetime.timedelta(days=26, seconds=65235),
#   datetime.timedelta(seconds=1509),
#   datetime.timedelta(days=1, seconds=25516),
#   datetime.timedelta(days=3, seconds=1159),
#   datetime.timedelta(days=18, seconds=59943)],
#  'human-865213866': [datetime.timedelta(days=8, seconds=41988),
#   datetime.timedelta(days=5, seconds=80757),
#   datetime.timedelta(days=2, seconds=935),
#   datetime.timedelta(days=40, seconds=13553),
#   datetime.timedelta(days=21, seconds=46286)],
#  'human-49717874': [datetime.timedelta(seconds=1937),
#   datetime.timedelta(days=6, seconds=84899),
#   datetime.timedelta(seconds=128),
#   datetime.timedelta(days=7, seconds=56251),
#   datetime.timedelta(seconds=21),
#   datetime.timedelta(seconds=28639),
#   datetime.timedelta(days=6, seconds=82604),
#   datetime.timedelta(days=6, seconds=71243),
#   datetime.timedelta(days=2, seconds=1963)],
#  'bot-507975093': [datetime.timedelta(seconds=134),
#   datetime.timedelta(seconds=7792),
#   datetime.timedelta(seconds=828),
#   datetime.timedelta(seconds=459)],
#  'human-319916258': [datetime.timedelta(seconds=33702),
#   datetime.timedelta(days=3, seconds=51915),
#   datetime.timedelta(seconds=363),
#   datetime.timedelta(seconds=5309),
#   datetime.timedelta(seconds=26695),
#   datetime.timedelta(seconds=76481),
#   datetime.timedelta(seconds=666),
#   datetime.timedelta(seconds=11389),
#   datetime.timedelta(days=1, seconds=73087)],
#  'human-33416325': [datetime.timedelta(seconds=89),
#   datetime.timedelta(seconds=123),
#   datetime.timedelta(seconds=91),
#   datetime.timedelta(days=4, seconds=57675),
#   datetime.timedelta(days=33, seconds=78671),
#   datetime.timedelta(days=16, seconds=27370),
#   datetime.timedelta(seconds=63),
#   datetime.timedelta(days=5, seconds=69341),
#   datetime.timedelta(seconds=272)],
#  'human-27055023': [datetime.timedelta(seconds=29486),
#   datetime.timedelta(days=1, seconds=173),
#   datetime.timedelta(seconds=16285),
#   datetime.timedelta(days=3, seconds=60694),
#   datetime.timedelta(seconds=22158),
#   datetime.timedelta(seconds=2626),
#   datetime.timedelta(days=1, seconds=58978),
#   datetime.timedelta(days=3, seconds=31933),
#   datetime.timedelta(seconds=60279)],
#  'human-772201057506164736': [datetime.timedelta(seconds=84),
#   datetime.timedelta(seconds=1098),
#   datetime.timedelta(seconds=1558),
#   datetime.timedelta(seconds=549),
#   datetime.timedelta(seconds=53),
#   datetime.timedelta(seconds=477)],
#  'bot-2765054066': [datetime.timedelta(seconds=2803),
#   datetime.timedelta(seconds=2960),
#   datetime.timedelta(seconds=2349),
#   datetime.timedelta(seconds=3608),
#   datetime.timedelta(seconds=3386),
#   datetime.timedelta(seconds=9064)],
#  'human-2557037323': [datetime.timedelta(days=3, seconds=85345),
#   datetime.timedelta(days=7, seconds=1018),
#   datetime.timedelta(days=1, seconds=66184),
#   datetime.timedelta(days=8, seconds=16614),
#   datetime.timedelta(days=2, seconds=76985),
#   datetime.timedelta(days=8, seconds=85222),
#   datetime.timedelta(days=4, seconds=10694),
#   datetime.timedelta(days=2, seconds=2185),
#   datetime.timedelta(days=6, seconds=72899)],
#  'human-3930997512': [datetime.timedelta(days=6, seconds=73093),
#   datetime.timedelta(days=2, seconds=47752),
#   datetime.timedelta(days=16, seconds=39979),
#   datetime.timedelta(seconds=309),
#   datetime.timedelta(days=2, seconds=30904),
#   datetime.timedelta(days=27, seconds=1727),
#   datetime.timedelta(days=33, seconds=54906),
#   datetime.timedelta(seconds=112),
#   datetime.timedelta(seconds=135)],
#  'bot-194490327': [datetime.timedelta(seconds=16218),
#   datetime.timedelta(seconds=7193),
#   datetime.timedelta(seconds=12619),
#   datetime.timedelta(seconds=7194),
#   datetime.timedelta(seconds=16184),
#   datetime.timedelta(seconds=185),
#   datetime.timedelta(seconds=7020),
#   datetime.timedelta(seconds=5582),
#   datetime.timedelta(seconds=1622)],
#  'human-8161232': [datetime.timedelta(seconds=81465),
#   datetime.timedelta(days=3, seconds=26519),
#   datetime.timedelta(seconds=18666),
#   datetime.timedelta(seconds=81362),
#   datetime.timedelta(seconds=72873),
#   datetime.timedelta(0),
#   datetime.timedelta(seconds=1),
#   datetime.timedelta(seconds=7883),
#   datetime.timedelta(seconds=80118)],
#  'bot-266567089': [datetime.timedelta(days=129, seconds=72338),
#   datetime.timedelta(days=332, seconds=14250),
#   datetime.timedelta(seconds=447),
#   datetime.timedelta(seconds=187)],
#  'human-284265377': [datetime.timedelta(seconds=231),
#   datetime.timedelta(seconds=2515),
#   datetime.timedelta(seconds=11274),
#   datetime.timedelta(seconds=446),
#   datetime.timedelta(seconds=1406),
#   datetime.timedelta(seconds=779),
#   datetime.timedelta(seconds=1442),
#   datetime.timedelta(seconds=1615),
#   datetime.timedelta(seconds=13465)],
#  'human-172028587': [datetime.timedelta(seconds=2985),
#   datetime.timedelta(seconds=62),
#   datetime.timedelta(seconds=17737),
#   datetime.timedelta(seconds=77572),
#   datetime.timedelta(seconds=91),
#   datetime.timedelta(seconds=1978),
#   datetime.timedelta(seconds=4),
#   datetime.timedelta(seconds=4411),
#   datetime.timedelta(seconds=2344)],
#  'bot-524229856': [datetime.timedelta(days=149, seconds=84216),
#   datetime.timedelta(days=103, seconds=28971),
#   datetime.timedelta(days=23, seconds=73124),
#   datetime.timedelta(days=716, seconds=83688),
#   datetime.timedelta(seconds=753),
#   datetime.timedelta(seconds=410),
#   datetime.timedelta(seconds=397)],
#  'human-106854148': [],
#  'bot-2753102609': [datetime.timedelta(days=19, seconds=58730),
#   datetime.timedelta(days=6, seconds=62351),
#   datetime.timedelta(days=4, seconds=81626),
#   datetime.timedelta(days=1, seconds=49971),
#   datetime.timedelta(days=1, seconds=11042),
#   datetime.timedelta(seconds=107),
#   datetime.timedelta(seconds=34105),
#   datetime.timedelta(seconds=8998),
#   datetime.timedelta(days=264, seconds=76225)],
#  'bot-2493362950': [datetime.timedelta(seconds=3531),
#   datetime.timedelta(seconds=1520),
#   datetime.timedelta(seconds=1335),
#   datetime.timedelta(seconds=27),
#   datetime.timedelta(days=2, seconds=11582),
#   datetime.timedelta(seconds=3536),
#   datetime.timedelta(seconds=277),
#   datetime.timedelta(seconds=1717),
#   datetime.timedelta(seconds=33)],
#  'human-2444454050': [datetime.timedelta(seconds=5),
#   datetime.timedelta(days=3, seconds=10880),
#   datetime.timedelta(seconds=71062),
#   datetime.timedelta(seconds=8909),
#   datetime.timedelta(seconds=30205),
#   datetime.timedelta(seconds=4913),
#   datetime.timedelta(seconds=2545),
#   datetime.timedelta(seconds=76),
#   datetime.timedelta(seconds=41)],
#  'human-1353020900': [datetime.timedelta(seconds=28529),
#   datetime.timedelta(seconds=55146),
#   datetime.timedelta(days=5, seconds=5260),
#   datetime.timedelta(days=3, seconds=3085),
#   datetime.timedelta(days=2, seconds=22250),
#   datetime.timedelta(seconds=56235),
#   datetime.timedelta(days=3, seconds=15698),
#   datetime.timedelta(days=4, seconds=3064),
#   datetime.timedelta(days=28, seconds=19652)],
#  'human-997629601': [datetime.timedelta(days=2, seconds=17189),
#   datetime.timedelta(seconds=102),
#   datetime.timedelta(days=8, seconds=81117),
#   datetime.timedelta(days=13, seconds=74953),
#   datetime.timedelta(days=6, seconds=19576),
#   datetime.timedelta(days=10, seconds=58126),
#   datetime.timedelta(days=81, seconds=18280),
#   datetime.timedelta(days=6, seconds=6579),
#   datetime.timedelta(days=5, seconds=3592)],
#  'human-36149861': [datetime.timedelta(days=62, seconds=7702),
#   datetime.timedelta(days=3, seconds=59828),
#   datetime.timedelta(seconds=6287),
#   datetime.timedelta(seconds=220),
#   datetime.timedelta(seconds=53),
#   datetime.timedelta(seconds=1319),
#   datetime.timedelta(seconds=6011)],
#  'bot-452695727': [],
#  'human-595227048': [],
#  'human-146962935': [datetime.timedelta(seconds=17731),
#   datetime.timedelta(days=1, seconds=60666),
#   datetime.timedelta(seconds=14557),
#   datetime.timedelta(seconds=44),
#   datetime.timedelta(days=2, seconds=83134),
#   datetime.timedelta(days=3, seconds=50917),
#   datetime.timedelta(seconds=2869),
#   datetime.timedelta(days=3, seconds=46525),
#   datetime.timedelta(days=3, seconds=71082)],
#  'human-2149467889': [],
#  'human-39916645': [datetime.timedelta(days=41, seconds=20136),
#   datetime.timedelta(seconds=5763),
#   datetime.timedelta(days=1, seconds=67879),
#   datetime.timedelta(days=3, seconds=81723),
#   datetime.timedelta(days=2, seconds=13800),
#   datetime.timedelta(seconds=15),
#   datetime.timedelta(days=21, seconds=50646),
#   datetime.timedelta(days=12, seconds=73),
#   datetime.timedelta(days=13, seconds=9965)],
#  'bot-185614108': [datetime.timedelta(seconds=198),
#   datetime.timedelta(seconds=440),
#   datetime.timedelta(seconds=4105),
#   datetime.timedelta(seconds=816),
#   datetime.timedelta(seconds=2054),
#   datetime.timedelta(seconds=2571)],
#  'human-96756427': [datetime.timedelta(seconds=521),
#   datetime.timedelta(seconds=7698),
#   datetime.timedelta(seconds=75),
#   datetime.timedelta(seconds=908),
#   datetime.timedelta(seconds=1491),
#   datetime.timedelta(seconds=25701),
#   datetime.timedelta(days=1, seconds=53985),
#   datetime.timedelta(seconds=408),
#   datetime.timedelta(seconds=342)],
#  'human-3304160639': [datetime.timedelta(seconds=4),
#   datetime.timedelta(seconds=310),
#   datetime.timedelta(seconds=705),
#   datetime.timedelta(seconds=10),
#   datetime.timedelta(seconds=23),
#   datetime.timedelta(seconds=4),
#   datetime.timedelta(seconds=215)],
#  'human-262261686': [datetime.timedelta(days=3, seconds=20856),
#   datetime.timedelta(days=1, seconds=54861),
#   datetime.timedelta(days=1, seconds=54379),
#   datetime.timedelta(seconds=37954),
#   datetime.timedelta(seconds=45198),
#   datetime.timedelta(seconds=35366),
#   datetime.timedelta(seconds=2),
#   datetime.timedelta(days=1, seconds=16397),
#   datetime.timedelta(seconds=13)],
#  'bot-101022647': [datetime.timedelta(days=756, seconds=20506),
#   datetime.timedelta(days=3, seconds=64355),
#   datetime.timedelta(days=626, seconds=40284),
#   datetime.timedelta(seconds=5311),
#   datetime.timedelta(seconds=2372),
#   datetime.timedelta(seconds=11001),
#   datetime.timedelta(seconds=1997),
#   datetime.timedelta(seconds=3243)],
#  'bot-211951322': [],
#  'human-65957347': [datetime.timedelta(days=4, seconds=73473),
#   datetime.timedelta(days=1, seconds=83305),
#   datetime.timedelta(seconds=22078),
#   datetime.timedelta(seconds=74780),
#   datetime.timedelta(seconds=82281),
#   datetime.timedelta(days=1, seconds=9549),
#   datetime.timedelta(days=44, seconds=50189),
#   datetime.timedelta(days=7, seconds=40432),
#   datetime.timedelta(days=14, seconds=76864)],
#  'human-130557513': [datetime.timedelta(seconds=54),
#   datetime.timedelta(seconds=4139),
#   datetime.timedelta(seconds=52),
#   datetime.timedelta(seconds=7417),
#   datetime.timedelta(seconds=203),
#   datetime.timedelta(seconds=56),
#   datetime.timedelta(seconds=75),
#   datetime.timedelta(seconds=49),
#   datetime.timedelta(seconds=483)],
#  'human-3048406794': [datetime.timedelta(seconds=181),
#   datetime.timedelta(days=73, seconds=23642),
#   datetime.timedelta(seconds=327),
#   datetime.timedelta(days=1, seconds=48032),
#   datetime.timedelta(seconds=62),
#   datetime.timedelta(days=16, seconds=11117)],
#  'bot-768505022': [datetime.timedelta(seconds=4069),
#   datetime.timedelta(seconds=4990),
#   datetime.timedelta(seconds=1510),
#   datetime.timedelta(seconds=929),
#   datetime.timedelta(seconds=6800),
#   datetime.timedelta(seconds=11029),
#   datetime.timedelta(seconds=2986)],
#  'human-434968527': [],
#  'human-27744185': [datetime.timedelta(days=100, seconds=82307),
#   datetime.timedelta(days=65, seconds=83304),
#   datetime.timedelta(days=16, seconds=14487),
#   datetime.timedelta(days=86, seconds=72609),
#   datetime.timedelta(days=1, seconds=11896),
#   datetime.timedelta(seconds=73178),
#   datetime.timedelta(days=55, seconds=13536),
#   datetime.timedelta(days=1, seconds=75524),
#   datetime.timedelta(0)],
#  'human-444084726': [datetime.timedelta(days=945, seconds=74460),
#   datetime.timedelta(days=155, seconds=15777),
#   datetime.timedelta(days=106, seconds=65336),
#   datetime.timedelta(days=146, seconds=18038),
#   datetime.timedelta(days=33, seconds=44703),
#   datetime.timedelta(days=13, seconds=54097),
#   datetime.timedelta(days=10, seconds=57935),
#   datetime.timedelta(days=3, seconds=17587)],
#  'human-24636191': [datetime.timedelta(days=1, seconds=66482),
#   datetime.timedelta(days=2, seconds=13590),
#   datetime.timedelta(seconds=72),
#   datetime.timedelta(days=1, seconds=81671),
#   datetime.timedelta(days=4, seconds=68287),
#   datetime.timedelta(seconds=18208),
#   datetime.timedelta(days=1, seconds=68554),
#   datetime.timedelta(seconds=469),
#   datetime.timedelta(days=3, seconds=24988)],
#  'human-31583882': [datetime.timedelta(seconds=9663),
#   datetime.timedelta(seconds=5229),
#   datetime.timedelta(seconds=4037),
#   datetime.timedelta(seconds=5038),
#   datetime.timedelta(0),
#   datetime.timedelta(seconds=906),
#   datetime.timedelta(seconds=284),
#   datetime.timedelta(seconds=2474),
#   datetime.timedelta(seconds=4134)],
#  'human-44511572': [datetime.timedelta(days=1, seconds=10046),
#   datetime.timedelta(seconds=46211),
#   datetime.timedelta(seconds=32079),
#   datetime.timedelta(seconds=2133),
#   datetime.timedelta(days=1, seconds=5431),
#   datetime.timedelta(seconds=1264),
#   datetime.timedelta(seconds=7303),
#   datetime.timedelta(days=3, seconds=76380),
#   datetime.timedelta(seconds=9945)],
#  'human-14200130': [datetime.timedelta(seconds=699),
#   datetime.timedelta(seconds=56850),
#   datetime.timedelta(seconds=6353),
#   datetime.timedelta(seconds=62851),
#   datetime.timedelta(days=1, seconds=2848),
#   datetime.timedelta(days=2, seconds=19007),
#   datetime.timedelta(seconds=686),
#   datetime.timedelta(seconds=143),
#   datetime.timedelta(seconds=1289)],
#  'bot-899210773': [datetime.timedelta(seconds=125),
#   datetime.timedelta(days=554, seconds=57760),
#   datetime.timedelta(days=17, seconds=26752),
#   datetime.timedelta(days=64, seconds=43182),
#   datetime.timedelta(days=109, seconds=8432),
#   datetime.timedelta(days=7, seconds=7855),
#   datetime.timedelta(days=7, seconds=78587),
#   datetime.timedelta(seconds=12792),
#   datetime.timedelta(days=18, seconds=38968)],
#  'human-331613467': [datetime.timedelta(days=1, seconds=2164),
#   datetime.timedelta(days=3, seconds=81372),
#   datetime.timedelta(seconds=98),
#   datetime.timedelta(days=17, seconds=19030),
#   datetime.timedelta(days=3, seconds=80545),
#   datetime.timedelta(seconds=13),
#   datetime.timedelta(seconds=22364),
#   datetime.timedelta(seconds=218),
#   datetime.timedelta(days=72, seconds=51934)],
#  'human-33880658': [datetime.timedelta(days=565, seconds=65963),
#   datetime.timedelta(days=136, seconds=58550),
#   datetime.timedelta(seconds=23670),
#   datetime.timedelta(seconds=653),
#   datetime.timedelta(seconds=30248),
#   datetime.timedelta(seconds=5948),
#   datetime.timedelta(seconds=30446),
#   datetime.timedelta(seconds=360),
#   datetime.timedelta(seconds=54)],
#  'human-1006904365016330245': [],
#  'human-62318705': [datetime.timedelta(days=1, seconds=629),
#   datetime.timedelta(seconds=53634),
#   datetime.timedelta(days=3, seconds=35488),
#   datetime.timedelta(days=15, seconds=44074),
#   datetime.timedelta(days=8, seconds=33933),
#   datetime.timedelta(days=9, seconds=32494),
#   datetime.timedelta(days=1, seconds=48275),
#   datetime.timedelta(seconds=74432),
#   datetime.timedelta(days=7, seconds=75382)],
#  'human-227771924': [datetime.timedelta(days=13, seconds=26602),
#   datetime.timedelta(days=1, seconds=20392),
#   datetime.timedelta(days=9, seconds=69896),
#   datetime.timedelta(days=23, seconds=45580),
#   datetime.timedelta(days=1, seconds=1157),
#   datetime.timedelta(seconds=78323),
#   datetime.timedelta(seconds=72287),
#   datetime.timedelta(days=2, seconds=63583),
#   datetime.timedelta(days=18, seconds=29385)],
#  'human-365297032': [datetime.timedelta(days=6, seconds=12611),
#   datetime.timedelta(days=16, seconds=81436),
#   datetime.timedelta(days=22, seconds=25880),
#   datetime.timedelta(days=21, seconds=30860),
#   datetime.timedelta(days=34, seconds=83432),
#   datetime.timedelta(days=47, seconds=41968),
#   datetime.timedelta(seconds=2),
#   datetime.timedelta(seconds=12130),
#   datetime.timedelta(days=3, seconds=11582)],
#  'bot-1355634794': [datetime.timedelta(seconds=1916),
#   datetime.timedelta(seconds=4877),
#   datetime.timedelta(seconds=853),
#   datetime.timedelta(seconds=11462),
#   datetime.timedelta(seconds=7495),
#   datetime.timedelta(seconds=697),
#   datetime.timedelta(seconds=2372)],
#  'human-549680454': [datetime.timedelta(days=5, seconds=68233),
#   datetime.timedelta(seconds=21613),
#   datetime.timedelta(seconds=19),
#   datetime.timedelta(seconds=1329),
#   datetime.timedelta(seconds=54416),
#   datetime.timedelta(days=83, seconds=69508),
#   datetime.timedelta(seconds=12665)],
#  'human-206811711': [datetime.timedelta(seconds=14092),
#   datetime.timedelta(seconds=9151),
#   datetime.timedelta(seconds=5107),
#   datetime.timedelta(seconds=1415),
#   datetime.timedelta(seconds=59270),
#   datetime.timedelta(seconds=29),
#   datetime.timedelta(seconds=34),
#   datetime.timedelta(seconds=1732),
#   datetime.timedelta(seconds=670)],
#  'bot-301218888': [datetime.timedelta(seconds=36),
#   datetime.timedelta(seconds=26),
#   datetime.timedelta(days=1, seconds=85350),
#   datetime.timedelta(seconds=16),
#   datetime.timedelta(days=2, seconds=2287),
#   datetime.timedelta(seconds=17),
#   datetime.timedelta(days=2, seconds=29843),
#   datetime.timedelta(days=1, seconds=77956),
#   datetime.timedelta(seconds=25)],
#  'human-2204874359': [datetime.timedelta(seconds=170),
#   datetime.timedelta(seconds=876),
#   datetime.timedelta(seconds=72),
#   datetime.timedelta(seconds=30),
#   datetime.timedelta(seconds=89),
#   datetime.timedelta(seconds=172),
#   datetime.timedelta(seconds=59),
#   datetime.timedelta(seconds=8),
#   datetime.timedelta(seconds=288)],
#  'human-434986912': [datetime.timedelta(seconds=331),
#   datetime.timedelta(seconds=7137),
#   datetime.timedelta(seconds=792)],
#  'bot-1094153152389992449': [datetime.timedelta(seconds=43208),
#   datetime.timedelta(seconds=86395),
#   datetime.timedelta(seconds=43186),
#   datetime.timedelta(seconds=43215),
#   datetime.timedelta(seconds=43200),
#   datetime.timedelta(seconds=86394),
#   datetime.timedelta(seconds=43206),
#   datetime.timedelta(seconds=43191),
#   datetime.timedelta(seconds=43209)],
#  'human-834554303176138752': [datetime.timedelta(seconds=136),
#   datetime.timedelta(seconds=1538),
#   datetime.timedelta(seconds=420),
#   datetime.timedelta(seconds=52),
#   datetime.timedelta(seconds=505)],
#  'human-2545978907': [datetime.timedelta(days=72, seconds=8011),
#   datetime.timedelta(days=13, seconds=19953),
#   datetime.timedelta(days=7, seconds=51102),
#   datetime.timedelta(days=4, seconds=34049),
#   datetime.timedelta(days=8, seconds=2400),
#   datetime.timedelta(days=26, seconds=83378),
#   datetime.timedelta(days=6, seconds=78131),
#   datetime.timedelta(seconds=8968)],
#  'human-155561448': [datetime.timedelta(seconds=71),
#   datetime.timedelta(days=11, seconds=27446),
#   datetime.timedelta(days=1, seconds=29452),
#   datetime.timedelta(seconds=39223),
#   datetime.timedelta(days=6, seconds=12007),
#   datetime.timedelta(days=4, seconds=40316),
#   datetime.timedelta(seconds=5143),
#   datetime.timedelta(days=3, seconds=54993),
#   datetime.timedelta(days=1, seconds=41051)],
#  'bot-22316967': [datetime.timedelta(days=48, seconds=73649),
#   datetime.timedelta(seconds=2528),
#   datetime.timedelta(seconds=759),
#   datetime.timedelta(seconds=2580),
#   datetime.timedelta(seconds=1617)],
#  'human-1016379415205482496': [datetime.timedelta(days=3, seconds=65177),
#   datetime.timedelta(days=1, seconds=86026),
#   datetime.timedelta(seconds=8985),
#   datetime.timedelta(seconds=3751),
#   datetime.timedelta(seconds=1696),
#   datetime.timedelta(seconds=2028),
#   datetime.timedelta(seconds=3702),
#   datetime.timedelta(days=1, seconds=57553),
#   datetime.timedelta(seconds=24683)],
#  'human-370693222': [datetime.timedelta(days=211, seconds=83850),
#   datetime.timedelta(days=28, seconds=61809),
#   datetime.timedelta(days=16, seconds=79984),
#   datetime.timedelta(days=4, seconds=8189),
#   datetime.timedelta(days=2, seconds=29234),
#   datetime.timedelta(days=10, seconds=53690),
#   datetime.timedelta(days=5, seconds=2299),
#   datetime.timedelta(days=1, seconds=81758),
#   datetime.timedelta(days=2, seconds=13210)],
#  'human-21741551': [datetime.timedelta(seconds=238),
#   datetime.timedelta(days=1, seconds=48988),
#   datetime.timedelta(days=2, seconds=68883),
#   datetime.timedelta(seconds=12356),
#   datetime.timedelta(days=2, seconds=77996),
#   datetime.timedelta(seconds=66),
#   datetime.timedelta(seconds=76),
#   datetime.timedelta(seconds=8713),
#   datetime.timedelta(seconds=9760)],
#  'bot-956522994': [datetime.timedelta(seconds=1121),
#   datetime.timedelta(seconds=448),
#   datetime.timedelta(seconds=44),
#   datetime.timedelta(seconds=11),
#   datetime.timedelta(seconds=78613),
#   datetime.timedelta(seconds=849),
#   datetime.timedelta(seconds=3244),
#   datetime.timedelta(seconds=1717)],
#  'bot-877329307005100032': [datetime.timedelta(seconds=5),
#   datetime.timedelta(seconds=39),
#   datetime.timedelta(seconds=6),
#   datetime.timedelta(seconds=155),
#   datetime.timedelta(seconds=11),
#   datetime.timedelta(seconds=10)],
#  'human-98487400': [],
#  'human-321799506': [datetime.timedelta(seconds=41),
#   datetime.timedelta(days=9, seconds=16611),
#   datetime.timedelta(days=1, seconds=68056),
#   datetime.timedelta(seconds=3838),
#   datetime.timedelta(days=20, seconds=11894),
#   datetime.timedelta(seconds=94),
#   datetime.timedelta(days=46, seconds=183),
#   datetime.timedelta(seconds=39793),
#   datetime.timedelta(days=30, seconds=52689)],
#  'human-1244372887': [datetime.timedelta(seconds=365),
#   datetime.timedelta(seconds=12),
#   datetime.timedelta(seconds=98),
#   datetime.timedelta(seconds=25),
#   datetime.timedelta(seconds=65),
#   datetime.timedelta(seconds=67),
#   datetime.timedelta(seconds=264),
#   datetime.timedelta(seconds=16328),
#   datetime.timedelta(seconds=84)],
#  'human-4766492432': [datetime.timedelta(seconds=6707),
#   datetime.timedelta(seconds=6125),
#   datetime.timedelta(seconds=31),
#   datetime.timedelta(seconds=11860),
#   datetime.timedelta(seconds=75),
#   datetime.timedelta(seconds=7),
#   datetime.timedelta(seconds=3765),
#   datetime.timedelta(seconds=1753),
#   datetime.timedelta(seconds=151)],
#  'human-365090932': [datetime.timedelta(seconds=18313),
#   datetime.timedelta(seconds=7540),
#   datetime.timedelta(seconds=3),
#   datetime.timedelta(seconds=2561),
#   datetime.timedelta(seconds=149),
#   datetime.timedelta(seconds=538),
#   datetime.timedelta(days=1, seconds=84968),
#   datetime.timedelta(days=3, seconds=2319),
#   datetime.timedelta(seconds=83753)],
#  'human-1062421026': [],
#  'bot-3020078978': [datetime.timedelta(seconds=620),
#   datetime.timedelta(seconds=500),
#   datetime.timedelta(seconds=6348),
#   datetime.timedelta(seconds=376)],
#  'human-1030207566628970496': [],
#  'human-761296330903916545': [datetime.timedelta(seconds=171),
#   datetime.timedelta(seconds=1249),
#   datetime.timedelta(seconds=407),
#   datetime.timedelta(seconds=103),
#   datetime.timedelta(seconds=3887),
#   datetime.timedelta(seconds=642),
#   datetime.timedelta(seconds=9182),
#   datetime.timedelta(seconds=3968),
#   datetime.timedelta(seconds=41257),
#   datetime.timedelta(days=8, seconds=4109),
#   datetime.timedelta(seconds=28),
#   datetime.timedelta(seconds=5986),
#   datetime.timedelta(seconds=4171),
#   datetime.timedelta(seconds=3599),
#   datetime.timedelta(seconds=1749),
#   datetime.timedelta(seconds=2221),
#   datetime.timedelta(seconds=3982),
#   datetime.timedelta(seconds=690),
#   datetime.timedelta(seconds=289)],
#  'human-289019369': [datetime.timedelta(seconds=17052),
#   datetime.timedelta(seconds=1773),
#   datetime.timedelta(seconds=4784),
#   datetime.timedelta(seconds=2382),
#   datetime.timedelta(seconds=4535),
#   datetime.timedelta(seconds=40185),
#   datetime.timedelta(seconds=16),
#   datetime.timedelta(seconds=164),
#   datetime.timedelta(seconds=5473)],
#  'human-3320478908': [datetime.timedelta(seconds=82),
#   datetime.timedelta(seconds=183),
#   datetime.timedelta(seconds=100),
#   datetime.timedelta(seconds=672),
#   datetime.timedelta(seconds=98),
#   datetime.timedelta(seconds=353),
#   datetime.timedelta(days=2, seconds=81984),
#   datetime.timedelta(seconds=12),
#   datetime.timedelta(seconds=382)],
#  'human-14348594': [datetime.timedelta(seconds=34),
#   datetime.timedelta(seconds=22873),
#   datetime.timedelta(seconds=2943),
#   datetime.timedelta(seconds=4456),
#   datetime.timedelta(seconds=14728),
#   datetime.timedelta(seconds=2260),
#   datetime.timedelta(seconds=202),
#   datetime.timedelta(seconds=6003),
#   datetime.timedelta(seconds=629)],
#  'human-515297173': [datetime.timedelta(days=4, seconds=8819),
#   datetime.timedelta(days=13, seconds=78633),
#   datetime.timedelta(days=9, seconds=22919),
#   datetime.timedelta(days=2, seconds=42081),
#   datetime.timedelta(seconds=15),
#   datetime.timedelta(seconds=332),
#   datetime.timedelta(seconds=992),
#   datetime.timedelta(days=11, seconds=19206),
#   datetime.timedelta(days=3, seconds=61259)],
#  'human-23201994': [],
#  'human-734492654755577858': [datetime.timedelta(seconds=34161),
#   datetime.timedelta(seconds=25),
# ...
#   datetime.timedelta(seconds=3593),
#   datetime.timedelta(seconds=4400),
#   datetime.timedelta(seconds=5200),
#   datetime.timedelta(seconds=188),
#   datetime.timedelta(seconds=88)],
#  'bot-877492293967773697': [datetime.timedelta(seconds=92),
#   datetime.timedelta(seconds=57),
#   datetime.timedelta(seconds=7298),
#   datetime.timedelta(seconds=199),
#   datetime.timedelta(seconds=15),
#   datetime.timedelta(seconds=61),
#   datetime.timedelta(seconds=26),
#   datetime.timedelta(seconds=99),
#   datetime.timedelta(days=-1, seconds=78553),
#   datetime.timedelta(seconds=92),
#   datetime.timedelta(seconds=57)],
#  'bot-490801600': [datetime.timedelta(days=53, seconds=12544),
#   datetime.timedelta(days=69, seconds=12314),
#   datetime.timedelta(days=710, seconds=69548),
#   datetime.timedelta(days=17, seconds=64109),
#   datetime.timedelta(days=10, seconds=23350),
#   datetime.timedelta(days=16, seconds=61560),
#   datetime.timedelta(days=39, seconds=22433),
#   datetime.timedelta(days=11, seconds=8677),
#   datetime.timedelta(days=2, seconds=73073)],
#  'bot-1342207069': [],
#  'human-277163970': [datetime.timedelta(days=146, seconds=4369),
#   datetime.timedelta(days=180, seconds=32192),
#   datetime.timedelta(days=86, seconds=61465),
#   datetime.timedelta(days=49, seconds=70017),
#   datetime.timedelta(days=2, seconds=14700),
#   datetime.timedelta(days=36, seconds=14423),
#   datetime.timedelta(days=17, seconds=71426),
#   datetime.timedelta(days=3, seconds=16484),
#   datetime.timedelta(days=15, seconds=58999)],
#  'human-1027986648947150848': [datetime.timedelta(days=3, seconds=64049),
#   datetime.timedelta(seconds=238),
#   datetime.timedelta(seconds=230),
#   datetime.timedelta(seconds=72),
#   datetime.timedelta(seconds=50),
#   datetime.timedelta(seconds=123),
#   datetime.timedelta(seconds=105),
#   datetime.timedelta(seconds=68),
#   datetime.timedelta(days=7, seconds=37964)],
#  'bot-2309880170': [datetime.timedelta(seconds=904),
#   datetime.timedelta(seconds=416),
#   datetime.timedelta(seconds=671),
#   datetime.timedelta(seconds=57),
#   datetime.timedelta(seconds=2687),
#   datetime.timedelta(seconds=323),
#   datetime.timedelta(seconds=60),
#   datetime.timedelta(seconds=22),
#   datetime.timedelta(seconds=59)],
#  'human-376012638': [datetime.timedelta(days=5, seconds=8004),
#   datetime.timedelta(days=1, seconds=75939),
#   datetime.timedelta(days=2, seconds=56539),
#   datetime.timedelta(days=10, seconds=7583),
#   datetime.timedelta(days=1, seconds=43410),
#   datetime.timedelta(days=6, seconds=38557),
#   datetime.timedelta(days=7, seconds=78015),
#   datetime.timedelta(days=4, seconds=67008),
#   datetime.timedelta(days=6, seconds=67478)],
#  'human-1714082910': [datetime.timedelta(seconds=4),
#   datetime.timedelta(days=8, seconds=14638),
#   datetime.timedelta(seconds=23),
#   datetime.timedelta(days=19, seconds=31992),
#   datetime.timedelta(seconds=12),
#   datetime.timedelta(seconds=40),
#   datetime.timedelta(days=3, seconds=28297),
#   datetime.timedelta(days=39, seconds=56687),
#   datetime.timedelta(days=7, seconds=4045)],
#  'bot-865887312407822336': [datetime.timedelta(seconds=509),
#   datetime.timedelta(days=74, seconds=45866),
#   datetime.timedelta(days=43, seconds=47531),
#   datetime.timedelta(days=8, seconds=82455),
#   datetime.timedelta(days=8, seconds=47354),
#   datetime.timedelta(days=7, seconds=48735),
#   datetime.timedelta(days=7, seconds=45175),
#   datetime.timedelta(days=1, seconds=3771)],
#  'human-74795417': [datetime.timedelta(days=86, seconds=73169),
#   datetime.timedelta(days=14, seconds=73939),
#   datetime.timedelta(0),
#   datetime.timedelta(days=4, seconds=7767),
#   datetime.timedelta(seconds=43),
#   datetime.timedelta(seconds=41),
#   datetime.timedelta(seconds=74),
#   datetime.timedelta(seconds=70894),
#   datetime.timedelta(seconds=6)],
#  'human-620708877': [datetime.timedelta(days=25, seconds=16565),
#   datetime.timedelta(days=5, seconds=12331),
#   datetime.timedelta(seconds=21),
#   datetime.timedelta(seconds=27),
#   datetime.timedelta(seconds=19),
#   datetime.timedelta(seconds=22),
#   datetime.timedelta(seconds=22),
#   datetime.timedelta(seconds=19),
#   datetime.timedelta(seconds=25)],
#  'bot-852562204607913984': [datetime.timedelta(seconds=9356),
#   datetime.timedelta(seconds=1360),
#   datetime.timedelta(seconds=909),
#   datetime.timedelta(seconds=290),
#   datetime.timedelta(seconds=8500),
#   datetime.timedelta(seconds=1565),
#   datetime.timedelta(seconds=2634),
#   datetime.timedelta(seconds=6021)],
#  'bot-2332583791': [datetime.timedelta(days=3, seconds=57701),
#   datetime.timedelta(seconds=21),
#   datetime.timedelta(days=10, seconds=18699),
#   datetime.timedelta(seconds=10),
#   datetime.timedelta(seconds=533),
#   datetime.timedelta(seconds=55),
#   datetime.timedelta(seconds=83),
#   datetime.timedelta(seconds=27),
#   datetime.timedelta(seconds=81)],
#  'human-72131142': [datetime.timedelta(seconds=40179),
#   datetime.timedelta(seconds=5525),
#   datetime.timedelta(seconds=270),
#   datetime.timedelta(seconds=60),
#   datetime.timedelta(seconds=160),
#   datetime.timedelta(seconds=137),
#   datetime.timedelta(seconds=225),
#   datetime.timedelta(seconds=1933),
#   datetime.timedelta(seconds=207)],
#  'bot-1144796250': [],
#  'bot-1661404440': [datetime.timedelta(seconds=3161),
#   datetime.timedelta(seconds=22),
#   datetime.timedelta(seconds=44),
#   datetime.timedelta(seconds=43),
#   datetime.timedelta(seconds=190),
#   datetime.timedelta(seconds=2544),
#   datetime.timedelta(seconds=12384),
#   datetime.timedelta(seconds=2965),
#   datetime.timedelta(seconds=438)],
#  'human-312751823': [datetime.timedelta(seconds=16),
#   datetime.timedelta(seconds=6246),
#   datetime.timedelta(seconds=26983),
#   datetime.timedelta(seconds=75),
#   datetime.timedelta(seconds=29044),
#   datetime.timedelta(days=1, seconds=13489),
#   datetime.timedelta(seconds=1300),
#   datetime.timedelta(seconds=398),
#   datetime.timedelta(seconds=13946)],
#  'human-14312300': [],
#  'bot-57858524': [datetime.timedelta(seconds=422),
#   datetime.timedelta(seconds=2419),
#   datetime.timedelta(seconds=2576),
#   datetime.timedelta(seconds=659)],
#  'human-62915097': [datetime.timedelta(seconds=690),
#   datetime.timedelta(seconds=168),
#   datetime.timedelta(seconds=394),
#   datetime.timedelta(seconds=65008),
#   datetime.timedelta(seconds=67),
#   datetime.timedelta(seconds=303),
#   datetime.timedelta(seconds=36),
#   datetime.timedelta(seconds=224),
#   datetime.timedelta(seconds=116)],
#  'human-840642788': [datetime.timedelta(days=10, seconds=86330),
#   datetime.timedelta(days=2, seconds=86393),
#   datetime.timedelta(days=17, seconds=86314),
#   datetime.timedelta(days=17, seconds=86106),
#   datetime.timedelta(days=2, seconds=86231),
#   datetime.timedelta(days=42, seconds=7),
#   datetime.timedelta(days=12, seconds=770),
#   datetime.timedelta(days=1, seconds=86084),
#   datetime.timedelta(days=3, seconds=86370)],
#  'human-1877152158': [datetime.timedelta(days=3, seconds=56554),
#   datetime.timedelta(days=23, seconds=44574),
#   datetime.timedelta(seconds=47583),
#   datetime.timedelta(days=9, seconds=32287),
#   datetime.timedelta(days=8, seconds=59826),
#   datetime.timedelta(seconds=459),
#   datetime.timedelta(days=5, seconds=82160)],
#  'human-15146558': [datetime.timedelta(seconds=15),
#   datetime.timedelta(seconds=7378),
#   datetime.timedelta(seconds=5622),
#   datetime.timedelta(seconds=14826),
#   datetime.timedelta(seconds=50806),
#   datetime.timedelta(seconds=233),
#   datetime.timedelta(seconds=15856),
#   datetime.timedelta(seconds=1786),
#   datetime.timedelta(seconds=9734)],
#  'human-1909134048': [datetime.timedelta(days=77, seconds=30066),
#   datetime.timedelta(days=4, seconds=84245),
#   datetime.timedelta(days=7, seconds=63044),
#   datetime.timedelta(days=93, seconds=19809),
#   datetime.timedelta(days=6, seconds=14146),
#   datetime.timedelta(days=3, seconds=8402),
#   datetime.timedelta(seconds=1457),
#   datetime.timedelta(days=1, seconds=75657),
#   datetime.timedelta(days=1, seconds=4223)],
#  'human-283068083': [datetime.timedelta(seconds=81255),
#   datetime.timedelta(days=1, seconds=5789),
#   datetime.timedelta(seconds=232),
#   datetime.timedelta(seconds=50),
#   datetime.timedelta(seconds=23),
#   datetime.timedelta(seconds=21),
#   datetime.timedelta(seconds=5226),
#   datetime.timedelta(seconds=162),
#   datetime.timedelta(seconds=70)],
#  'human-44551682': [datetime.timedelta(seconds=53),
#   datetime.timedelta(seconds=35),
#   datetime.timedelta(seconds=52),
#   datetime.timedelta(seconds=29),
#   datetime.timedelta(seconds=9218),
#   datetime.timedelta(seconds=69),
#   datetime.timedelta(seconds=10946),
#   datetime.timedelta(seconds=31),
#   datetime.timedelta(seconds=76406)],
#  'human-436366250': [datetime.timedelta(seconds=1958),
#   datetime.timedelta(seconds=3750),
#   datetime.timedelta(seconds=6260),
#   datetime.timedelta(seconds=1961),
#   datetime.timedelta(seconds=1618),
#   datetime.timedelta(seconds=300),
#   datetime.timedelta(seconds=1042),
#   datetime.timedelta(seconds=22476),
#   datetime.timedelta(seconds=46825)],
#  'bot-238503376': [datetime.timedelta(seconds=927),
#   datetime.timedelta(seconds=3773),
#   datetime.timedelta(seconds=1166),
#   datetime.timedelta(seconds=6118),
#   datetime.timedelta(seconds=9870),
#   datetime.timedelta(seconds=4715),
#   datetime.timedelta(seconds=6476)],
#  'human-315476130': [datetime.timedelta(days=3, seconds=54614),
#   datetime.timedelta(days=35, seconds=2088),
#   datetime.timedelta(days=965, seconds=29818),
#   datetime.timedelta(seconds=104),
#   datetime.timedelta(seconds=78190),
#   datetime.timedelta(days=13, seconds=4963),
#   datetime.timedelta(days=1, seconds=69495),
#   datetime.timedelta(seconds=4),
#   datetime.timedelta(days=41, seconds=25480)],
#  'human-775162575420002306': [datetime.timedelta(seconds=6588),
#   datetime.timedelta(seconds=7672),
#   datetime.timedelta(seconds=399),
#   datetime.timedelta(seconds=1845),
#   datetime.timedelta(seconds=25479),
#   datetime.timedelta(seconds=3291),
#   datetime.timedelta(seconds=60499),
#   datetime.timedelta(seconds=8500),
#   datetime.timedelta(seconds=10838),
#   datetime.timedelta(days=6, seconds=40590),
#   datetime.timedelta(seconds=142),
#   datetime.timedelta(seconds=4),
#   datetime.timedelta(seconds=315),
#   datetime.timedelta(seconds=386),
#   datetime.timedelta(seconds=85598),
#   datetime.timedelta(seconds=400),
#   datetime.timedelta(seconds=1215),
#   datetime.timedelta(seconds=59),
#   datetime.timedelta(days=1, seconds=25434)],
#  'human-25068919': [datetime.timedelta(seconds=1223),
#   datetime.timedelta(seconds=30412),
#   datetime.timedelta(seconds=7362),
#   datetime.timedelta(seconds=10374),
#   datetime.timedelta(seconds=40954),
#   datetime.timedelta(seconds=3019),
#   datetime.timedelta(seconds=14057),
#   datetime.timedelta(seconds=15575),
#   datetime.timedelta(seconds=3022)],
#  'bot-363852718': [datetime.timedelta(days=3, seconds=9293),
#   datetime.timedelta(seconds=1606),
#   datetime.timedelta(days=8, seconds=20127),
#   datetime.timedelta(days=1, seconds=25231),
#   datetime.timedelta(seconds=109),
#   datetime.timedelta(seconds=2309)],
#  'bot-743565374499749888': [],
#  'human-28474662': [datetime.timedelta(days=2, seconds=68951),
#   datetime.timedelta(days=1, seconds=6084),
#   datetime.timedelta(days=4, seconds=8165),
#   datetime.timedelta(days=1, seconds=4907),
#   datetime.timedelta(days=1, seconds=84743),
#   datetime.timedelta(days=1, seconds=77719),
#   datetime.timedelta(days=2, seconds=71214),
#   datetime.timedelta(seconds=25320),
#   datetime.timedelta(seconds=4036)],
#  'bot-1698808080': [datetime.timedelta(days=255, seconds=28126),
#   datetime.timedelta(days=12, seconds=6373),
#   datetime.timedelta(days=8, seconds=53867),
#   datetime.timedelta(seconds=47390),
#   datetime.timedelta(days=28, seconds=83748),
#   datetime.timedelta(days=3, seconds=69999),
#   datetime.timedelta(days=9, seconds=65291),
#   datetime.timedelta(days=5, seconds=73250),
#   datetime.timedelta(days=129, seconds=1862)],
#  'bot-84114859': [datetime.timedelta(seconds=318),
#   datetime.timedelta(seconds=302),
#   datetime.timedelta(seconds=1094),
#   datetime.timedelta(seconds=154),
#   datetime.timedelta(seconds=26),
#   datetime.timedelta(seconds=85468),
#   datetime.timedelta(seconds=25)],
#  'bot-2491336532': [datetime.timedelta(days=1, seconds=76961),
#   datetime.timedelta(seconds=77),
#   datetime.timedelta(seconds=775),
#   datetime.timedelta(seconds=200),
#   datetime.timedelta(seconds=1990),
#   datetime.timedelta(seconds=12),
#   datetime.timedelta(seconds=140)],
#  'human-368549815': [datetime.timedelta(seconds=44),
#   datetime.timedelta(days=1, seconds=14278),
#   datetime.timedelta(days=4, seconds=77775),
#   datetime.timedelta(days=1, seconds=10768),
#   datetime.timedelta(days=1, seconds=84937),
#   datetime.timedelta(days=3, seconds=80900),
#   datetime.timedelta(seconds=45424),
#   datetime.timedelta(seconds=38215),
#   datetime.timedelta(days=1, seconds=3504)],
#  'human-890657462512123904': [datetime.timedelta(seconds=96),
#   datetime.timedelta(seconds=6283),
#   datetime.timedelta(seconds=192),
#   datetime.timedelta(seconds=27),
#   datetime.timedelta(seconds=28)],
#  'human-3924259581': [],
#  'human-951241980859830272': [datetime.timedelta(days=212, seconds=72403),
#   datetime.timedelta(days=7, seconds=180),
#   datetime.timedelta(seconds=63),
#   datetime.timedelta(days=27, seconds=84852),
#   datetime.timedelta(seconds=20),
#   datetime.timedelta(seconds=54),
#   datetime.timedelta(days=2, seconds=9860),
#   datetime.timedelta(days=1, seconds=1503),
#   datetime.timedelta(seconds=1)],
#  'bot-229030007': [datetime.timedelta(seconds=18),
#   datetime.timedelta(seconds=27),
#   datetime.timedelta(seconds=17),
#   datetime.timedelta(seconds=306),
#   datetime.timedelta(seconds=22),
#   datetime.timedelta(seconds=109),
#   datetime.timedelta(seconds=54),
#   datetime.timedelta(seconds=160)],
#  'human-37355062': [datetime.timedelta(seconds=9120),
#   datetime.timedelta(seconds=1188),
#   datetime.timedelta(days=2, seconds=74726),
#   datetime.timedelta(days=1, seconds=85437),
#   datetime.timedelta(seconds=2452),
#   datetime.timedelta(days=6, seconds=82640),
#   datetime.timedelta(seconds=9040),
#   datetime.timedelta(days=7, seconds=82063),
#   datetime.timedelta(seconds=3210)],
#  'human-2977616300': [datetime.timedelta(seconds=62190),
#   datetime.timedelta(days=8, seconds=9286),
#   datetime.timedelta(seconds=5117),
#   datetime.timedelta(days=14, seconds=76451),
#   datetime.timedelta(days=5, seconds=3532),
#   datetime.timedelta(days=7, seconds=1180),
#   datetime.timedelta(days=21, seconds=24040),
#   datetime.timedelta(seconds=36),
#   datetime.timedelta(seconds=65721)],
#  'bot-4111400352': [datetime.timedelta(days=6, seconds=23398),
#   datetime.timedelta(seconds=23040),
#   datetime.timedelta(seconds=176),
#   datetime.timedelta(seconds=2520),
#   datetime.timedelta(seconds=544),
#   datetime.timedelta(seconds=239),
#   datetime.timedelta(seconds=67074)],
#  'bot-280986369': [datetime.timedelta(seconds=3600),
#   datetime.timedelta(seconds=3600),
#   datetime.timedelta(seconds=3601),
#   datetime.timedelta(seconds=3599),
#   datetime.timedelta(seconds=3600),
#   datetime.timedelta(seconds=3599),
#   datetime.timedelta(seconds=3601),
#   datetime.timedelta(seconds=3601),
#   datetime.timedelta(seconds=3599)],
#  'human-305763080': [datetime.timedelta(seconds=8521),
#   datetime.timedelta(days=9, seconds=9922),
#   datetime.timedelta(days=4, seconds=68291),
#   datetime.timedelta(seconds=11470),
#   datetime.timedelta(days=2, seconds=62471),
#   datetime.timedelta(seconds=201),
#   datetime.timedelta(seconds=106),
#   datetime.timedelta(days=1, seconds=41674),
#   datetime.timedelta(days=2, seconds=41590)],
#  'bot-865479344923197440': [datetime.timedelta(seconds=88),
#   datetime.timedelta(seconds=215),
#   datetime.timedelta(days=4, seconds=190),
#   datetime.timedelta(seconds=131),
#   datetime.timedelta(days=3, seconds=25589),
#   datetime.timedelta(seconds=174),
#   datetime.timedelta(seconds=52),
#   datetime.timedelta(seconds=81),
#   datetime.timedelta(seconds=63)],
#  'human-1643500784': [datetime.timedelta(seconds=125),
#   datetime.timedelta(seconds=121),
#   datetime.timedelta(seconds=49),
#   datetime.timedelta(seconds=29),
#   datetime.timedelta(seconds=1099),
#   datetime.timedelta(seconds=199),
#   datetime.timedelta(seconds=275),
#   datetime.timedelta(seconds=45),
#   datetime.timedelta(seconds=198)],
#  ...}

# %%
tweets_dataset.loc[tweets_dataset["account_id"]==370890435]
# Out:
#                   id                               attachments  \
# 318164  8.986528e+17                                       NaN
# 318165  8.986501e+17                                       NaN
# 318166  8.986474e+17                                       NaN
# 318167  8.986257e+17                                       NaN
# 318168  8.986166e+17  {'media_keys': ['7_898506990661492736']}
# 318169  8.986085e+17                                       NaN
#
#                                       context_annotations  conversation_id  \
# 318164                                                NaN     8.986528e+17
# 318165  [{'domain': {'id': '67', 'name': 'Interests an...     8.986501e+17
# 318166  [{'domain': {'id': '67', 'name': 'Interests an...     8.986474e+17
# 318167                                                NaN     8.986257e+17
# 318168                                                NaN     8.986166e+17
# 318169                                                NaN     8.986085e+17
#
#                       created_at  account_id  in_reply_to_user_id lang  \
# 318164  2017-08-18T21:08:15.000Z   370890435                  NaN   en
# 318165  2017-08-18T20:57:42.000Z   370890435                  NaN   en
# 318166  2017-08-18T20:47:01.000Z   370890435                  NaN   en
# 318167  2017-08-18T19:20:44.000Z   370890435                  NaN  und
# 318168  2017-08-18T18:44:26.000Z   370890435                  NaN   ja
# 318169  2017-08-18T18:12:27.000Z   370890435                  NaN   en
#
#         retweet_count  reply_count  like_count  quote_count reply_settings  \
# 318164         8464.0          0.0         0.0          0.0       everyone
# 318165         1067.0          0.0         0.0          0.0       everyone
# 318166         1077.0          0.0         0.0          0.0       everyone
# 318167          114.0          0.0         0.0          0.0       everyone
# 318168          583.0          0.0         0.0          0.0       everyone
# 318169         1492.0          0.0         0.0          0.0       everyone
#
#                      source  \
# 318164  Twitter for Android
# 318165  Twitter for Android
# 318166  Twitter for Android
# 318167  Twitter for Android
# 318168  Twitter for Android
# 318169  Twitter for Android
#
#                                                      text  \
# 318164  RT @STU_ACTOR: Devastated to hear the Legend t...
# 318165  RT @LiveFunAndDiy: How to Make a Fidget Spinne...
# 318166  RT @LiveFunAndDiy: How to Make a Fidget Spinne...
# 318167          RT @GriffyOnline: https://t.co/YVPTddKqJ8
# 318168  RT @yuchaso_prince: だまされた... https://t.co/299z...
# 318169  RT @yashqaraah: Just upload it boosting testos...
#
#                              mentions                      hashtags  \
# 318164                  ['STU_ACTOR']                            []
# 318165  ['lifehacker', 'lifehackorg']                 ['LifeHacks']
# 318166         ['vidme', 'VidmeClub']  ['vidme', 'TUTORIAL', 'DIY']
# 318167               ['GriffyOnline']                            []
# 318168             ['yuchaso_prince']                            []
# 318169                 ['yashqaraah']                            []
#
#                                                      urls
# 318164                                                 []
# 318165                   ['https://youtu.be/r0ZavqtlaHc']
# 318166                           ['https://vid.me/88Ua8']
# 318167                         ['http://fb.me/3TdZw7vq4']
# 318168  ['https://twitter.com/yuchaso_prince/status/89...
# 318169                              ['http://7stage.com']

# %%
tweets_dataset.loc[tweets_dataset.id.duplicated()==True & tweets_dataset.id.notna()].id.tolist()
# Out:
# [nan,
#  9.008736941296558e+17,
#  9.008798058219232e+17,
#  9.132059093204582e+17,
#  9.155896056209777e+17,
#  9.13209194660094e+17,
#  1.5242131162710958e+18,
#  1.5241623185604813e+18,
#  1.5240927956731863e+18,
#  1.523406809070854e+18,
#  1.523406793006719e+18,
#  1.5233880541525238e+18,
#  1.5244732489933414e+18,
#  1.5237785974245335e+18,
#  1.5219099927391314e+18,
#  1.5246231223008174e+18,
#  1.5246229683824968e+18,
#  1.5246227021784556e+18,
#  1.090098464942248e+18,
#  1.524422067147391e+18,
#  1.5245424434539643e+18,
#  1.5244647353784607e+18,
#  1.5241146251759045e+18,
#  1.5237500248778015e+18,
#  1.4208873236848353e+18,
#  1.302777144519557e+18,
#  1.2838670053686395e+18,
#  1.5220004835394724e+18,
#  1.5238978376202404e+18,
#  1.5245352665011036e+18,
#  1.524531015183929e+18,
#  1.5245303890582118e+18,
#  1.52346304635349e+18,
#  1.524608902528123e+18,
#  1.5245990933933384e+18,
#  1.524583918393082e+18,
#  1.5245684685610516e+18,
#  1.5219689797990728e+18,
#  1.521616786508206e+18,
#  1.4865361186025062e+18,
#  1.5178318339620946e+18,
#  1.5230391030333645e+18,
#  1.520928334997168e+18,
#  1.5012690150076908e+18,
#  1.0773663263337062e+18,
#  1.077362451367297e+18,
#  1.5243583253868585e+18,
#  1.5073544296909783e+18,
#  1.5246078930135532e+18,
#  1.5246015860682056e+18,
#  1.5245808003221012e+18,
#  1.5245802206274683e+18,
#  1.524577015537492e+18,
#  1.5245732854045286e+18,
#  1.5245211401018245e+18,
#  1.524531513756422e+18,
#  1.5245652701693665e+18,
#  1.5236734005979546e+18,
#  1.5236728839519724e+18,
#  1.5236678105008783e+18,
#  1.523667597920641e+18,
#  1.5245947706302956e+18,
#  1.523548430777262e+18,
#  1.5235481249621975e+18,
#  1.5218925951017984e+18,
#  1.5215421534822605e+18,
#  1.521542045294289e+18,
#  1.5215417637894636e+18,
#  1.3999829471434998e+18,
#  1.5246833128366162e+18,
#  1.5246682167185408e+18,
#  1.5246531156429496e+18,
#  1.5246380161359135e+18,
#  1.5245675849259663e+18,
#  1.5245674768556155e+18,
#  1.524567005608751e+18,
#  1.5245668825604506e+18,
#  1.5245661424880927e+18,
#  1.5245659831632568e+18,
#  1.5245654893216563e+18,
#  1.5245646881089372e+18,
#  1.5245639573270528e+18,
#  1.524550015712215e+18,
#  1.342587557222228e+18,
#  1.5196342996114514e+18,
#  1.524035492949418e+18,
#  1.5225819558832783e+18,
#  1.524580292668924e+18,
#  1.5245798974857953e+18,
#  1.5245793961825444e+18,
#  1.5245511589997036e+18,
#  1.5245473854892974e+18,
#  1.5245468246856335e+18,
#  1.2685194051697664e+18,
#  1.524683136847815e+18,
#  1.524482043417174e+18,
#  1.5243167880660296e+18,
#  1.524316474025857e+18,
#  1.5243164062962893e+18,
#  1.5241494889522586e+18,
#  1.52420824956996e+18,
#  1.524171097331143e+18,
#  1.5230746815988408e+18,
#  1.524619394135036e+18,
#  1.5246188938762076e+18,
#  1.524113081361703e+18,
#  1.5240432230936863e+18,
#  1.52404062211353e+18,
#  1.52404054134383e+18,
#  1.5237335046429368e+18,
#  1.5233397911311073e+18,
#  1.5230324510307983e+18,
#  1.141934661318394e+18,
#  1.5207632932914913e+18,
#  1.507015056495559e+18,
#  1.4842907559506985e+18,
#  1.5246075333185083e+18,
#  1.5195472973857464e+18,
#  1.5245483018355425e+18,
#  1.061308152623366e+18,
#  1.0613079060024689e+18,
#  1.524608526479417e+18,
#  1.5245986590311752e+18,
#  1.5245977740749742e+18,
#  1.5245977373202924e+18,
#  1.5245976716920586e+18,
#  1.5241469477996257e+18,
#  1.5230162446766735e+18,
#  1.0610637177549536e+18,
#  1.5245586706416435e+18,
#  1.5245396558987717e+18,
#  1.524525481776894e+18,
#  1.5172135252942848e+18,
#  1.5243618055476838e+18,
#  1.5241257041028465e+18,
#  1.524125692488827e+18,
#  1.523981040724947e+18,
#  1.5239803483292344e+18,
#  1.5226091422041457e+18,
#  1.521315469491376e+18,
#  1.5213143568305562e+18,
#  1.5213142926032325e+18,
#  1.521314215738458e+18,
#  1.5211246607457567e+18,
#  1.5192952612684923e+18,
#  1.5182846781423002e+18,
#  1.5182787431686226e+18,
#  1.5182744128223764e+18,
#  1.5182738281447877e+18,
#  1.5182727262465966e+18,
#  1.5182723800528568e+18,
#  1.5182664731641938e+18,
#  1.4377900405502566e+18,
#  1.5191493147607572e+18,
#  1.4899392306546196e+18,
#  1.485388405202686e+18,
#  9.462327097430304e+17,
#  9.385089857323377e+17,
#  9.385064977593016e+17,
#  9.316305710124442e+17,
#  9.306405253041192e+17,
#  9.294919970392556e+17,
#  1.478820579818025e+18,
#  1.4682489724395684e+18,
#  1.521308199915516e+18,
#  1.5196480399796142e+18,
#  1.5106358012769894e+18,
#  1.5048424638105846e+18,
#  1.0130585852224348e+18,
#  1.0127903842699468e+18,
#  8.876698984277156e+17,
#  8.876697458305516e+17,
#  9.668552571196047e+17,
#  9.510793359093556e+17,
#  9.510791900985796e+17,
#  9.510779646613628e+17,
#  9.510773862625198e+17,
#  9.51071836548358e+17,
#  8.986717748579615e+17,
#  8.986203454935409e+17,
#  8.986161882923131e+17,
#  8.986028939886019e+17,
#  8.985852883052913e+17,
#  1.5147380235058012e+18,
#  1.4574521864478474e+18,
#  1.4519563861375754e+18,
#  1.4465662580870103e+18,
#  1.359686185497424e+18,
#  9.484772526640456e+17,
#  9.47348715676713e+17,
#  1.362961907045466e+18,
#  1.4290935267558564e+18,
#  1.3874357729833247e+18,
#  1.5202053624563343e+18,
#  1.5201100243070812e+18,
#  1.5201067727987057e+18,
#  1.5198352913972388e+18,
#  1.3225229438769275e+18,
#  1.4990757229958554e+18,
#  1.515838913562169e+18,
#  1.5158388826711163e+18,
#  1.5158388690396283e+18,
#  1.515838855542362e+18,
#  1.5134760040227512e+18,
#  1.5133058035281592e+18,
#  1.3944484424250614e+18,
#  9.053482566532465e+17,
#  9.053184855673242e+17,
#  1.5213163052610191e+18,
#  1.504569355371266e+18,
#  1.4999334123580334e+18,
#  1.4992284001034363e+18,
#  1.4832664771804692e+18,
#  1.483208930729812e+18,
#  1.483208898622464e+18,
#  1.4816138766931927e+18,
#  1.4808871771647672e+18,
#  9.00879276588712e+17,
#  9.008788800845046e+17,
#  9.008592738776064e+17,
#  9.008477231501804e+17,
#  9.008464871937352e+17,
#  8.807213102965432e+17,
#  8.807212909901128e+17,
#  8.807208677890335e+17,
#  8.223186305912668e+17,
#  8.223185406738227e+17,
#  8.223179042972795e+17,
#  8.21219050646868e+17,
#  8.212189187778847e+17,
#  8.212188553600369e+17,
#  8.212188387967304e+17,
#  8.212183588425605e+17,
#  8.212181215791677e+17,
#  1.0678912063598428e+18,
#  1.0678899270383452e+18,
#  1.0678889911382098e+18,
#  1.0620856594758e+18,
#  1.0394740119804068e+18,
#  1.0288081841511096e+18,
#  1.0288076853266842e+18,
#  1.0288051644955116e+18,
#  1.0288051140295926e+18,
#  1.019248876249854e+18,
#  8.794207918672855e+17,
#  8.794182352124969e+17,
#  8.794167296754647e+17,
#  8.794111257790833e+17,
#  8.794097284591288e+17,
#  8.794072488623186e+17,
#  8.794055313828946e+17,
#  8.794032038839296e+17,
#  8.81246476650795e+17,
#  8.811860670758339e+17,
#  8.81171722459693e+17,
#  8.811667127452303e+17,
#  8.811206198986179e+17,
#  8.810174283348787e+17,
#  8.810116323520553e+17,
#  8.809847084855706e+17,
#  8.809814427962081e+17,
#  8.809791942088581e+17,
#  1.4433920996054835e+18,
#  1.292875436398203e+18,
#  1.2761189418328105e+18,
#  1.2761187361315594e+18,
#  1.2726870293615616e+18,
#  1.2717209526116475e+18,
#  1.2688848044451308e+18,
#  1.2688845979343053e+18,
#  1.2688843874935276e+18,
#  1.517279661021188e+18,
#  1.5078999674190766e+18,
#  1.5075673319831675e+18,
#  1.5038518654480138e+18,
#  1.502433871216128e+18,
#  1.498769378522841e+18,
#  1.494464380435669e+18,
#  1.484332233154388e+18,
#  1.5105146947125903e+18,
#  1.4651445017946522e+18,
#  1.442221931445502e+18,
#  1.432522704033403e+18,
#  1.4296178506380124e+18,
#  1.4285624650010337e+18,
#  1.4277883893534638e+18,
#  1.4271324501201142e+18,
#  1.421924880040276e+18,
#  8.986861629229507e+17,
#  8.986689039659704e+17,
#  8.986487600366756e+17,
#  8.986389488340664e+17,
#  8.986105703576453e+17,
#  8.985943277560218e+17,
#  8.985851014909788e+17,
#  8.985696259730391e+17,
#  8.806837314634179e+17,
#  8.806792928160358e+17,
#  8.806791705562112e+17,
#  8.806764251536056e+17,
#  8.80676403783639e+17,
#  8.806720996182344e+17,
#  8.806701787150295e+17,
#  8.806682984715182e+17,
#  1.52021630964412e+18,
#  1.5198844717005332e+18,
#  1.5191073083699896e+18,
#  1.5191068009010995e+18,
#  1.5190960838210478e+18,
#  1.51694431423189e+18,
#  8.807590857250816e+17,
#  8.807590351962563e+17,
#  8.807588832534569e+17,
#  8.807563214437745e+17,
#  8.807562939040809e+17,
#  8.807545423039488e+17,
#  8.80754439228973e+17,
#  8.807502381427876e+17,
#  1.5129387002499113e+18,
#  1.5067836012700877e+18,
#  1.4986974074203177e+18,
#  1.4986493486069432e+18,
#  1.4986459207616676e+18,
#  1.4980992877036216e+18,
#  1.4979870426340434e+18,
#  1.4978014976015278e+18,
#  1.4977175741922714e+18,
#  1.4976364794006487e+18,
#  8.880374930519941e+17,
#  8.880370209786593e+17,
#  8.880369347481682e+17,
#  8.880368806877921e+17,
#  8.880163188212163e+17,
#  8.88016267155841e+17,
#  8.880161073444536e+17,
#  8.880160577929462e+17,
#  8.880160081827348e+17,
#  1.188731147301376e+18,
#  1.188509302182613e+18,
#  1.1594584084640973e+18,
#  1.0455712004606976e+18,
#  1.0455698427100078e+18,
#  1.5212290989278126e+18,
#  1.517482144062341e+18,
#  1.515039005070426e+18,
#  1.514742623810257e+18,
#  1.5146836985782927e+18,
#  1.5139601031410156e+18,
#  1.5136688659930194e+18,
#  1.5121850457586524e+18,
#  1.5114999070178058e+18,
#  8.845043127301407e+17,
#  1.0618597667403776e+18,
#  1.0618595526547128e+18,
#  1.0618591377080074e+18,
#  1.2678811572253532e+18,
#  1.1323106425709076e+18,
#  1.1322824036726415e+18,
#  1.1322696096780616e+18,
#  1.1322532316046254e+18,
#  1.1322153526606193e+18,
#  1.1321910152200724e+18,
#  1.4662410190752563e+18,
#  1.3607223332967137e+18,
#  1.2671313961008497e+18,
#  1.2636843277386834e+18,
#  1.2534798223214223e+18,
#  1.2292124882159534e+18,
#  1.2265791397565153e+18,
#  1.2240216948824228e+18,
#  1.224021303927214e+18,
#  1.224016001546838e+18,
#  1.4320819266728223e+18,
#  1.4320806835188654e+18,
#  1.4320540898698445e+18,
#  8.807657299178496e+17,
#  8.807655975036969e+17,
#  8.807654298783252e+17,
#  8.807652966378619e+17,
#  8.807651971447726e+17,
#  8.807594073358787e+17,
#  8.807593692768092e+17,
#  8.807591516637553e+17,
#  8.807590736245146e+17,
#  8.731688790649324e+17,
#  8.729611622494618e+17,
#  8.729501487369748e+17,
#  8.7293122289229e+17,
#  8.729129310208287e+17,
#  8.728789786038968e+17,
#  1.070369999405994e+18,
#  1.0703676691471892e+18,
#  1.0703675058084168e+18,
#  1.0703674406079652e+18,
#  1.0703672776801935e+18,
#  1.059877437507539e+18,
#  1.0598474982132736e+18,
#  1.0598466066385142e+18,
#  1.0598459771027948e+18,
#  1.0598298042231194e+18,
#  1.4345636545995612e+18,
#  1.3045411887965798e+18,
#  1.304472293494739e+18,
#  8.876730596198973e+17,
#  8.876729597912801e+17,
#  8.876728577691361e+17,
#  8.876404577061765e+17,
#  8.876404224781722e+17,
#  8.876403998122025e+17,
#  8.876403566108713e+17,
#  8.876403339658199e+17,
#  1.521535084796461e+18,
#  1.0162997501723156e+18,
#  1.0124360254681252e+18,
#  1.0124360152550892e+18,
#  1.0124360097395712e+18,
#  1.0124360037416836e+18,
#  1.0124359995599462e+18,
#  1.0124359937299128e+18,
#  1.0124359897662464e+18,
#  1.514804496093778e+18,
#  1.4995040517546107e+18,
#  1.499256277184172e+18,
#  1.4962109331982991e+18,
#  1.4958157828272415e+18,
#  1.4898369859257385e+18,
#  1.4898357996926484e+18,
#  1.4672663602753536e+18,
#  1.479893020447101e+18,
#  1.4798929429112504e+18,
#  1.460653157210493e+18,
#  1.4436222903824097e+18,
#  1.40307414184294e+18,
#  1.4010603700688937e+18,
#  1.401059555128316e+18,
#  1.4006796012825518e+18,
#  1.5212853215095562e+18,
#  1.513739445979304e+18,
#  1.513735450413998e+18,
#  1.5137347271733535e+18,
#  1.5137341366237716e+18,
#  1.5104045838515364e+18,
#  1.5103988218215547e+18,
#  1.510384538207363e+18,
#  1.510382902575616e+18,
#  1.5103820484181893e+18,
#  1.4139963077614387e+18,
#  1.4139962503372104e+18,
#  1.4139962236027085e+18,
#  1.4136827659883889e+18,
#  1.4130621330178376e+18,
#  1.41306199278968e+18,
#  1.4129442121616712e+18,
#  1.412944036277674e+18,
#  9.049858804646912e+17,
#  9.049547132751954e+17,
#  9.049409581307249e+17,
#  9.049398135931616e+17,
#  9.04938413765288e+17,
#  9.049252844192522e+17,
#  8.880303660652831e+17,
#  8.880303024586588e+17,
#  8.880301523445596e+17,
#  8.880296740008755e+17,
#  8.880296149199094e+17,
#  8.88029464289878e+17,
#  8.880290198908928e+17,
#  9.053377621020426e+17,
#  9.053241667060696e+17,
#  9.05310123110871e+17,
#  9.052961362395054e+17,
#  9.052955950359142e+17,
#  9.05295048492843e+17,
#  1.4982638514140488e+18,
#  1.4982613540246815e+18,
#  1.4982539437591183e+18,
#  1.2892185149228155e+18,
#  1.2892184100484956e+18,
#  1.2838640842498253e+18,
#  1.2838635779846715e+18,
#  1.283861321067397e+18,
#  1.2838499465470607e+18,
#  8.812466385845412e+17,
#  1.5175808764811878e+18,
#  1.5175789233784504e+18,
#  1.514935365773185e+18,
#  1.5103422823686676e+18,
#  1.5099487039136973e+18,
#  1.5099485570586255e+18,
#  8.8286021074577e+17,
#  8.826080911575859e+17,
#  8.826079647621939e+17,
#  8.82607955408855e+17,
#  8.826055728345088e+17,
#  1.317420136035459e+18,
#  1.1791873030732145e+18,
#  1.1485326063105393e+18,
#  1.148532269222699e+18,
#  1.14851755319672e+18,
#  1.148517165961818e+18,
#  1.1485020677340896e+18,
#  1.1484873261228564e+18,
#  1.1484869693931316e+18,
#  1.5201041342335304e+18,
#  1.5139793246087004e+18,
#  1.48781150312226e+18,
#  1.485341107504431e+18,
#  1.4831108620260106e+18,
#  1.4575479741296845e+18,
#  1.0125930931730063e+18,
#  1.0125929347751526e+18,
#  1.0125929030200116e+18,
#  1.0125928541689404e+18,
#  1.5104064985638584e+18,
#  1.5100000844859064e+18,
#  1.509986234252374e+18,
#  1.4929778042286776e+18,
#  1.4346722758658826e+18,
#  1.4327157903111168e+18,
#  1.429968920648237e+18,
#  1.4265066543932457e+18,
#  1.4263681845092065e+18,
#  8.986218733778903e+17,
#  8.986118905191219e+17,
#  8.985794634152796e+17,
#  8.984973074646958e+17,
#  8.807210807338803e+17,
#  8.80718800697643e+17,
#  8.807186452399596e+17,
#  8.807132508407398e+17,
#  8.807087241926697e+17,
#  8.807083803478303e+17,
#  8.807080906849894e+17,
#  8.807051443961569e+17,
#  8.872749084090982e+17,
#  8.872747808435364e+17,
#  8.872747095823196e+17,
#  8.872746779908301e+17,
#  1.5099405515709358e+18,
#  1.50971411771571e+18,
#  1.5006938218852393e+18,
#  1.4798534366068572e+18,
#  1.4780810120558182e+18,
#  1.4780704229985608e+18,
#  1.4776900955452948e+18,
#  1.4776856677401969e+18,
#  1.4776854134269092e+18,
#  9.053377492841103e+17,
#  9.05324046149075e+17,
#  9.053104848612516e+17,
#  9.052972436573962e+17,
#  9.05297121825493e+17,
#  9.052967638164316e+17,
#  9.052959505954488e+17,
#  1.2701860339848888e+18,
#  1.2701854595707576e+18,
#  1.270184535905325e+18,
#  1.2369797188065894e+18,
#  1.2351975184864625e+18,
#  1.2351974565575885e+18,
#  1.2350624477922468e+18,
#  1.2317468594518303e+18,
#  8.812465901904937e+17,
#  9.667585224521728e+17,
#  9.667506579768975e+17,
#  9.667494600459428e+17,
#  9.667491008163922e+17,
#  9.66668774324736e+17,
#  9.666684398415832e+17,
#  1.5193779090766684e+18,
#  1.5193777110510264e+18,
#  1.5193776191621284e+18,
#  1.3237463176848876e+18,
#  1.3237415608534548e+18,
#  1.323736648010662e+18,
#  1.3237319599825756e+18,
#  1.3237290557331948e+18,
#  1.2917894320482796e+18,
#  1.2896915040767017e+18,
#  8.80721832441258e+17,
#  8.807215651088998e+17,
#  8.807207516949463e+17,
#  8.807188647824302e+17,
#  8.873553787275182e+17,
#  8.873552667900191e+17,
#  8.873552106702561e+17,
#  8.873549438621901e+17,
#  8.873548715775386e+17,
#  8.873548073584558e+17,
#  8.873547228013978e+17,
#  8.873545255264379e+17,
#  8.678436193900544e+17,
#  8.678151845130199e+17,
#  8.675755914569605e+17,
#  8.675560278221988e+17,
#  8.682865260562596e+17,
#  8.681882772113695e+17,
#  8.681362664492483e+17,
#  8.675887829330698e+17,
#  8.668252831056732e+17,
#  8.666952634188186e+17,
#  8.66653109476524e+17,
#  1.521258130222596e+18,
#  1.521203048844075e+18,
#  1.5197322298905764e+18,
#  1.5149910245354455e+18,
#  1.513506297756504e+18,
#  1.2147021509301084e+18,
#  1.2134614337128284e+18,
#  1.2134586081402757e+18,
#  1.2128750241195827e+18,
#  1.2114331050489733e+18,
#  1.2113512308045824e+18,
#  1.210994212696658e+18,
#  1.2099319768551752e+18,
#  1.209543437365764e+18,
#  1.2091532131753492e+18,
#  8.91206112057471e+17,
#  8.912053823995044e+17,
#  8.912052200841871e+17,
#  8.912045562768548e+17,
#  8.912043970275369e+17,
#  8.912041689537454e+17,
#  8.912040048307487e+17,
#  8.912038473303859e+17,
#  8.912037356612362e+17,
#  8.912033518069678e+17,
#  8.807208982731817e+17,
#  8.807188676513423e+17,
#  8.807188404009492e+17,
#  8.807187597780173e+17,
#  8.807107958642647e+17,
#  8.807065641890202e+17,
#  8.807063583409807e+17,
#  8.807063051655782e+17,
#  1.499740556997632e+18,
#  1.4332787132028232e+18,
#  1.2006304776625398e+18,
#  1.196589753883345e+18,
#  1.1945050405826437e+18,
#  1.190263035711152e+18,
#  1.188861396655792e+18,
#  1.158864588106023e+18,
#  1.1588644334494515e+18,
#  1.4205668448307978e+18,
#  1.4031804370491556e+18,
#  1.4023438792953528e+18,
#  1.3846322150872433e+18,
#  1.3519585362517156e+18,
#  1.3310561663786312e+18,
#  1.3221752113541366e+18,
#  1.3060254633877422e+18,
#  1.3056276101358346e+18,
#  1.3055570057640428e+18,
#  9.170689584901366e+17,
#  9.170677725252936e+17,
#  9.16675298346795e+17,
#  8.873416963920568e+17,
#  8.873416395215135e+17,
#  8.873410048100639e+17,
#  8.873408706762301e+17,
#  8.873407451448812e+17,
#  8.873403698008146e+17,
#  8.873400779987763e+17,
#  8.873086259659284e+17,
#  1.0773939556192625e+18,
#  1.0767771821046129e+18,
#  1.0764618663969096e+18,
#  1.0758553165485056e+18,
#  1.075208970695e+18,
#  9.72271671343272e+17,
#  9.722669831305748e+17,
#  9.722604693848924e+17,
#  9.715222980029686e+17,
#  8.807710796602409e+17,
#  8.8076782263219e+17,
#  8.807676722455265e+17,
#  8.807674949439078e+17,
#  8.807673105706762e+17,
#  8.807655690327532e+17,
#  8.807655370050478e+17,
#  8.807654762588938e+17,
#  1.5212788093199073e+18,
#  1.5211992805723095e+18,
#  1.5211969697582367e+18,
#  1.5208707748145275e+18,
#  8.807136782780129e+17,
#  8.807110067580887e+17,
#  8.807108554108109e+17,
#  8.80706937150636e+17,
#  8.807068063345746e+17,
#  8.806966813392691e+17,
#  8.80694279223595e+17,
#  8.806918169784074e+17,
#  1.0242686643952476e+18,
#  1.0240065679334892e+18,
#  1.0240065250844754e+18,
#  1.0240064852344054e+18,
#  1.0236619059347784e+18,
#  1.022958406339113e+18,
#  1.5159994966181028e+18,
#  1.5159987144307302e+18,
#  1.5127826549612462e+18,
#  1.5101560017224417e+18,
#  1.5061828552438415e+18,
#  1.5061828127260918e+18,
#  1.50618267139063e+18,
#  1.5061825590630605e+18,
#  1.1814124782000824e+18,
#  8.869702098142003e+17,
#  8.869697442003927e+17,
#  8.869416407446077e+17,
#  8.869082015386501e+17,
#  8.86908082441388e+17,
#  8.869079718417777e+17,
#  8.869079430562898e+17,
#  8.880374900320379e+17,
#  8.880368955104584e+17,
#  8.88036817139839e+17,
#  8.880367387651318e+17,
#  8.880366837987738e+17,
#  8.88016409061544e+17,
#  8.880163464238694e+17,
#  8.880161872667484e+17,
#  9.722910771043738e+17,
#  9.722885334561792e+17,
#  9.722875853295985e+17,
#  9.722875035406705e+17,
#  9.722874700659302e+17,
#  9.722873671754342e+17,
#  9.71913024356352e+17,
#  8.68424954467029e+17,
#  8.6829599169024e+17,
#  8.675819519931392e+17,
#  8.675589667332628e+17,
#  8.673760139987395e+17,
#  8.672059040595108e+17,
#  8.67114914279809e+17,
#  8.667683308746056e+17,
#  8.665823270691594e+17,
#  9.725473000975892e+17,
#  9.725389841349468e+17,
#  9.725386681444762e+17,
#  9.723081769126912e+17,
#  9.723016786062418e+17,
#  9.718376425507922e+17,
#  9.718370034017812e+17,
#  9.050500657268204e+17,
#  9.050493698498478e+17,
#  9.050436657262264e+17,
#  8.782949710565089e+17,
#  8.782864234130555e+17,
#  8.90786284599337e+17,
#  8.907855121553818e+17,
#  8.907847545632973e+17,
#  8.907840220658565e+17,
#  8.900418704993608e+17,
#  8.900396068752671e+17,
#  8.899882593460961e+17,
#  8.89840288100778e+17,
#  8.897444274508513e+17,
#  9.008827057593508e+17,
#  9.00857691391746e+17,
#  9.008529281765622e+17,
#  9.008480321612104e+17,
#  9.008070804827914e+17,
#  1.1601945115423744e+18,
#  1.1508897514965934e+18,
#  1.1503730309520916e+18,
#  1.1288731209479332e+18,
#  1.1288728847625462e+18,
#  8.873416937914778e+17,
#  8.873416342406513e+17,
#  8.87340996123476e+17,
#  8.873408714771128e+17,
#  8.873407184605184e+17,
#  8.873403518909235e+17,
#  8.873399739213005e+17,
#  8.872557139401564e+17,
#  8.872556567341015e+17,
#  1.5191354183269622e+18,
#  1.5183455290166927e+18,
#  1.5155799215564554e+18,
#  1.5155784002741084e+18,
#  1.515578346515538e+18,
#  1.5155783097147924e+18,
#  1.5155782623275418e+18,
#  1.5155782266844406e+18,
#  8.807559148270592e+17,
#  8.807547239970693e+17,
#  8.807503064384635e+17,
#  8.807484045061898e+17,
#  8.807437975246356e+17,
#  8.807417028304036e+17,
#  8.807407880024474e+17,
#  8.807390154559857e+17,
#  8.873334677756969e+17,
#  8.873333235587482e+17,
#  8.873330519567032e+17,
#  8.873325933934469e+17,
#  8.873322787157729e+17,
#  8.873318147963986e+17,
#  8.873315054203453e+17,
#  8.873313045802721e+17,
#  8.87331036748628e+17,
#  1.2693523961125888e+18,
#  8.986345954360443e+17,
#  8.98608195232555e+17,
#  8.985690029681336e+17,
#  8.985633117547192e+17,
#  8.985554004501914e+17,
#  8.985168176935526e+17,
#  1.516576645368275e+18,
#  1.5161584291983155e+18,
#  1.5161575485412762e+18,
#  1.516157529214288e+18,
#  1.5143065807155077e+18,
#  1.514304578002428e+18,
#  1.512218165903696e+18,
#  1.5099932145137172e+18,
#  1.5215316796131123e+18,
#  1.5161636663113646e+18,
#  1.4704840491898675e+18,
#  1.4689974863375647e+18,
#  1.4689896182216827e+18,
#  1.468982770596823e+18,
#  1.4689760257196933e+18,
#  1.468961846942077e+18,
#  1.308124251313107e+18,
#  1.2125881817130148e+18,
#  1.2125088646351954e+18,
#  1.1245057938968207e+18,
#  1.1241552687770214e+18,
#  1.1237794705051484e+18,
#  1.1143045527597138e+18,
#  1.112725298762711e+18,
#  8.877046521622241e+17,
#  8.877045724410921e+17,
#  8.877044203682079e+17,
#  8.876891012431749e+17,
#  8.876890610072044e+17,
#  8.876886917364285e+17,
#  8.87688433426088e+17,
#  9.050864346249052e+17,
#  9.050843807035474e+17,
#  9.050807067491328e+17,
#  9.050802858548838e+17,
#  8.915845137630372e+17,
#  8.915840846060462e+17,
#  8.915833243967324e+17,
#  8.915831909885051e+17,
#  8.915700719773368e+17,
#  8.915697920075489e+17,
#  8.915558140451021e+17,
#  8.915556099167027e+17,
#  9.287281917573734e+17,
#  9.287275411788636e+17,
#  9.287252447513436e+17,
#  9.287242351865078e+17,
#  9.287214459533926e+17,
#  1.4957826001321574e+18,
#  1.4954868575761326e+18,
#  1.4773137163917517e+18,
#  1.474824231833809e+18,
#  1.4693039455751086e+18,
#  1.464814621781631e+18,
#  1.4599554957967196e+18,
#  1.4560130119661773e+18,
#  1.453882890002092e+18,
#  1.1335019687842652e+18,
#  1.1334994546219254e+18,
#  1.1334692558386504e+18,
#  1.1333786618502636e+18,
#  1.1333459608122696e+18,
#  1.1332012408196874e+18,
#  1.133139579677139e+18,
#  1.1331068626798428e+18,
#  1.2041168389358633e+18,
#  1.1870520641965302e+18,
#  1.164282037311877e+18,
#  1.1530294264158822e+18,
#  1.1490946785218888e+18,
#  1.1429246301953434e+18,
#  1.1422210133521572e+18,
#  1.1421893739009352e+18,
#  8.806612270719959e+17,
#  8.806611080125932e+17,
#  8.80660504032809e+17,
#  8.806544705055416e+17,
#  8.806502241082819e+17,
#  8.806501758862623e+17,
#  8.806474555320975e+17,
#  8.80645400830632e+17,
#  8.806452877018194e+17,
#  1.4787555118560993e+18,
#  1.4784650863478866e+18,
#  1.4574124649082716e+18,
#  1.4539088842555064e+18,
#  1.4534570459826422e+18,
#  1.3723618577055048e+18,
#  1.1099619841522074e+18,
#  1.0676530279122862e+18,
#  9.053475390624522e+17,
#  9.053329056223478e+17,
#  9.053160926792049e+17,
#  9.053152938866033e+17,
#  1.4965995287781294e+18,
#  1.4965960737160684e+18,
#  1.4965929301313577e+18,
#  1.4913728251014554e+18,
#  1.491038390657114e+18,
#  1.4906798287852913e+18,
#  1.4895733902351483e+18,
#  1.48957334742392e+18,
#  1.382656481762349e+18,
#  1.3826564279536517e+18,
#  8.816577407409193e+17,
#  8.816576988021678e+17,
#  8.816569730281513e+17,
#  8.8165694837828e+17,
#  9.226768154869678e+17,
#  8.779998829166428e+17,
#  8.7510316803149e+17,
#  8.73242024920703e+17,
#  8.710772539412111e+17,
#  8.69371206079787e+17,
#  1.5217415533618422e+18,
#  1.5216840588072346e+18,
#  1.5216249041430405e+18,
#  8.876404113127588e+17,
#  8.876402906258596e+17,
#  8.876402411414569e+17,
#  8.876401463251026e+17,
#  8.876401039500739e+17,
#  8.876400301260227e+17,
#  8.876399628493947e+17,
#  9.053552203682038e+17,
#  9.053498737882112e+17,
#  1.3074095084325765e+18,
#  1.3074094575850332e+18,
#  1.2305692981559706e+18,
#  1.2291754025365422e+18,
#  1.2291753941270405e+18,
#  1.2291753847317258e+18,
#  1.2258782558001357e+18,
#  1.2257511565734707e+18,
#  1.2257511485288817e+18,
#  1.2257511356816876e+18,
#  8.81634270128812e+17,
#  8.816342366918697e+17,
#  8.816341548148613e+17,
#  8.816339787840225e+17,
#  8.816339549688668e+17,
#  8.816335615053865e+17,
#  8.816335043244646e+17,
#  8.816334781561446e+17,
#  9.080675228004844e+17,
#  9.077948560341402e+17,
#  9.077925383666033e+17,
#  9.077533666038702e+17,
#  9.072623021305078e+17,
#  9.067674817375314e+17,
#  9.06445641840296e+17,
#  9.007835608435057e+17,
#  8.876731711508644e+17,
#  8.876730403934249e+17,
#  8.876729118506025e+17,
#  1.5216779380218388e+18,
#  1.5063182862077338e+18,
#  1.519731182895829e+18,
#  1.517202424678789e+18,
#  1.5134393060603863e+18,
#  8.869751101748265e+17,
#  8.869750412121088e+17,
#  8.869744018322964e+17,
#  8.86940900919849e+17,
#  1.091175910567334e+18,
#  8.876730752941015e+17,
#  8.876728484325499e+17,
#  8.876727068412969e+17,
#  1.519282967293702e+18,
#  1.51922435532621e+18,
#  1.5192217008770744e+18,
#  1.5192202015433728e+18,
#  1.519134707253977e+18,
#  1.5191337074618696e+18,
#  1.4867260162822144e+18,
#  1.4867241131335557e+18,
#  1.4867229127405158e+18,
#  1.4803129977132687e+18,
#  1.5149377096635638e+18,
#  1.5162735529908677e+18,
#  1.5082970958533222e+18,
#  1.5082967165079224e+18,
#  1.5215580103085343e+18,
#  1.5070510882011013e+18,
#  1.5070508571116913e+18,
#  1.4887673669347123e+18,
#  8.922675583337636e+17,
#  1.5190350170784522e+18,
#  ...]

# %%
tweets_dataset.loc[tweets_dataset["id"].astype(str)=='9.008736941296558e+17']
# Out:
#                  id attachments  \
# 20086  9.008737e+17         NaN
# 51620  9.008737e+17         NaN
#
#                                      context_annotations  conversation_id  \
# 20086  [{'domain': {'id': '45', 'name': 'Brand Vertic...     9.008737e+17
# 51620  [{'domain': {'id': '13', 'name': 'Place', 'des...     9.008737e+17
#
#                      created_at  account_id  in_reply_to_user_id lang  \
# 20086  2017-08-25T00:13:20.000Z  2283108739                  NaN   en
# 51620  2017-08-25T00:13:20.000Z  4928186374                  NaN   en
#
#        retweet_count  reply_count  like_count  quote_count reply_settings  \
# 20086          400.0          0.0         0.0          0.0       everyone
# 51620         1230.0          0.0         0.0          0.0       everyone
#
#                     source                                               text  \
# 20086  Twitter for Android  RT @every1bets: Giovannis Gems Slots Is LIVE W...
# 51620  Twitter for Android  RT @mohitfreedom: High Commissioner of #India ...
#
#                                mentions  \
# 20086                    ['every1bets']
# 51620  ['RuchiraKamboj', 'SAPresident']
#
#                                                 hashtags  \
# 20086  ['free', 'casino', 'slots', 'games', 'xbox', '...
# 51620                           ['India', 'SouthAfrica']
#
#                                   urls
# 20086  ['http://bit.ly/blackdiamond7']
# 51620                               []

# %%
from twitter_account_enrichment import *
tweets_per_account = get_accounts_tweets([370890435])
# Out:
# 200

# %%
tweets_per_account[370890435]
# Out:
# [{'created_at': '2017-08-18T21:08:15.000Z',
#   'source': 'Twitter for Android',
#   'lang': 'en',
#   'public_metrics': {'retweet_count': 8460,
#    'reply_count': 0,
#    'like_count': 0,
#    'quote_count': 0},
#   'text': 'RT @STU_ACTOR: Devastated to hear the Legend that is Sir Bruce Forsyth has sadly passed away. A true gent and a talent beyond compare #RIPB…',
#   'id': '898652788011352064',
#   'entities': {'mentions': [{'start': 3,
#      'end': 13,
#      'username': 'STU_ACTOR',
#      'id': '351541320'}],
#    'annotations': [{'start': 53,
#      'end': 69,
#      'probability': 0.856,
#      'type': 'Person',
#      'normalized_text': 'Sir Bruce Forsyth'}]},
#   'conversation_id': '898652788011352064',
#   'reply_settings': 'everyone',
#   'referenced_tweets': [{'type': 'retweeted', 'id': '898571054922289152'}]},
#  {'created_at': '2017-08-18T20:57:42.000Z',
#   'entities': {'urls': [{'start': 70,
#      'end': 93,
#      'url': 'https://t.co/kI8w7nnOyv',
#      'expanded_url': 'https://youtu.be/r0ZavqtlaHc',
#      'display_url': 'youtu.be/r0ZavqtlaHc'}],
#    'hashtags': [{'start': 119, 'end': 129, 'tag': 'LifeHacks'}],
#    'mentions': [{'start': 94,
#      'end': 105,
#      'username': 'lifehacker',
#      'id': '7144422'},
#     {'start': 106, 'end': 118, 'username': 'lifehackorg', 'id': '9027932'}]},
#   'source': 'Twitter for Android',
#   'lang': 'en',
#   'public_metrics': {'retweet_count': 1067,
#    'reply_count': 0,
#    'like_count': 0,
#    'quote_count': 0},
#   'text': 'RT @LiveFunAndDiy: How to Make a Fidget Spinner from 2 old Hard Disks\nhttps://t.co/kI8w7nnOyv\n@lifehacker @lifehackorg #LifeHacks @life_che…',
#   'id': '898650133725716481',
#   'conversation_id': '898650133725716481',
#   'reply_settings': 'everyone',
#   'referenced_tweets': [{'type': 'retweeted', 'id': '898622899040419841'}],
#   'context_annotations': [{'domain': {'id': '67',
#      'name': 'Interests and Hobbies',
#      'description': 'Interests, opinions, and behaviors of individuals, groups, or cultures; like Speciality Cooking or Theme Parks'},
#     'entity': {'id': '869997163270488064',
#      'name': 'Fidget Spinners',
#      'description': 'Fidget Spinners'}}]},
#  {'created_at': '2017-08-18T20:47:01.000Z',
#   'entities': {'urls': [{'start': 71,
#      'end': 94,
#      'url': 'https://t.co/3AjHatmeN5',
#      'expanded_url': 'https://vid.me/88Ua8',
#      'display_url': 'vid.me/88Ua8'}],
#    'hashtags': [{'start': 113, 'end': 119, 'tag': 'vidme'},
#     {'start': 120, 'end': 129, 'tag': 'TUTORIAL'},
#     {'start': 130, 'end': 134, 'tag': 'DIY'}],
#    'mentions': [{'start': 95,
#      'end': 101,
#      'username': 'vidme',
#      'id': '2241619002'},
#     {'start': 102,
#      'end': 112,
#      'username': 'VidmeClub',
#      'id': '829083950169600001'}]},
#   'source': 'Twitter for Android',
#   'lang': 'en',
#   'public_metrics': {'retweet_count': 1076,
#    'reply_count': 0,
#    'like_count': 0,
#    'quote_count': 0},
#   'text': 'RT @LiveFunAndDiy: How to Make a Fidget Spinner from 2 old Hard Disks \nhttps://t.co/3AjHatmeN5\n@vidme @VidmeClub #vidme #TUTORIAL #DIY @Bes…',
#   'id': '898647446326132736',
#   'conversation_id': '898647446326132736',
#   'reply_settings': 'everyone',
#   'referenced_tweets': [{'type': 'retweeted', 'id': '898621497257930752'}],
#   'context_annotations': [{'domain': {'id': '67',
#      'name': 'Interests and Hobbies',
#      'description': 'Interests, opinions, and behaviors of individuals, groups, or cultures; like Speciality Cooking or Theme Parks'},
#     'entity': {'id': '869997163270488064',
#      'name': 'Fidget Spinners',
#      'description': 'Fidget Spinners'}}]},
#  {'created_at': '2017-08-18T19:20:44.000Z',
#   'entities': {'urls': [{'start': 18,
#      'end': 41,
#      'url': 'https://t.co/YVPTddKqJ8',
#      'expanded_url': 'http://fb.me/3TdZw7vq4',
#      'display_url': 'fb.me/3TdZw7vq4'}],
#    'mentions': [{'start': 3,
#      'end': 16,
#      'username': 'GriffyOnline',
#      'id': '25752106'}]},
#   'source': 'Twitter for Android',
#   'lang': 'und',
#   'public_metrics': {'retweet_count': 114,
#    'reply_count': 0,
#    'like_count': 0,
#    'quote_count': 0},
#   'text': 'RT @GriffyOnline: https://t.co/YVPTddKqJ8',
#   'id': '898625728668811264',
#   'conversation_id': '898625728668811264',
#   'reply_settings': 'everyone',
#   'referenced_tweets': [{'type': 'retweeted', 'id': '898624212151058432'}]},
#  {'created_at': '2017-08-18T18:44:26.000Z',
#   'entities': {'urls': [{'start': 29,
#      'end': 52,
#      'url': 'https://t.co/299zgTr2E8',
#      'expanded_url': 'https://twitter.com/yuchaso_prince/status/898507221172076544/video/1',
#      'display_url': 'pic.twitter.com/299zgTr2E8',
#      'media_key': '7_898506990661492736'}],
#    'mentions': [{'start': 3,
#      'end': 18,
#      'username': 'yuchaso_prince',
#      'id': '2794403642'}]},
#   'source': 'Twitter for Android',
#   'lang': 'ja',
#   'public_metrics': {'retweet_count': 583,
#    'reply_count': 0,
#    'like_count': 0,
#    'quote_count': 0},
#   'text': 'RT @yuchaso_prince: だまされた... https://t.co/299zgTr2E8',
#   'id': '898616596280647681',
#   'attachments': {'media_keys': ['7_898506990661492736']},
#   'conversation_id': '898616596280647681',
#   'reply_settings': 'everyone',
#   'referenced_tweets': [{'type': 'retweeted', 'id': '898507221172076544'}]},
#  {'created_at': '2017-08-18T18:12:27.000Z',
#   'entities': {'urls': [{'start': 94,
#      'end': 117,
#      'url': 'https://t.co/xPYpzFJilr',
#      'expanded_url': 'http://7stage.com',
#      'display_url': '7stage.com',
#      'status': 200,
#      'title': 'Allkaline/Vegan | Qaraah Films™LLC',
#      'unwound_url': 'http://7stage.com'}],
#    'mentions': [{'start': 3,
#      'end': 14,
#      'username': 'yashqaraah',
#      'id': '35011829'}]},
#   'source': 'Twitter for Android',
#   'lang': 'en',
#   'public_metrics': {'retweet_count': 1490,
#    'reply_count': 0,
#    'like_count': 0,
#    'quote_count': 0},
#   'text': 'RT @yashqaraah: Just upload it boosting testosterone on the survival and nutrition channel on https://t.co/xPYpzFJilr https://t.co/qRT7ugD1…',
#   'id': '898608547096698880',
#   'conversation_id': '898608547096698880',
#   'reply_settings': 'everyone',
#   'referenced_tweets': [{'type': 'retweeted', 'id': '896846602836561921'}]}]

# %%
tweets_dataset.to_csv(f"twitter_human_bots_dataset/tweets140522.csv", index=True)

# %%
total_seconds_deltas = [123,60,80,34,1,2,7,77,48,9]
less_than_1min_deltas = filter(lambda s: s<=60, total_seconds_deltas)
len([t for t in total_seconds_deltas if t<=60])
# Out:
# 7
