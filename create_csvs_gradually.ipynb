# %%
import pandas
import time
from twitter_account_enrichment import *

twitter_human_bots_dataset_path = "twitter_human_bots_dataset/twitter_human_bots_dataset.csv"

# %%
twitter_human_bots_data = pandas.read_csv(twitter_human_bots_dataset_path, index_col=0)
accounts_ids = twitter_human_bots_data.id.astype(str).tolist()

# %% [markdown]
# # Followers Enrichment

# %%
followers_per_account = get_accounts_followers(accounts_ids[:])

# %%
followers_counter = 0
followers_nones_counter = 0
for account_id, followers in followers_per_account.items():
    if followers is not None:
        followers_counter += len(followers)
    else:
        followers_nones_counter += 1
len(followers_per_account), followers_counter, followers_nones_counter
# Out:
# (15, 7174, 3)

# %%
columns_names = ["followed_id", "follower_id", "follower_username", "follower_name", "follower_created_at", 
                 "follower_description", "follower_location", "follower_pinned_tweet_id", 
                 "follower_followers_count", "follower_following_count", "follower_tweet_count", 
                 "follower_listed_count"]
new_data = {column_name: [] for column_name in columns_names}
          
for followed_id, followers in followers_per_account.items():
    if followers is None:
        for column_name in columns_names:
            if column_name == "followed_id":
                new_data[column_name].append(followed_id)
            else:
                new_data[column_name].append(None)
        continue
    for follower in followers:
        for column_name in columns_names:
            if column_name == "followed_id":
                new_data[column_name].append(followed_id)
            elif column_name in ("follower_followers_count", "follower_following_count", "follower_tweet_count", 
                               "follower_listed_count"):
                new_data[column_name].append(follower["public_metrics"][column_name[9:]])
            else:
                new_data[column_name].append(follower.get(column_name[9:]))

# %%
df = pd.DataFrame(data=new_data)
df
# Out:
#      followed_id          follower_id follower_username follower_name  \
# 0      194490327  1449310127899611136   futukatu8SHINRI          せいさん
# 1      194490327  1500720679343165442     gingakaneko09       ミカヅキ銀河🌙
# 2      194490327  1461169079352700929          tugeongi         柘植まさじ
# 3      194490327  1450918944534147072    Mayumi55691066        Mayumi
# 4      194490327  1514299139173261313   Jg7j8BPWityq4WA      スカ－トは、芸術
# ...          ...                  ...               ...           ...
# 7172    36149861             42354130           illyttf      Vasilios
# 7173    36149861             18703604           S_RAM21     Stephanie
# 7174    36149861             16184186       alaria_doom   Broth Queen
# 7175   452695727                 None              None          None
# 7176   595227048                 None              None          None
#
#            follower_created_at  \
# 0     2021-10-16T09:44:30.000Z
# 1     2022-03-07T06:31:38.000Z
# 2     2021-11-18T03:07:57.000Z
# 3     2021-10-20T20:16:57.000Z
# 4     2022-04-13T17:47:38.000Z
# ...                        ...
# 7172  2009-05-25T05:07:06.000Z
# 7173  2009-01-07T00:41:26.000Z
# 7174  2008-09-08T13:30:02.000Z
# 7175                      None
# 7176                      None
#
#                                    follower_description follower_location  \
# 0     皆さまありがとう御座います。コロナ禍、いろいろな事の有る此の世の中。明るく、元気にして行きま...              None
# 1            幸福の科学メンバーです。幸福実現党を応援しています。無言フォロー失礼します。🎉😉❤️        シャンバラの遥か彼方
# 2                                        愛国者です、ニコニコします。              None
# 3     160㎝のhカップ💚18歳💜\n\nライン来てね～💘→https://t.co/k5MN84...              None
# 4                                                                    None
# ...                                                 ...               ...
# 7172                              The Illest forrealest          Chicago
# 7173                                                                 None
# 7174    Broth Queen 💖 #shibarmy / #dogecoin / #evergrow              None
# 7175                                               None              None
# 7176                                               None              None
#
#      follower_pinned_tweet_id  follower_followers_count  \
# 0                        None                     292.0
# 1                        None                     192.0
# 2                        None                    1523.0
# 3                        None                      55.0
# 4                        None                      43.0
# ...                       ...                       ...
# 7172                     None                      43.0
# 7173                     None                     127.0
# 7174      1421688721624244224                     358.0
# 7175                     None                       NaN
# 7176                     None                       NaN
#
#       follower_following_count  follower_tweet_count  follower_listed_count
# 0                        570.0                2182.0                    2.0
# 1                        505.0                  20.0                    1.0
# 2                       2301.0                2788.0                    4.0
# 3                       1466.0                   1.0                    6.0
# 4                        164.0                 119.0                    0.0
# ...                        ...                   ...                    ...
# 7172                      38.0                 205.0                    1.0
# 7173                     396.0               12080.0                    0.0
# 7174                     699.0                4862.0                   11.0
# 7175                       NaN                   NaN                    NaN
# 7176                       NaN                   NaN                    NaN
#
# [7177 rows x 12 columns]

# %%
df = pd.DataFrame(data=new_data)
df.to_csv(f"twitter_human_bots_dataset/followers{int(time.time())}.csv", index=False)

# %% [markdown]
# # Tweets Enrichment

# %%
tweets_per_account = get_accounts_tweets(accounts_ids[12500:])
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
tweets_counter = 0
tweets_nones_counter = 0
for account_id, tweets in tweets_per_account.items():
    if tweets is not None:
        tweets_counter += len(tweets)
    else:
        tweets_nones_counter += 1
len(tweets_per_account), tweets_counter, tweets_nones_counter
# Out:
# (113, 938, 9)

# %%
tweets_per_account[list(tweets_per_account.keys())[0]]
# Out:
# [{'source': 'Twitter for iPad',
#   'reply_settings': 'everyone',
#   'context_annotations': [{'domain': {'id': '10',
#      'name': 'Person',
#      'description': 'Named people in the world like Nelson Mandela'},
#     'entity': {'id': '799022225751871488',
#      'name': 'Donald Trump',
#      'description': '45th US President, Donald Trump'}},
#    {'domain': {'id': '10',
#      'name': 'Person',
#      'description': 'Named people in the world like Nelson Mandela'},
#     'entity': {'id': '1059669906201862144',
#      'name': 'Jack Posobiec',
#      'description': 'Jack Posobiec'}},
#    {'domain': {'id': '35',
#      'name': 'Politician',
#      'description': 'Politicians in the world, like Joe Biden'},
#     'entity': {'id': '799022225751871488',
#      'name': 'Donald Trump',
#      'description': '45th US President, Donald Trump'}}],
#   'text': '@SotoJellian3500 @JackPosobiec Trump, at least accomplished something.',
#   'id': '1498506850588712962',
#   'conversation_id': '1498328207334027264',
#   'lang': 'en',
#   'created_at': '2022-03-01T03:54:08.000Z',
#   'entities': {'annotations': [{'start': 31,
#      'end': 35,
#      'probability': 0.9977,
#      'type': 'Person',
#      'normalized_text': 'Trump'}],
#    'mentions': [{'start': 0,
#      'end': 16,
#      'username': 'SotoJellian3500',
#      'id': '808907412'},
#     {'start': 17, 'end': 30, 'username': 'JackPosobiec', 'id': '592730371'}]},
#   'in_reply_to_user_id': '808907412',
#   'public_metrics': {'retweet_count': 0,
#    'reply_count': 0,
#    'like_count': 0,
#    'quote_count': 0}},
#  {'source': 'Twitter for iPad',
#   'reply_settings': 'everyone',
#   'context_annotations': [{'domain': {'id': '10',
#      'name': 'Person',
#      'description': 'Named people in the world like Nelson Mandela'},
#     'entity': {'id': '1059669906201862144',
#      'name': 'Jack Posobiec',
#      'description': 'Jack Posobiec'}}],
#   'text': '@JackPosobiec AMEN…..',
#   'id': '1498506031248207873',
#   'conversation_id': '1498328207334027264',
#   'lang': 'en',
#   'created_at': '2022-03-01T03:50:53.000Z',
#   'entities': {'mentions': [{'start': 0,
#      'end': 13,
#      'username': 'JackPosobiec',
#      'id': '592730371'}]},
#   'in_reply_to_user_id': '592730371',
#   'public_metrics': {'retweet_count': 1,
#    'reply_count': 0,
#    'like_count': 0,
#    'quote_count': 0}},
#  {'source': 'Twitter for iPad',
#   'reply_settings': 'everyone',
#   'context_annotations': [{'domain': {'id': '10',
#      'name': 'Person',
#      'description': 'Named people in the world like Nelson Mandela'},
#     'entity': {'id': '1059669906201862144',
#      'name': 'Jack Posobiec',
#      'description': 'Jack Posobiec'}}],
#   'text': '@stubborn_swede @JackPosobiec He has screwed up everything he’s tried.',
#   'id': '1498505427637600257',
#   'conversation_id': '1498328207334027264',
#   'lang': 'en',
#   'created_at': '2022-03-01T03:48:29.000Z',
#   'entities': {'mentions': [{'start': 0,
#      'end': 15,
#      'username': 'stubborn_swede',
#      'id': '82211673'},
#     {'start': 16, 'end': 29, 'username': 'JackPosobiec', 'id': '592730371'}]},
#   'in_reply_to_user_id': '82211673',
#   'public_metrics': {'retweet_count': 0,
#    'reply_count': 0,
#    'like_count': 5,
#    'quote_count': 0}},
#  {'source': 'Twitter for iPad',
#   'reply_settings': 'everyone',
#   'text': '@JaniceDean Sorry, I can’t get my code right',
#   'id': '1466188699541012481',
#   'conversation_id': '1466118926996230148',
#   'lang': 'en',
#   'created_at': '2021-12-01T23:33:21.000Z',
#   'entities': {'mentions': [{'start': 0,
#      'end': 11,
#      'username': 'JaniceDean',
#      'id': '111400999'}]},
#   'in_reply_to_user_id': '111400999',
#   'public_metrics': {'retweet_count': 0,
#    'reply_count': 0,
#    'like_count': 0,
#    'quote_count': 0}},
#  {'source': 'Twitter for iPhone',
#   'reply_settings': 'everyone',
#   'context_annotations': [{'domain': {'id': '10',
#      'name': 'Person',
#      'description': 'Named people in the world like Nelson Mandela'},
#     'entity': {'id': '989579035599515648',
#      'name': 'Jim Jordan',
#      'description': 'US Representative Jim Jordan (OH-04)'}},
#    {'domain': {'id': '35',
#      'name': 'Politician',
#      'description': 'Politicians in the world, like Joe Biden'},
#     'entity': {'id': '989579035599515648',
#      'name': 'Jim Jordan',
#      'description': 'US Representative Jim Jordan (OH-04)'}}],
#   'text': '@Jim_Jordan And a great leader.',
#   'id': '1437171363165270017',
#   'conversation_id': '1364607989211156481',
#   'lang': 'en',
#   'created_at': '2021-09-12T21:48:48.000Z',
#   'entities': {'mentions': [{'start': 0,
#      'end': 11,
#      'username': 'Jim_Jordan',
#      'id': '18166778'}]},
#   'in_reply_to_user_id': '18166778',
#   'public_metrics': {'retweet_count': 0,
#    'reply_count': 0,
#    'like_count': 0,
#    'quote_count': 0}},
#  {'source': 'Twitter for iPad',
#   'reply_settings': 'everyone',
#   'context_annotations': [{'domain': {'id': '10',
#      'name': 'Person',
#      'description': 'Named people in the world like Nelson Mandela'},
#     'entity': {'id': '1138070898013982721',
#      'name': 'Ryan Fournier',
#      'description': 'Political Commentator and Analyst '}},
#    {'domain': {'id': '35',
#      'name': 'Politician',
#      'description': 'Politicians in the world, like Joe Biden'},
#     'entity': {'id': '1138070898013982721',
#      'name': 'Ryan Fournier',
#      'description': 'Political Commentator and Analyst '}}],
#   'text': '@RyanAFournier That’s right',
#   'id': '1436891063994650625',
#   'conversation_id': '1402756965877653504',
#   'lang': 'en',
#   'created_at': '2021-09-12T03:15:00.000Z',
#   'entities': {'mentions': [{'start': 0,
#      'end': 14,
#      'username': 'RyanAFournier',
#      'id': '166751745'}]},
#   'in_reply_to_user_id': '166751745',
#   'public_metrics': {'retweet_count': 0,
#    'reply_count': 0,
#    'like_count': 0,
#    'quote_count': 0}},
#  {'source': 'Twitter for iPad',
#   'reply_settings': 'everyone',
#   'text': '@GingersPage I love America',
#   'id': '1436890627384365058',
#   'conversation_id': '1402705839752888322',
#   'lang': 'en',
#   'created_at': '2021-09-12T03:13:16.000Z',
#   'entities': {'annotations': [{'start': 20,
#      'end': 26,
#      'probability': 0.9764,
#      'type': 'Place',
#      'normalized_text': 'America'}]},
#   'in_reply_to_user_id': '1101953865409314817',
#   'public_metrics': {'retweet_count': 0,
#    'reply_count': 0,
#    'like_count': 0,
#    'quote_count': 0}},
#  {'source': 'Twitter for iPad',
#   'reply_settings': 'everyone',
#   'text': '@CzaplickiStan @JaniceDean Piece of shit',
#   'id': '1382844713389092866',
#   'conversation_id': '1382368934305935361',
#   'lang': 'en',
#   'created_at': '2021-04-15T23:54:06.000Z',
#   'entities': {'mentions': [{'start': 0,
#      'end': 14,
#      'username': 'CzaplickiStan',
#      'id': '1298826170595770371'},
#     {'start': 15, 'end': 26, 'username': 'JaniceDean', 'id': '111400999'}]},
#   'in_reply_to_user_id': '1298826170595770371',
#   'public_metrics': {'retweet_count': 0,
#    'reply_count': 0,
#    'like_count': 0,
#    'quote_count': 0}},
#  {'source': 'Twitter for iPhone',
#   'reply_settings': 'everyone',
#   'entities': {'urls': [{'start': 39,
#      'end': 62,
#      'url': 'https://t.co/1yRMIvyTr9',
#      'expanded_url': 'https://m.wishdates.com/wizard/preferences-join-reasons',
#      'display_url': 'm.wishdates.com/wizard/prefere…',
#      'unwound_url': 'https://m.wishdates.com/wizard/preferences-join-reasons'}]},
#   'text': 'WishDates Join Us and Find your Couple https://t.co/1yRMIvyTr9',
#   'id': '1335798588673159168',
#   'conversation_id': '1335798588673159168',
#   'lang': 'en',
#   'created_at': '2020-12-07T04:09:36.000Z',
#   'public_metrics': {'retweet_count': 0,
#    'reply_count': 0,
#    'like_count': 1,
#    'quote_count': 0}},
#  {'source': 'Twitter for iPad',
#   'reply_settings': 'everyone',
#   'context_annotations': [{'domain': {'id': '10',
#      'name': 'Person',
#      'description': 'Named people in the world like Nelson Mandela'},
#     'entity': {'id': '799022225751871488',
#      'name': 'Donald Trump',
#      'description': '45th US President, Donald Trump'}},
#    {'domain': {'id': '35',
#      'name': 'Politician',
#      'description': 'Politicians in the world, like Joe Biden'},
#     'entity': {'id': '799022225751871488',
#      'name': 'Donald Trump',
#      'description': '45th US President, Donald Trump'}}],
#   'text': '@EvanAKilgore @realDonaldTrump Yes',
#   'id': '1296964836933251072',
#   'conversation_id': '1296853687487401985',
#   'lang': 'und',
#   'created_at': '2020-08-22T00:18:08.000Z',
#   'entities': {'mentions': [{'start': 0,
#      'end': 13,
#      'username': 'EvanAKilgore',
#      'id': '960285302899298304'},
#     {'start': 14,
#      'end': 30,
#      'username': 'realDonaldTrump',
#      'id': '25073877'}]},
#   'in_reply_to_user_id': '960285302899298304',
#   'public_metrics': {'retweet_count': 0,
#    'reply_count': 0,
#    'like_count': 0,
#    'quote_count': 0}}]

# %%
columns_names = ["id","attachments","context_annotations","conversation_id","created_at","account_id", 
                 "in_reply_to_user_id","lang","retweet_count","reply_count","like_count","quote_count",
                 "reply_settings","source","text", "mentions", "hashtags", "urls"]
new_data = {column_name: [] for column_name in columns_names}

for account_id, tweets in tweets_per_account.items():
    if tweets is None:
        for column_name in columns_names:
            if column_name == "account_id":
                new_data[column_name].append(account_id)
            else:
                new_data[column_name].append(None)
        continue
    for tweet in tweets:
        for column_name in columns_names:
            if column_name in ("retweet_count", "reply_count", "like_count", "quote_count"):
                new_data[column_name].append(tweet["public_metrics"][column_name])
            elif column_name == "mentions":
                mentions_usernames = []
                if "mentions" in tweet.get("entities", []):
                    mentions_usernames = [m["username"] for m in tweet["entities"]["mentions"]]
                new_data[column_name].append(mentions_usernames)
            elif column_name == "hashtags":
                hashtags_tags = []
                if "hashtags" in tweet.get("entities", []):
                    hashtags_tags = [m["tag"] for m in tweet["entities"]["hashtags"]]
                new_data[column_name].append(hashtags_tags)
            elif column_name == "urls":
                urls_expanded_url = []
                if "urls" in tweet.get("entities", []):
                    urls_expanded_url = [m["expanded_url"] for m in tweet["entities"]["urls"]]
                new_data[column_name].append(urls_expanded_url)
            elif column_name == "account_id":
                new_data[column_name].append(account_id)
            else:
                new_data[column_name].append(tweet.get(column_name))

# %%
df = pd.DataFrame(data=new_data)
df
# Out:
#                       id                                 attachments  \
# 0    1498506850588712962                                        None
# 1    1498506031248207873                                        None
# 2    1498505427637600257                                        None
# 3    1466188699541012481                                        None
# 4    1437171363165270017                                        None
# ..                   ...                                         ...
# 942  1520428453509611521                                        None
# 943  1520421199943192577                                        None
# 944  1520421168565690368                                        None
# 945  1520421088802574337                                        None
# 946  1520415305926946816  {'media_keys': ['13_1520413192631078913']}
#
#                                    context_annotations      conversation_id  \
# 0    [{'domain': {'id': '10', 'name': 'Person', 'de...  1498328207334027264
# 1    [{'domain': {'id': '10', 'name': 'Person', 'de...  1498328207334027264
# 2    [{'domain': {'id': '10', 'name': 'Person', 'de...  1498328207334027264
# 3                                                 None  1466118926996230148
# 4    [{'domain': {'id': '10', 'name': 'Person', 'de...  1364607989211156481
# ..                                                 ...                  ...
# 942  [{'domain': {'id': '3', 'name': 'TV Shows', 'd...  1520428453509611521
# 943  [{'domain': {'id': '12', 'name': 'Sports Team'...  1520421199943192577
# 944  [{'domain': {'id': '10', 'name': 'Person', 'de...  1520421168565690368
# 945  [{'domain': {'id': '12', 'name': 'Sports Team'...  1520421088802574337
# 946  [{'domain': {'id': '12', 'name': 'Sports Team'...  1520415305926946816
#
#                    created_at  account_id in_reply_to_user_id lang  \
# 0    2022-03-01T03:54:08.000Z  2433787058           808907412   en
# 1    2022-03-01T03:50:53.000Z  2433787058           592730371   en
# 2    2022-03-01T03:48:29.000Z  2433787058            82211673   en
# 3    2021-12-01T23:33:21.000Z  2433787058           111400999   en
# 4    2021-09-12T21:48:48.000Z  2433787058            18166778   en
# ..                        ...         ...                 ...  ...
# 942  2022-04-30T15:42:46.000Z   187574893                None   en
# 943  2022-04-30T15:13:56.000Z   187574893                None   en
# 944  2022-04-30T15:13:49.000Z   187574893                None   en
# 945  2022-04-30T15:13:30.000Z   187574893                None   en
# 946  2022-04-30T14:50:31.000Z   187574893                None   en
#
#      retweet_count  reply_count  like_count  quote_count reply_settings  \
# 0              0.0          0.0         0.0          0.0       everyone
# 1              1.0          0.0         0.0          0.0       everyone
# 2              0.0          0.0         5.0          0.0       everyone
# 3              0.0          0.0         0.0          0.0       everyone
# 4              0.0          0.0         0.0          0.0       everyone
# ..             ...          ...         ...          ...            ...
# 942         5299.0          0.0         0.0          0.0       everyone
# 943            4.0          0.0         0.0          0.0       everyone
# 944           10.0          0.0         0.0          0.0       everyone
# 945            3.0          0.0         0.0          0.0       everyone
# 946           25.0          0.0         0.0          0.0       everyone
#
#                  source                                               text  \
# 0      Twitter for iPad  @SotoJellian3500 @JackPosobiec Trump, at least...
# 1      Twitter for iPad                              @JackPosobiec AMEN…..
# 2      Twitter for iPad  @stubborn_swede @JackPosobiec He has screwed u...
# 3      Twitter for iPad       @JaniceDean Sorry, I can’t get my code right
# 4    Twitter for iPhone                    @Jim_Jordan And a great leader.
# ..                  ...                                                ...
# 942  Twitter for iPhone  RT @chris_kammy: After 24years at Sky Sports w...
# 943  Twitter for iPhone  RT @wwfcofficial: What an assist!\n\nDavid Whe...
# 944  Twitter for iPhone  RT @wwfcofficial: Onto Thursday!\n\nGareth Ain...
# 945  Twitter for iPhone  RT @wwfcofficial: News about tickets for the a...
# 946  Twitter for iPhone  RT @wwfcofficial: The show goes on!\n\n#BURvWY...
#
#                             mentions     hashtags  \
# 0    [SotoJellian3500, JackPosobiec]           []
# 1                     [JackPosobiec]           []
# 2     [stubborn_swede, JackPosobiec]           []
# 3                       [JaniceDean]           []
# 4                       [Jim_Jordan]           []
# ..                               ...          ...
# 942                    [chris_kammy]           []
# 943                   [wwfcofficial]           []
# 944                   [wwfcofficial]  [Chairboys]
# 945                   [wwfcofficial]  [Chairboys]
# 946                   [wwfcofficial]    [BURvWYC]
#
#                                                   urls
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 942                                                 []
# 943                                                 []
# 944                                                 []
# 945                                                 []
# 946  [https://twitter.com/wwfcofficial/status/15204...
#
# [947 rows x 18 columns]

# %%
df = pd.DataFrame(data=new_data)
df.to_csv(f"twitter_human_bots_dataset/tweets{int(time.time())}.csv", index=False)

# %%
twitter_human_tweets_data = pandas.read_csv("twitter_human_bots_dataset/tweets1651652762.csv")
twitter_human_tweets_data
# Out:
#                  id                                attachments  \
# 0      1.520095e+18  {'media_keys': ['3_1520069366892609542']}
# 1      1.520067e+18                                        NaN
# 2      1.516582e+18  {'media_keys': ['3_1516091367365267469']}
# 3      1.516264e+18                                        NaN
# 4      1.516263e+18                                        NaN
# ...             ...                                        ...
# 12567  1.129202e+18  {'media_keys': ['7_1128824151924498432']}
# 12568  1.128491e+18                                        NaN
# 12569  1.127664e+18  {'media_keys': ['3_1127664051033657344']}
# 12570  1.126236e+18                                        NaN
# 12571  1.126229e+18                                        NaN
#
#                                      context_annotations  conversation_id  \
# 0                                                    NaN     1.520095e+18
# 1                                                    NaN     1.519788e+18
# 2                                                    NaN     1.516582e+18
# 3                                                    NaN     1.514945e+18
# 4                                                    NaN     1.516263e+18
# ...                                                  ...              ...
# 12567                                                NaN     1.129202e+18
# 12568                                                NaN     1.128491e+18
# 12569  [{'domain': {'id': '29', 'name': 'Events [Enti...     1.127664e+18
# 12570                                                NaN     1.126236e+18
# 12571                                                NaN     1.126229e+18
#
#                      created_at  account_id  in_reply_to_user_id lang  \
# 0      2022-04-29T17:37:46.000Z    53779179                  NaN  und
# 1      2022-04-29T15:46:55.000Z    53779179         1.219082e+09   de
# 2      2022-04-20T00:59:32.000Z    53779179                  NaN  und
# 3      2022-04-19T03:53:28.000Z    53779179         1.250953e+18   pt
# 4      2022-04-19T03:49:11.000Z    53779179                  NaN  und
# ...                         ...         ...                  ...  ...
# 12567  2019-05-17T01:47:31.000Z   604842260                  NaN   en
# 12568  2019-05-15T02:43:53.000Z   604842260                  NaN   en
# 12569  2019-05-12T19:57:18.000Z   604842260                  NaN   en
# 12570  2019-05-08T21:24:04.000Z   604842260                  NaN   en
# 12571  2019-05-08T20:55:17.000Z   604842260                  NaN   en
#
#        retweet_count  reply_count  like_count  quote_count reply_settings  \
# 0              860.0          0.0         0.0          0.0       everyone
# 1                0.0          0.0         0.0          0.0       everyone
# 2            18465.0          0.0         0.0          0.0       everyone
# 3                0.0          0.0         0.0          0.0       everyone
# 4                0.0          0.0         2.0          0.0       everyone
# ...              ...          ...         ...          ...            ...
# 12567       155263.0          0.0         0.0          0.0       everyone
# 12568        13148.0          0.0         0.0          0.0       everyone
# 12569            0.0          1.0         5.0          0.0       everyone
# 12570          255.0          0.0         0.0          0.0       everyone
# 12571        69906.0          0.0         0.0          0.0       everyone
#
#                    source                                               text  \
# 0      Twitter for iPhone          RT @meltedvideos: https://t.co/mJzMYPvYvm
# 1      Twitter for iPhone                       @colnagu Achei sensuellen 💅💅
# 2      Twitter for iPhone       RT @FilosofiaMderna: https://t.co/YL5Nwf7fbU
# 3      Twitter for iPhone                       @LiperaAlves_ Kkkkkkkkk SIM!
# 4      Twitter for iPhone                        🗣🗣🗣 https://t.co/B3E72iX5hL
# ...                   ...                                                ...
# 12567  Twitter for iPhone  RT @tacopoop23: I think my mom found the best ...
# 12568  Twitter for iPhone  RT @naji_miracle: TIP OF THE DAY : God IS bigg...
# 12569  Twitter for iPhone  Happy Mother’s Day! @SoBlessed_96_98 ❤️❤️ http...
# 12570  Twitter for iPhone  RT @ChristineCaine: Therefore, submit to God. ...
# 12571  Twitter for iPhone  RT @sshireen_: Whenever I say ‘I am confusion’...
#
#                   mentions hashtags  \
# 0         ['meltedvideos']       []
# 1              ['colnagu']       []
# 2      ['FilosofiaMderna']       []
# 3         ['LiperaAlves_']       []
# 4                       []       []
# ...                    ...      ...
# 12567       ['tacopoop23']       []
# 12568                   []       []
# 12569  ['SoBlessed_96_98']       []
# 12570   ['ChristineCaine']       []
# 12571        ['Sshireen_']       []
#
#                                                     urls
# 0      ['https://twitter.com/meltedvideos/status/1520...
# 1                                                     []
# 2      ['https://twitter.com/FilosofiaMderna/status/1...
# 3                                                     []
# 4      ['https://twitter.com/alcrsk/status/1516039417...
# ...                                                  ...
# 12567  ['https://twitter.com/tacopoop23/status/112882...
# 12568                                                 []
# 12569  ['https://twitter.com/Bballin_Laney42/status/1...
# 12570                                                 []
# 12571                        ['https://t.co/yk0XLWhHM2']
#
# [12572 rows x 18 columns]

# %% [markdown]
# # User Details Enrichment

# %%
enriched_users = get_accounts_enriched(accounts_ids)

# %%
columns_names = ["id", "username", "created_at", "description", "location", "pinned_tweet_id", "protected",
                 "following_count", "tweet_count", "listed_count", "verified", "withheld", "account_type"]
new_data = {column_name: [] for column_name in columns_names}

for row in enriched_users:
    current_account_id = int(row['id'])
    for column_name in columns_names:
        if column_name == "account_type":
            new_data[column_name].append(dt.loc[dt['id'] == current_account_id].account_type.iloc[0])
        elif column_name in ("following_count", "tweet_count", "listed_count"):
            new_data[column_name].append(row["public_metrics"][column_name])
        else:
            new_data[column_name].append(row.get(column_name))

# %%
df = pd.DataFrame(data=new_data)
df.to_csv(f"data_sets/enriched_data_sets/{dir_names[0]}--{int(time.time())}--{file_names[0]}", index=False)
