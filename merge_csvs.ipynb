# %%
import os
from utils import *

# %%
twitter_human_bots_dataset_files = os.listdir("twitter_human_bots_dataset")
twitter_human_bots_dataset_files
# Out:
# ['tweets1651662905.csv',
#  'followers1651655975.csv',
#  'followers1651657526.csv',
#  'tweets1651668054.csv',
#  'followers1651661041.csv',
#  'tweets1651667363.csv',
#  'tweets040522.csv',
#  'tweets1651664867.csv',
#  'followers1651659335.csv',
#  'tweets1651668899.csv',
#  'followers040522.csv',
#  'tweets1651654376.csv',
#  'twitter_human_bots_dataset_orig.csv',
#  'twitter_human_bots_dataset.csv',
#  'followers1651657474.csv',
#  'tweets1651669069.csv',
#  'tweets1651661959.csv',
#  'last_queried.txt',
#  'tweets1651665687.csv',
#  'followers1651656297.csv',
#  'followers1651656056.csv',
#  'tweets1651652762.csv']

# %%
followers_files = list(filter(lambda fn: fn.startswith("followers1"), twitter_human_bots_dataset_files))
followers_files = list(map(lambda fn: "twitter_human_bots_dataset/"+fn, followers_files))
followers_files
# Out:
# ['twitter_human_bots_dataset/followers1651655975.csv',
#  'twitter_human_bots_dataset/followers1651657526.csv',
#  'twitter_human_bots_dataset/followers1651661041.csv',
#  'twitter_human_bots_dataset/followers1651659335.csv',
#  'twitter_human_bots_dataset/followers1651657474.csv',
#  'twitter_human_bots_dataset/followers1651656297.csv',
#  'twitter_human_bots_dataset/followers1651656056.csv']

# %%
df=merge_dfs_files(followers_files)
df.to_csv(f"twitter_human_bots_dataset/followers040522.csv", index=False)
# Out:
# /Users/orlysk/Documents/TwitterBotsProject/venv/lib/python3.7/site-packages/ipykernel_launcher.py:1: DtypeWarning: Columns (0,1,2,3,4,5,6) have mixed types.Specify dtype option on import or set low_memory=False.
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#      followed_id            follower_id follower_username    follower_name  \
# 0       53779179   781684125296168960.0   gabizinhacamara           Câmara
# 1       53779179  1386817842922860544.0      gabidarcim11             gabi
# 2       53779179  1468619493207572480.0        Gabis_Goes    Gabriele Goes
# 3       53779179  1475611624992083968.0      tai_cavallii  Tainara Cavalli
# 4       53779179            103288329.0     LariissaWolff        larisuolf
# ...          ...                    ...               ...              ...
# 4092    62204119            212339090.0        malcalorie             🤷‍♀️
# 4093    62204119            185120771.0       halfmoonl83  Hollis Martinez
# 4094    62204119             93221790.0          linzo183     Lindsay Vann
# 4095    62204119             15411122.0           nightie             Lace
# 4096    62204119             93550460.0        TulpaBlack      Tulpa Black
#
#            follower_created_at  \
# 0     2016-09-30T02:36:33.000Z
# 1     2021-04-26T23:02:03.000Z
# 2     2021-12-08T16:33:15.000Z
# 3     2021-12-27T23:37:34.000Z
# 4     2010-01-09T14:55:49.000Z
# ...                        ...
# 4092  2010-11-05T20:16:54.000Z
# 4093  2010-08-31T08:13:43.000Z
# 4094  2009-11-28T17:17:41.000Z
# 4095  2008-07-13T03:05:42.000Z
# 4096  2009-11-30T03:24:48.000Z
#
#                                    follower_description  \
# 0                                             XVIIII/💍💓
# 1                                       dentista, 21y 💖
# 2                                              Be you ✨
# 3                                                   NaN
# 4                                  🐾 Insta: Larisswolff
# ...                                                 ...
# 4092  Feminist. Sexual Assault and Domestic Violence...
# 4093                                                NaN
# 4094  short, silly, way too nice and has mad love fo...
# 4095  A brutally honest (temporary) redhead with too...
# 4096  If you can't be a good example, you've an obli...
#
#                 follower_location  follower_pinned_tweet_id  \
# 0                  Loanda, Brasil              1.440296e+18
# 1            Manoel Ribas, Brasil              1.480320e+18
# 2                             NaN                       NaN
# 3                  Loanda, Brasil                       NaN
# 4                 Maringá, Brasil                       NaN
# ...                           ...                       ...
# 4092                Montclair, NJ              9.840787e+17
# 4093                          NaN                       NaN
# 4094             jacksonville, fl                       NaN
# 4095                   Tucson, AZ                       NaN
# 4096  Somnambulant-City, Florida                        NaN
#
#       follower_followers_count  follower_following_count  \
# 0                       1049.0                     493.0
# 1                        395.0                     193.0
# 2                          4.0                      16.0
# 3                         40.0                      68.0
# 4                       1975.0                    1066.0
# ...                        ...                       ...
# 4092                     206.0                     390.0
# 4093                     172.0                     358.0
# 4094                      28.0                     133.0
# 4095                     308.0                    1266.0
# 4096                     157.0                     198.0
#
#       follower_tweet_count  follower_listed_count
# 0                   9619.0                    0.0
# 1                   2625.0                    0.0
# 2                      0.0                    0.0
# 3                     33.0                    0.0
# 4                 175706.0                    6.0
# ...                    ...                    ...
# 4092                4364.0                    5.0
# 4093                 367.0                    2.0
# 4094                2461.0                    2.0
# 4095                2114.0                    8.0
# 4096                1725.0                    0.0
#
# [365546 rows x 12 columns]

# %%
tweets_files = list(filter(lambda fn: fn.startswith("tweets1"), twitter_human_bots_dataset_files))
tweets_files = list(map(lambda fn: "twitter_human_bots_dataset/"+fn, tweets_files))

df=merge_dfs_files(tweets_files)
df.to_csv(f"twitter_human_bots_dataset/tweets040522.csv", index=False)

# %%
tweets_files
# Out:
# ['twitter_human_bots_dataset/tweets1651662905.csv',
#  'twitter_human_bots_dataset/tweets1651668054.csv',
#  'twitter_human_bots_dataset/tweets1651667363.csv',
#  'twitter_human_bots_dataset/tweets1651664867.csv',
#  'twitter_human_bots_dataset/tweets1651668899.csv',
#  'twitter_human_bots_dataset/tweets1651654376.csv',
#  'twitter_human_bots_dataset/tweets1651669069.csv',
#  'twitter_human_bots_dataset/tweets1651661959.csv',
#  'twitter_human_bots_dataset/tweets1651665687.csv',
#  'twitter_human_bots_dataset/tweets1651652762.csv']
